# %%
setwd('/Users/alexis/IEHS Dropbox/Rager Lab/Alexis_Payton/1_Compartment_Analysis/Expt1.2_Cytokine Distribution Analyses/Input')
Output = ('/Users/alexis/IEHS Dropbox/Rager Lab/Alexis_Payton/1_Compartment_Analysis/Expt1.2_Cytokine Distribution Analyses/Output')
cur_date = '121520'

library(readxl)
library(tidyverse)
library(reshape2)

#reading in file
data_df <- data.frame(read_excel("CytokineData_102920.xlsx", sheet = 2))

#reading in demographics file
demographics_data_df = data.frame(read_excel("SubjectInfo_102920.xlsx", sheet = 2))

#reading in contrasts file
contrasts = data.frame(read_excel("Table_of_Contrasts_121520.xlsx"))
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths

# %%
#dichotomizing variables
for (i in 1:length(demographics_data_df$Race)){
    if(demographics_data_df$Race[i] != 'W'){
        demographics_data_df$Race[i] = 'NW'
    } 
    if(demographics_data_df$Age[i] <= 30){
        demographics_data_df$Age[i] = 'U' #under 30
    } 
    else {
        demographics_data_df$Age[i] = 'O' #over 30
    }
}

for (i in 1:length(demographics_data_df$Race)){
    if (i != 32){ #ignoring NA value
        if(demographics_data_df$BMI[i] < 25){
            demographics_data_df$BMI[i] = 'N' #normal bmi
    }
        else {
            demographics_data_df$BMI[i] = 'O' #overweight
        }
    }
}

# %%
#adding demographics data to cytokine df
#could've made my life easier by just using full_join
race = c()
ethnicity = c()
sex = c()
age = c()
BMI = c()
for (i in 1:length(data_df$SubjectNo)){
    for(j in 1:length(demographics_data_df$SubjectNo)){
        if (data_df$SubjectNo[i] == demographics_data_df$SubjectNo[j]){
            race = c(race, demographics_data_df$Race[j])
            ethnicity = c(ethnicity, demographics_data_df$Ethnicity[j])
            sex = c(sex, demographics_data_df$Sex[j])
            age = c(age, demographics_data_df$Age[j])
            BMI = c(BMI, demographics_data_df$BMI[j])
        }
    }
}

data_df$Race = race
data_df$Ethnicity = ethnicity
data_df$Sex = sex
data_df$Age = age
data_df$BMI = BMI

# %%
head(data_df)
# Out:
#   Original_Identifier Protein Conc       Conc_pslog2 Compartment SubjectNo
# 1 E_C_F_002           IFNg     17.642316 4.220509    ELF         1
# 2 E_C_F_002           IL10      2.873724 1.953721    ELF         1
# 3 E_C_F_002           IL12p70   1.625272 1.392467    ELF         1
# 4 E_C_F_002           IL13     36.117692 5.214035    ELF         1
# 5 E_C_F_002           IL1b    104.409217 6.719857    ELF         1
# 6 E_C_F_002           IL6      21.159536 4.469856    ELF         1
#   Group SubjectID Race Ethnicity Sex Age BMI
# 1 NS    NS_1      W    NH        F   U   O
# 2 NS    NS_1      W    NH        F   U   O
# 3 NS    NS_1      W    NH        F   U   O
# 4 NS    NS_1      W    NH        F   U   O
# 5 NS    NS_1      W    NH        F   U   O
# 6 NS    NS_1      W    NH        F   U   O

# %% [markdown]
# # Race

# %%
get_race_subset = function(dataframe, race, protein, smoking_status){
    #"""
    # Getting concentrations for white subjects for each cytokine based on smoking status (ciagratte or e-cig user).
    
    #:param: subsetted data frame, race specification, cytokine, smoking status 
    #:output: a 24x13 matrix containing concentrations for each cytokine

    #"""
    subsetted_df = subset(dataframe, dataframe$Race == race & dataframe$Protein == protein & dataframe$Group == smoking_status)
}

#white subjects
white_Eotaxin_CS = get_race_subset(data_df, 'W','Eotaxin','CS')
white_Eotaxin3_CS = get_race_subset(data_df, 'W','Eotaxin3','CS')
white_Fractalkine_CS = get_race_subset(data_df, 'W','Fractalkine','CS')
white_I309_CS = get_race_subset(data_df, 'W','I309','CS')
white_IFNg_CS = get_race_subset(data_df, 'W','IFNg','CS')
white_IL10_CS = get_race_subset(data_df, 'W','IL10','CS')
white_IL12p70_CS = get_race_subset(data_df, 'W','IL12p70','CS')
white_IL13_CS = get_race_subset(data_df, 'W','IL13','CS')
white_IL17B_CS = get_race_subset(data_df, 'W','IL17B','CS')
white_IL17D_CS = get_race_subset(data_df, 'W','IL17D','CS')
white_IL1b_CS = get_race_subset(data_df, 'W','IL1b','CS')
white_IL4_CS = get_race_subset(data_df, 'W','IL4','CS')
white_IL6_CS = get_race_subset(data_df, 'W','IL6','CS')
white_IL8_CS = get_race_subset(data_df, 'W','IL8','CS')
white_IP10_CS = get_race_subset(data_df, 'W','IP10','CS')
white_ITAC_CS = get_race_subset(data_df, 'W','ITAC','CS')
white_MCP1_CS = get_race_subset(data_df, 'W','MCP1','CS')
white_MIG_CS = get_race_subset(data_df, 'W','MIG','CS')
white_MIP1a_CS = get_race_subset(data_df, 'W','MIP1a','CS')
white_MIP1b_CS = get_race_subset(data_df, 'W','MIP1b','CS')
white_TARC_CS = get_race_subset(data_df, 'W','TARC','CS')
white_TNFa_CS = get_race_subset(data_df, 'W','TNFa','CS')
white_Eotaxin_Ecig = get_race_subset(data_df, 'W','Eotaxin','Ecig')
white_Eotaxin3_Ecig = get_race_subset(data_df, 'W','Eotaxin3','Ecig')
white_Fractalkine_Ecig = get_race_subset(data_df, 'W','Fractalkine','Ecig')
white_I309_Ecig = get_race_subset(data_df, 'W','I309','Ecig')
white_IFNg_Ecig = get_race_subset(data_df, 'W','IFNg','Ecig')
white_IL10_Ecig = get_race_subset(data_df, 'W','IL10','Ecig')
white_IL12p70_Ecig = get_race_subset(data_df, 'W','IL12p70','Ecig')
white_IL13_Ecig = get_race_subset(data_df, 'W','IL13','Ecig')
white_IL17B_Ecig = get_race_subset(data_df, 'W','IL17B','Ecig')
white_IL17D_Ecig = get_race_subset(data_df, 'W','IL17D','Ecig')
white_IL1b_Ecig = get_race_subset(data_df, 'W','IL1b','Ecig')
white_IL4_Ecig = get_race_subset(data_df, 'W','IL4','Ecig')
white_IL6_Ecig = get_race_subset(data_df, 'W','IL6','Ecig')
white_IL8_Ecig = get_race_subset(data_df, 'W','IL8','Ecig')
white_IP10_Ecig = get_race_subset(data_df, 'W','IP10','Ecig')
white_ITAC_Ecig = get_race_subset(data_df, 'W','ITAC','Ecig')
white_MCP1_Ecig = get_race_subset(data_df, 'W','MCP1','Ecig')
white_MIG_Ecig = get_race_subset(data_df, 'W','MIG','Ecig')
white_MIP1a_Ecig = get_race_subset(data_df, 'W','MIP1a','Ecig')
white_MIP1b_Ecig = get_race_subset(data_df, 'W','MIP1b','Ecig')
white_TARC_Ecig = get_race_subset(data_df, 'W','TARC','Ecig')
white_TNFa_Ecig = get_race_subset(data_df, 'W','TNFa','Ecig')
white_Eotaxin_NS = get_race_subset(data_df, 'W','Eotaxin','NS')
white_Eotaxin3_NS = get_race_subset(data_df, 'W','Eotaxin3','NS')
white_Fractalkine_NS = get_race_subset(data_df, 'W','Fractalkine','NS')
white_I309_NS = get_race_subset(data_df, 'W','I309','NS')
white_IFNg_NS = get_race_subset(data_df, 'W','IFNg','NS')
white_IL10_NS = get_race_subset(data_df, 'W','IL10','NS')
white_IL12p70_NS = get_race_subset(data_df, 'W','IL12p70','NS')
white_IL13_NS = get_race_subset(data_df, 'W','IL13','NS')
white_IL17B_NS = get_race_subset(data_df, 'W','IL17B','NS')
white_IL17D_NS = get_race_subset(data_df, 'W','IL17D','NS')
white_IL1b_NS = get_race_subset(data_df, 'W','IL1b','NS')
white_IL4_NS = get_race_subset(data_df, 'W','IL4','NS')
white_IL6_NS = get_race_subset(data_df, 'W','IL6','NS')
white_IL8_NS = get_race_subset(data_df, 'W','IL8','NS')
white_IP10_NS = get_race_subset(data_df, 'W','IP10','NS')
white_ITAC_NS = get_race_subset(data_df, 'W','ITAC','NS')
white_MCP1_NS = get_race_subset(data_df, 'W','MCP1','NS')
white_MIG_NS = get_race_subset(data_df, 'W','MIG','NS')
white_MIP1a_NS = get_race_subset(data_df, 'W','MIP1a','NS')
white_MIP1b_NS = get_race_subset(data_df, 'W','MIP1b','NS')
white_TARC_NS = get_race_subset(data_df, 'W','TARC','NS')
white_TNFa_NS = get_race_subset(data_df, 'W','TNFa','NS')

# %%
get_race_subset_nonwhite = function(dataframe, race, protein, smoking_status){
    #"""
    # Getting concentrations for non-Black subjects for each cytokine based on smoking status (ciagratte or e-cig user).
    
    #:param: subsetted data frame, race specification, cytokine, smoking status 
    #:output: a 24x13 matrix containing concentrations for each cytokine

    #"""
    subsetted_df = subset(dataframe, dataframe$Race != race & dataframe$Protein == protein & dataframe$Group == smoking_status)
}
#nonwhite subjects
nonwhite_Eotaxin_CS = get_race_subset_nonwhite(data_df, 'W','Eotaxin','CS')
nonwhite_Eotaxin3_CS = get_race_subset_nonwhite(data_df, 'W','Eotaxin3','CS')
nonwhite_Fractalkine_CS = get_race_subset_nonwhite(data_df, 'W','Fractalkine','CS')
nonwhite_I309_CS = get_race_subset_nonwhite(data_df, 'W','I309','CS')
nonwhite_IFNg_CS = get_race_subset_nonwhite(data_df, 'W','IFNg','CS')
nonwhite_IL10_CS = get_race_subset_nonwhite(data_df, 'W','IL10','CS')
nonwhite_IL12p70_CS = get_race_subset_nonwhite(data_df, 'W','IL12p70','CS')
nonwhite_IL13_CS = get_race_subset_nonwhite(data_df, 'W','IL13','CS')
nonwhite_IL17B_CS = get_race_subset_nonwhite(data_df, 'W','IL17B','CS')
nonwhite_IL17D_CS = get_race_subset_nonwhite(data_df, 'W','IL17D','CS')
nonwhite_IL1b_CS = get_race_subset_nonwhite(data_df, 'W','IL1b','CS')
nonwhite_IL4_CS = get_race_subset_nonwhite(data_df, 'W','IL4','CS')
nonwhite_IL6_CS = get_race_subset_nonwhite(data_df, 'W','IL6','CS')
nonwhite_IL8_CS = get_race_subset_nonwhite(data_df, 'W','IL8','CS')
nonwhite_IP10_CS = get_race_subset_nonwhite(data_df, 'W','IP10','CS')
nonwhite_ITAC_CS = get_race_subset_nonwhite(data_df, 'W','ITAC','CS')
nonwhite_MCP1_CS = get_race_subset_nonwhite(data_df, 'W','MCP1','CS')
nonwhite_MIG_CS = get_race_subset_nonwhite(data_df, 'W','MIG','CS')
nonwhite_MIP1a_CS = get_race_subset_nonwhite(data_df, 'W','MIP1a','CS')
nonwhite_MIP1b_CS = get_race_subset_nonwhite(data_df, 'W','MIP1b','CS')
nonwhite_TARC_CS = get_race_subset_nonwhite(data_df, 'W','TARC','CS')
nonwhite_TNFa_CS = get_race_subset_nonwhite(data_df, 'W','TNFa','CS')
nonwhite_Eotaxin_Ecig = get_race_subset_nonwhite(data_df, 'W','Eotaxin','Ecig')
nonwhite_Eotaxin3_Ecig = get_race_subset_nonwhite(data_df, 'W','Eotaxin3','Ecig')
nonwhite_Fractalkine_Ecig = get_race_subset_nonwhite(data_df, 'W','Fractalkine','Ecig')
nonwhite_I309_Ecig = get_race_subset_nonwhite(data_df, 'W','I309','Ecig')
nonwhite_IFNg_Ecig = get_race_subset_nonwhite(data_df, 'W','IFNg','Ecig')
nonwhite_IL10_Ecig = get_race_subset_nonwhite(data_df, 'W','IL10','Ecig')
nonwhite_IL12p70_Ecig = get_race_subset_nonwhite(data_df, 'W','IL12p70','Ecig')
nonwhite_IL13_Ecig = get_race_subset_nonwhite(data_df, 'W','IL13','Ecig')
nonwhite_IL17B_Ecig = get_race_subset_nonwhite(data_df, 'W','IL17B','Ecig')
nonwhite_IL17D_Ecig = get_race_subset_nonwhite(data_df, 'W','IL17D','Ecig')
nonwhite_IL1b_Ecig = get_race_subset_nonwhite(data_df, 'W','IL1b','Ecig')
nonwhite_IL4_Ecig = get_race_subset_nonwhite(data_df, 'W','IL4','Ecig')
nonwhite_IL6_Ecig = get_race_subset_nonwhite(data_df, 'W','IL6','Ecig')
nonwhite_IL8_Ecig = get_race_subset_nonwhite(data_df, 'W','IL8','Ecig')
nonwhite_IP10_Ecig = get_race_subset_nonwhite(data_df, 'W','IP10','Ecig')
nonwhite_ITAC_Ecig = get_race_subset_nonwhite(data_df, 'W','ITAC','Ecig')
nonwhite_MCP1_Ecig = get_race_subset_nonwhite(data_df, 'W','MCP1','Ecig')
nonwhite_MIG_Ecig = get_race_subset_nonwhite(data_df, 'W','MIG','Ecig')
nonwhite_MIP1a_Ecig = get_race_subset_nonwhite(data_df, 'W','MIP1a','Ecig')
nonwhite_MIP1b_Ecig = get_race_subset_nonwhite(data_df, 'W','MIP1b','Ecig')
nonwhite_TARC_Ecig = get_race_subset_nonwhite(data_df, 'W','TARC','Ecig')
nonwhite_TNFa_Ecig = get_race_subset_nonwhite(data_df, 'W','TNFa','Ecig')
nonwhite_Eotaxin_NS = get_race_subset_nonwhite(data_df, 'W','Eotaxin','NS')
nonwhite_Eotaxin3_NS = get_race_subset_nonwhite(data_df, 'W','Eotaxin3','NS')
nonwhite_Fractalkine_NS = get_race_subset_nonwhite(data_df, 'W','Fractalkine','NS')
nonwhite_I309_NS = get_race_subset_nonwhite(data_df, 'W','I309','NS')
nonwhite_IFNg_NS = get_race_subset_nonwhite(data_df, 'W','IFNg','NS')
nonwhite_IL10_NS = get_race_subset_nonwhite(data_df, 'W','IL10','NS')
nonwhite_IL12p70_NS = get_race_subset_nonwhite(data_df, 'W','IL12p70','NS')
nonwhite_IL13_NS = get_race_subset_nonwhite(data_df, 'W','IL13','NS')
nonwhite_IL17B_NS = get_race_subset_nonwhite(data_df, 'W','IL17B','NS')
nonwhite_IL17D_NS = get_race_subset_nonwhite(data_df, 'W','IL17D','NS')
nonwhite_IL1b_NS = get_race_subset_nonwhite(data_df, 'W','IL1b','NS')
nonwhite_IL4_NS = get_race_subset_nonwhite(data_df, 'W','IL4','NS')
nonwhite_IL6_NS = get_race_subset_nonwhite(data_df, 'W','IL6','NS')
nonwhite_IL8_NS = get_race_subset_nonwhite(data_df, 'W','IL8','NS')
nonwhite_IP10_NS = get_race_subset_nonwhite(data_df, 'W','IP10','NS')
nonwhite_ITAC_NS = get_race_subset_nonwhite(data_df, 'W','ITAC','NS')
nonwhite_MCP1_NS = get_race_subset_nonwhite(data_df, 'W','MCP1','NS')
nonwhite_MIG_NS = get_race_subset_nonwhite(data_df, 'W','MIG','NS')
nonwhite_MIP1a_NS = get_race_subset_nonwhite(data_df, 'W','MIP1a','NS')
nonwhite_MIP1b_NS = get_race_subset_nonwhite(data_df, 'W','MIP1b','NS')
nonwhite_TARC_NS = get_race_subset_nonwhite(data_df, 'W','TARC','NS')
nonwhite_TNFa_NS = get_race_subset_nonwhite(data_df, 'W','TNFa','NS')

# %%
#white CS vs. NS
Eotaxin_white_CS = wilcox.test(white_Eotaxin_CS$Conc_pslog2, white_Eotaxin_NS$Conc_pslog2)
Eotaxin3_white_CS = wilcox.test(white_Eotaxin3_CS$Conc_pslog2, white_Eotaxin3_NS$Conc_pslog2)
Fractalkine_white_CS = wilcox.test(white_Fractalkine_CS$Conc_pslog2, white_Fractalkine_NS$Conc_pslog2)
I309_white_CS = wilcox.test(white_I309_CS$Conc_pslog2, white_I309_NS$Conc_pslog2)
IFNg_white_CS = wilcox.test(white_IFNg_CS$Conc_pslog2, white_IFNg_NS$Conc_pslog2)
IL10_white_CS = wilcox.test(white_IL10_CS$Conc_pslog2, white_IL10_NS$Conc_pslog2)
IL12p70_white_CS = wilcox.test(white_IL12p70_CS$Conc_pslog2, white_IL12p70_NS$Conc_pslog2)
IL13_white_CS = wilcox.test(white_IL13_CS$Conc_pslog2, white_IL13_NS$Conc_pslog2)
IL17B_white_CS = wilcox.test(white_IL17B_CS$Conc_pslog2, white_IL17B_NS$Conc_pslog2)
IL17D_white_CS = wilcox.test(white_IL17D_CS$Conc_pslog2, white_IL17D_NS$Conc_pslog2)
IL1b_white_CS = wilcox.test(white_IL1b_CS$Conc_pslog2, white_IL1b_NS$Conc_pslog2)
IL4_white_CS = wilcox.test(white_IL4_CS$Conc_pslog2, white_IL4_NS$Conc_pslog2)
IL6_white_CS = wilcox.test(white_IL6_CS$Conc_pslog2, white_IL6_NS$Conc_pslog2)
IL8_white_CS = wilcox.test(white_IL8_CS$Conc_pslog2, white_IL8_NS$Conc_pslog2)
IP10_white_CS = wilcox.test(white_IP10_CS$Conc_pslog2, white_IP10_NS$Conc_pslog2)
ITAC_white_CS = wilcox.test(white_ITAC_CS$Conc_pslog2, white_ITAC_NS$Conc_pslog2)
MCP1_white_CS = wilcox.test(white_MCP1_CS$Conc_pslog2, white_MCP1_NS$Conc_pslog2)
MIG_white_CS = wilcox.test(white_MIG_CS$Conc_pslog2, white_MIG_NS$Conc_pslog2)
MIP1a_white_CS = wilcox.test(white_MIP1a_CS$Conc_pslog2, white_MIP1a_NS$Conc_pslog2)
MIP1b_white_CS = wilcox.test(white_MIP1b_CS$Conc_pslog2, white_MIP1b_NS$Conc_pslog2)
TARC_white_CS = wilcox.test(white_TARC_CS$Conc_pslog2, white_TARC_NS$Conc_pslog2)
TNFa_white_CS = wilcox.test(white_TNFa_CS$Conc_pslog2, white_TNFa_NS$Conc_pslog2)

#white Ecig vs. NS
Eotaxin_white_Ecig = wilcox.test(white_Eotaxin_Ecig$Conc_pslog2, white_Eotaxin_NS$Conc_pslog2)
Eotaxin3_white_Ecig = wilcox.test(white_Eotaxin3_Ecig$Conc_pslog2, white_Eotaxin3_NS$Conc_pslog2)
Fractalkine_white_Ecig = wilcox.test(white_Fractalkine_Ecig$Conc_pslog2, white_Fractalkine_NS$Conc_pslog2)
I309_white_Ecig = wilcox.test(white_I309_Ecig$Conc_pslog2, white_I309_NS$Conc_pslog2)
IFNg_white_Ecig = wilcox.test(white_IFNg_Ecig$Conc_pslog2, white_IFNg_NS$Conc_pslog2)
IL10_white_Ecig = wilcox.test(white_IL10_Ecig$Conc_pslog2, white_IL10_NS$Conc_pslog2)
IL12p70_white_Ecig = wilcox.test(white_IL12p70_Ecig$Conc_pslog2, white_IL12p70_NS$Conc_pslog2)
IL13_white_Ecig = wilcox.test(white_IL13_Ecig$Conc_pslog2, white_IL13_NS$Conc_pslog2)
IL17B_white_Ecig = wilcox.test(white_IL17B_Ecig$Conc_pslog2, white_IL17B_NS$Conc_pslog2)
IL17D_white_Ecig = wilcox.test(white_IL17D_Ecig$Conc_pslog2, white_IL17D_NS$Conc_pslog2)
IL1b_white_Ecig = wilcox.test(white_IL1b_Ecig$Conc_pslog2, white_IL1b_NS$Conc_pslog2)
IL4_white_Ecig = wilcox.test(white_IL4_Ecig$Conc_pslog2, white_IL4_NS$Conc_pslog2)
IL6_white_Ecig = wilcox.test(white_IL6_Ecig$Conc_pslog2, white_IL6_NS$Conc_pslog2)
IL8_white_Ecig = wilcox.test(white_IL8_Ecig$Conc_pslog2, white_IL8_NS$Conc_pslog2)
IP10_white_Ecig = wilcox.test(white_IP10_Ecig$Conc_pslog2, white_IP10_NS$Conc_pslog2)
ITAC_white_Ecig = wilcox.test(white_ITAC_Ecig$Conc_pslog2, white_ITAC_NS$Conc_pslog2)
MCP1_white_Ecig = wilcox.test(white_MCP1_Ecig$Conc_pslog2, white_MCP1_NS$Conc_pslog2)
MIG_white_Ecig = wilcox.test(white_MIG_Ecig$Conc_pslog2, white_MIG_NS$Conc_pslog2)
MIP1a_white_Ecig = wilcox.test(white_MIP1a_Ecig$Conc_pslog2, white_MIP1a_NS$Conc_pslog2)
MIP1b_white_Ecig = wilcox.test(white_MIP1b_Ecig$Conc_pslog2, white_MIP1b_NS$Conc_pslog2)
TARC_white_Ecig = wilcox.test(white_TARC_Ecig$Conc_pslog2, white_TARC_NS$Conc_pslog2)
TNFa_white_Ecig = wilcox.test(white_TNFa_Ecig$Conc_pslog2, white_TNFa_NS$Conc_pslog2)

#nonwhite CS vs. NS
Eotaxin_nonwhite_CS = wilcox.test(nonwhite_Eotaxin_CS$Conc_pslog2, nonwhite_Eotaxin_NS$Conc_pslog2)
Eotaxin3_nonwhite_CS = wilcox.test(nonwhite_Eotaxin3_CS$Conc_pslog2, nonwhite_Eotaxin3_NS$Conc_pslog2)
Fractalkine_nonwhite_CS = wilcox.test(nonwhite_Fractalkine_CS$Conc_pslog2, nonwhite_Fractalkine_NS$Conc_pslog2)
I309_nonwhite_CS = wilcox.test(nonwhite_I309_CS$Conc_pslog2, nonwhite_I309_NS$Conc_pslog2)
IFNg_nonwhite_CS = wilcox.test(nonwhite_IFNg_CS$Conc_pslog2, nonwhite_IFNg_NS$Conc_pslog2)
IL10_nonwhite_CS = wilcox.test(nonwhite_IL10_CS$Conc_pslog2, nonwhite_IL10_NS$Conc_pslog2)
IL12p70_nonwhite_CS = wilcox.test(nonwhite_IL12p70_CS$Conc_pslog2, nonwhite_IL12p70_NS$Conc_pslog2)
IL13_nonwhite_CS = wilcox.test(nonwhite_IL13_CS$Conc_pslog2, nonwhite_IL13_NS$Conc_pslog2)
IL17B_nonwhite_CS = wilcox.test(nonwhite_IL17B_CS$Conc_pslog2, nonwhite_IL17B_NS$Conc_pslog2)
IL17D_nonwhite_CS = wilcox.test(nonwhite_IL17D_CS$Conc_pslog2, nonwhite_IL17D_NS$Conc_pslog2)
IL1b_nonwhite_CS = wilcox.test(nonwhite_IL1b_CS$Conc_pslog2, nonwhite_IL1b_NS$Conc_pslog2)
IL4_nonwhite_CS = wilcox.test(nonwhite_IL4_CS$Conc_pslog2, nonwhite_IL4_NS$Conc_pslog2)
IL6_nonwhite_CS = wilcox.test(nonwhite_IL6_CS$Conc_pslog2, nonwhite_IL6_NS$Conc_pslog2)
IL8_nonwhite_CS = wilcox.test(nonwhite_IL8_CS$Conc_pslog2, nonwhite_IL8_NS$Conc_pslog2)
IP10_nonwhite_CS = wilcox.test(nonwhite_IP10_CS$Conc_pslog2, nonwhite_IP10_NS$Conc_pslog2)
ITAC_nonwhite_CS = wilcox.test(nonwhite_ITAC_CS$Conc_pslog2, nonwhite_ITAC_NS$Conc_pslog2)
MCP1_nonwhite_CS = wilcox.test(nonwhite_MCP1_CS$Conc_pslog2, nonwhite_MCP1_NS$Conc_pslog2)
MIG_nonwhite_CS = wilcox.test(nonwhite_MIG_CS$Conc_pslog2, nonwhite_MIG_NS$Conc_pslog2)
MIP1a_nonwhite_CS = wilcox.test(nonwhite_MIP1a_CS$Conc_pslog2, nonwhite_MIP1a_NS$Conc_pslog2)
MIP1b_nonwhite_CS = wilcox.test(nonwhite_MIP1b_CS$Conc_pslog2, nonwhite_MIP1b_NS$Conc_pslog2)
TARC_nonwhite_CS = wilcox.test(nonwhite_TARC_CS$Conc_pslog2, nonwhite_TARC_NS$Conc_pslog2)
TNFa_nonwhite_CS = wilcox.test(nonwhite_TNFa_CS$Conc_pslog2, nonwhite_TNFa_NS$Conc_pslog2)

#nonwhite Ecig vs. NS
Eotaxin_nonwhite_Ecig = wilcox.test(nonwhite_Eotaxin_Ecig$Conc_pslog2, nonwhite_Eotaxin_NS$Conc_pslog2)
Eotaxin3_nonwhite_Ecig = wilcox.test(nonwhite_Eotaxin3_Ecig$Conc_pslog2, nonwhite_Eotaxin3_NS$Conc_pslog2)
Fractalkine_nonwhite_Ecig = wilcox.test(nonwhite_Fractalkine_Ecig$Conc_pslog2, nonwhite_Fractalkine_NS$Conc_pslog2)
I309_nonwhite_Ecig = wilcox.test(nonwhite_I309_Ecig$Conc_pslog2, nonwhite_I309_NS$Conc_pslog2)
IFNg_nonwhite_Ecig = wilcox.test(nonwhite_IFNg_Ecig$Conc_pslog2, nonwhite_IFNg_NS$Conc_pslog2)
IL10_nonwhite_Ecig = wilcox.test(nonwhite_IL10_Ecig$Conc_pslog2, nonwhite_IL10_NS$Conc_pslog2)
IL12p70_nonwhite_Ecig = wilcox.test(nonwhite_IL12p70_Ecig$Conc_pslog2, nonwhite_IL12p70_NS$Conc_pslog2)
IL13_nonwhite_Ecig = wilcox.test(nonwhite_IL13_Ecig$Conc_pslog2, nonwhite_IL13_NS$Conc_pslog2)
IL17B_nonwhite_Ecig = wilcox.test(nonwhite_IL17B_Ecig$Conc_pslog2, nonwhite_IL17B_NS$Conc_pslog2)
IL17D_nonwhite_Ecig = wilcox.test(nonwhite_IL17D_Ecig$Conc_pslog2, nonwhite_IL17D_NS$Conc_pslog2)
IL1b_nonwhite_Ecig = wilcox.test(nonwhite_IL1b_Ecig$Conc_pslog2, nonwhite_IL1b_NS$Conc_pslog2)
IL4_nonwhite_Ecig = wilcox.test(nonwhite_IL4_Ecig$Conc_pslog2, nonwhite_IL4_NS$Conc_pslog2)
IL6_nonwhite_Ecig = wilcox.test(nonwhite_IL6_Ecig$Conc_pslog2, nonwhite_IL6_NS$Conc_pslog2)
IL8_nonwhite_Ecig = wilcox.test(nonwhite_IL8_Ecig$Conc_pslog2, nonwhite_IL8_NS$Conc_pslog2)
IP10_nonwhite_Ecig = wilcox.test(nonwhite_IP10_Ecig$Conc_pslog2, nonwhite_IP10_NS$Conc_pslog2)
ITAC_nonwhite_Ecig = wilcox.test(nonwhite_ITAC_Ecig$Conc_pslog2, nonwhite_ITAC_NS$Conc_pslog2)
MCP1_nonwhite_Ecig = wilcox.test(nonwhite_MCP1_Ecig$Conc_pslog2, nonwhite_MCP1_NS$Conc_pslog2)
MIG_nonwhite_Ecig = wilcox.test(nonwhite_MIG_Ecig$Conc_pslog2, nonwhite_MIG_NS$Conc_pslog2)
MIP1a_nonwhite_Ecig = wilcox.test(nonwhite_MIP1a_Ecig$Conc_pslog2, nonwhite_MIP1a_NS$Conc_pslog2)
MIP1b_nonwhite_Ecig = wilcox.test(nonwhite_MIP1b_Ecig$Conc_pslog2, nonwhite_MIP1b_NS$Conc_pslog2)
TARC_nonwhite_Ecig = wilcox.test(nonwhite_TARC_Ecig$Conc_pslog2, nonwhite_TARC_NS$Conc_pslog2)
TNFa_nonwhite_Ecig = wilcox.test(nonwhite_TNFa_Ecig$Conc_pslog2, nonwhite_TNFa_NS$Conc_pslog2)
# Out:
# Warning message in wilcox.test.default(white_Eotaxin_CS$Conc_pslog2, white_Eotaxin_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(white_Eotaxin3_CS$Conc_pslog2, white_Eotaxin3_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(white_I309_CS$Conc_pslog2, white_I309_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(white_IFNg_CS$Conc_pslog2, white_IFNg_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(white_IL10_CS$Conc_pslog2, white_IL10_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(white_IL12p70_CS$Conc_pslog2, white_IL12p70_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(white_IL13_CS$Conc_pslog2, white_IL13_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# ...

# %%
get_stat_pvalue_tuple = function(wilcox_test){
    rank_sum = wilcox_test$statistic
    p_value = wilcox_test$p.value
    tuple = c(rank_sum, p_value)
    return(tuple)
}
#white CS vs. NS
Eotaxin_white_CS_tuple = get_stat_pvalue_tuple(Eotaxin_white_CS)
Eotaxin3_white_CS_tuple = get_stat_pvalue_tuple(Eotaxin3_white_CS)
Fractalkine_white_CS_tuple = get_stat_pvalue_tuple(Fractalkine_white_CS)
I309_white_CS_tuple = get_stat_pvalue_tuple(I309_white_CS)
IFNg_white_CS_tuple = get_stat_pvalue_tuple(IFNg_white_CS)
IL10_white_CS_tuple = get_stat_pvalue_tuple(IL10_white_CS)
IL12p70_white_CS_tuple = get_stat_pvalue_tuple(IL12p70_white_CS)
IL13_white_CS_tuple = get_stat_pvalue_tuple(IL13_white_CS)
IL17B_white_CS_tuple = get_stat_pvalue_tuple(IL17B_white_CS)
IL17D_white_CS_tuple = get_stat_pvalue_tuple(IL17D_white_CS)
IL1b_white_CS_tuple = get_stat_pvalue_tuple(IL1b_white_CS)
IL4_white_CS_tuple = get_stat_pvalue_tuple(IL4_white_CS)
IL6_white_CS_tuple = get_stat_pvalue_tuple(IL6_white_CS)
IL8_white_CS_tuple = get_stat_pvalue_tuple(IL8_white_CS)
IP10_white_CS_tuple = get_stat_pvalue_tuple(IP10_white_CS)
ITAC_white_CS_tuple = get_stat_pvalue_tuple(ITAC_white_CS)
MCP1_white_CS_tuple = get_stat_pvalue_tuple(MCP1_white_CS)
MIG_white_CS_tuple = get_stat_pvalue_tuple(MIG_white_CS)
MIP1a_white_CS_tuple = get_stat_pvalue_tuple(MIP1a_white_CS)
MIP1b_white_CS_tuple = get_stat_pvalue_tuple(MIP1b_white_CS)
TARC_white_CS_tuple = get_stat_pvalue_tuple(TARC_white_CS)
TNFa_white_CS_tuple = get_stat_pvalue_tuple(TNFa_white_CS)

#white Ecig vs. NS
Eotaxin_white_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin_white_Ecig)
Eotaxin3_white_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin3_white_Ecig)
Fractalkine_white_Ecig_tuple = get_stat_pvalue_tuple(Fractalkine_white_Ecig)
I309_white_Ecig_tuple = get_stat_pvalue_tuple(I309_white_Ecig)
IFNg_white_Ecig_tuple = get_stat_pvalue_tuple(IFNg_white_Ecig)
IL10_white_Ecig_tuple = get_stat_pvalue_tuple(IL10_white_Ecig)
IL12p70_white_Ecig_tuple = get_stat_pvalue_tuple(IL12p70_white_Ecig)
IL13_white_Ecig_tuple = get_stat_pvalue_tuple(IL13_white_Ecig)
IL17B_white_Ecig_tuple = get_stat_pvalue_tuple(IL17B_white_Ecig)
IL17D_white_Ecig_tuple = get_stat_pvalue_tuple(IL17D_white_Ecig)
IL1b_white_Ecig_tuple = get_stat_pvalue_tuple(IL1b_white_Ecig)
IL4_white_Ecig_tuple = get_stat_pvalue_tuple(IL4_white_Ecig)
IL6_white_Ecig_tuple = get_stat_pvalue_tuple(IL6_white_Ecig)
IL8_white_Ecig_tuple = get_stat_pvalue_tuple(IL8_white_Ecig)
IP10_white_Ecig_tuple = get_stat_pvalue_tuple(IP10_white_Ecig)
ITAC_white_Ecig_tuple = get_stat_pvalue_tuple(ITAC_white_Ecig)
MCP1_white_Ecig_tuple = get_stat_pvalue_tuple(MCP1_white_Ecig)
MIG_white_Ecig_tuple = get_stat_pvalue_tuple(MIG_white_Ecig)
MIP1a_white_Ecig_tuple = get_stat_pvalue_tuple(MIP1a_white_Ecig)
MIP1b_white_Ecig_tuple = get_stat_pvalue_tuple(MIP1b_white_Ecig)
TARC_white_Ecig_tuple = get_stat_pvalue_tuple(TARC_white_Ecig)
TNFa_white_Ecig_tuple = get_stat_pvalue_tuple(TNFa_white_Ecig)

#nonwhite CS vs. NS
Eotaxin_nonwhite_CS_tuple = get_stat_pvalue_tuple(Eotaxin_nonwhite_CS)
Eotaxin3_nonwhite_CS_tuple = get_stat_pvalue_tuple(Eotaxin3_nonwhite_CS)
Fractalkine_nonwhite_CS_tuple = get_stat_pvalue_tuple(Fractalkine_nonwhite_CS)
I309_nonwhite_CS_tuple = get_stat_pvalue_tuple(I309_nonwhite_CS)
IFNg_nonwhite_CS_tuple = get_stat_pvalue_tuple(IFNg_nonwhite_CS)
IL10_nonwhite_CS_tuple = get_stat_pvalue_tuple(IL10_nonwhite_CS)
IL12p70_nonwhite_CS_tuple = get_stat_pvalue_tuple(IL12p70_nonwhite_CS)
IL13_nonwhite_CS_tuple = get_stat_pvalue_tuple(IL13_nonwhite_CS)
IL17B_nonwhite_CS_tuple = get_stat_pvalue_tuple(IL17B_nonwhite_CS)
IL17D_nonwhite_CS_tuple = get_stat_pvalue_tuple(IL17D_nonwhite_CS)
IL1b_nonwhite_CS_tuple = get_stat_pvalue_tuple(IL1b_nonwhite_CS)
IL4_nonwhite_CS_tuple = get_stat_pvalue_tuple(IL4_nonwhite_CS)
IL6_nonwhite_CS_tuple = get_stat_pvalue_tuple(IL6_nonwhite_CS)
IL8_nonwhite_CS_tuple = get_stat_pvalue_tuple(IL8_nonwhite_CS)
IP10_nonwhite_CS_tuple = get_stat_pvalue_tuple(IP10_nonwhite_CS)
ITAC_nonwhite_CS_tuple = get_stat_pvalue_tuple(ITAC_nonwhite_CS)
MCP1_nonwhite_CS_tuple = get_stat_pvalue_tuple(MCP1_nonwhite_CS)
MIG_nonwhite_CS_tuple = get_stat_pvalue_tuple(MIG_nonwhite_CS)
MIP1a_nonwhite_CS_tuple = get_stat_pvalue_tuple(MIP1a_nonwhite_CS)
MIP1b_nonwhite_CS_tuple = get_stat_pvalue_tuple(MIP1b_nonwhite_CS)
TARC_nonwhite_CS_tuple = get_stat_pvalue_tuple(TARC_nonwhite_CS)
TNFa_nonwhite_CS_tuple = get_stat_pvalue_tuple(TNFa_nonwhite_CS)

#nonwhite Ecig vs. NS
Eotaxin_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin_nonwhite_Ecig)
Eotaxin3_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin3_nonwhite_Ecig)
Fractalkine_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(Fractalkine_nonwhite_Ecig)
I309_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(I309_nonwhite_Ecig)
IFNg_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(IFNg_nonwhite_Ecig)
IL10_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(IL10_nonwhite_Ecig)
IL12p70_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(IL12p70_nonwhite_Ecig)
IL13_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(IL13_nonwhite_Ecig)
IL17B_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(IL17B_nonwhite_Ecig)
IL17D_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(IL17D_nonwhite_Ecig)
IL1b_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(IL1b_nonwhite_Ecig)
IL4_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(IL4_nonwhite_Ecig)
IL6_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(IL6_nonwhite_Ecig)
IL8_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(IL8_nonwhite_Ecig)
IP10_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(IP10_nonwhite_Ecig)
ITAC_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(ITAC_nonwhite_Ecig)
MCP1_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(MCP1_nonwhite_Ecig)
MIG_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(MIG_nonwhite_Ecig)
MIP1a_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(MIP1a_nonwhite_Ecig)
MIP1b_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(MIP1b_nonwhite_Ecig)
TARC_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(TARC_nonwhite_Ecig)
TNFa_nonwhite_Ecig_tuple = get_stat_pvalue_tuple(TNFa_nonwhite_Ecig)

# %% [markdown]
# # Sex

# %%
get_sex_subset = function(dataframe, sex, protein, smoking_status){
    #"""
    #Getting concentrations for subjects based on sex for each cytokine based on smoking status (ciagratte or 
    #e-cig user).
    
    #:param: subsetted data frame, sex specification, cytokine, smoking status 
    #:output: a 24x13 matrix containing concentrations for each cytokine

    #"""
    subsetted_df = subset(dataframe, dataframe$Sex == sex & dataframe$Protein == protein & dataframe$Group == smoking_status)
}

#male subjects
male_Eotaxin_CS = get_sex_subset(data_df, 'M','Eotaxin','CS')
male_Eotaxin3_CS = get_sex_subset(data_df, 'M','Eotaxin3','CS')
male_Fractalkine_CS = get_sex_subset(data_df, 'M','Fractalkine','CS')
male_I309_CS = get_sex_subset(data_df, 'M','I309','CS')
male_IFNg_CS = get_sex_subset(data_df, 'M','IFNg','CS')
male_IL10_CS = get_sex_subset(data_df, 'M','IL10','CS')
male_IL12p70_CS = get_sex_subset(data_df, 'M','IL12p70','CS')
male_IL13_CS = get_sex_subset(data_df, 'M','IL13','CS')
male_IL17B_CS = get_sex_subset(data_df, 'M','IL17B','CS')
male_IL17D_CS = get_sex_subset(data_df, 'M','IL17D','CS')
male_IL1b_CS = get_sex_subset(data_df, 'M','IL1b','CS')
male_IL4_CS = get_sex_subset(data_df, 'M','IL4','CS')
male_IL6_CS = get_sex_subset(data_df, 'M','IL6','CS')
male_IL8_CS = get_sex_subset(data_df, 'M','IL8','CS')
male_IP10_CS = get_sex_subset(data_df, 'M','IP10','CS')
male_ITAC_CS = get_sex_subset(data_df, 'M','ITAC','CS')
male_MCP1_CS = get_sex_subset(data_df, 'M','MCP1','CS')
male_MIG_CS = get_sex_subset(data_df, 'M','MIG','CS')
male_MIP1a_CS = get_sex_subset(data_df, 'M','MIP1a','CS')
male_MIP1b_CS = get_sex_subset(data_df, 'M','MIP1b','CS')
male_TARC_CS = get_sex_subset(data_df, 'M','TARC','CS')
male_TNFa_CS = get_sex_subset(data_df, 'M','TNFa','CS')
male_Eotaxin_Ecig = get_sex_subset(data_df, 'M','Eotaxin','Ecig')
male_Eotaxin3_Ecig = get_sex_subset(data_df, 'M','Eotaxin3','Ecig')
male_Fractalkine_Ecig = get_sex_subset(data_df, 'M','Fractalkine','Ecig')
male_I309_Ecig = get_sex_subset(data_df, 'M','I309','Ecig')
male_IFNg_Ecig = get_sex_subset(data_df, 'M','IFNg','Ecig')
male_IL10_Ecig = get_sex_subset(data_df, 'M','IL10','Ecig')
male_IL12p70_Ecig = get_sex_subset(data_df, 'M','IL12p70','Ecig')
male_IL13_Ecig = get_sex_subset(data_df, 'M','IL13','Ecig')
male_IL17B_Ecig = get_sex_subset(data_df, 'M','IL17B','Ecig')
male_IL17D_Ecig = get_sex_subset(data_df, 'M','IL17D','Ecig')
male_IL1b_Ecig = get_sex_subset(data_df, 'M','IL1b','Ecig')
male_IL4_Ecig = get_sex_subset(data_df, 'M','IL4','Ecig')
male_IL6_Ecig = get_sex_subset(data_df, 'M','IL6','Ecig')
male_IL8_Ecig = get_sex_subset(data_df, 'M','IL8','Ecig')
male_IP10_Ecig = get_sex_subset(data_df, 'M','IP10','Ecig')
male_ITAC_Ecig = get_sex_subset(data_df, 'M','ITAC','Ecig')
male_MCP1_Ecig = get_sex_subset(data_df, 'M','MCP1','Ecig')
male_MIG_Ecig = get_sex_subset(data_df, 'M','MIG','Ecig')
male_MIP1a_Ecig = get_sex_subset(data_df, 'M','MIP1a','Ecig')
male_MIP1b_Ecig = get_sex_subset(data_df, 'M','MIP1b','Ecig')
male_TARC_Ecig = get_sex_subset(data_df, 'M','TARC','Ecig')
male_TNFa_Ecig = get_sex_subset(data_df, 'M','TNFa','Ecig')
male_Eotaxin_NS = get_sex_subset(data_df, 'M','Eotaxin','NS')
male_Eotaxin3_NS = get_sex_subset(data_df, 'M','Eotaxin3','NS')
male_Fractalkine_NS = get_sex_subset(data_df, 'M','Fractalkine','NS')
male_I309_NS = get_sex_subset(data_df, 'M','I309','NS')
male_IFNg_NS = get_sex_subset(data_df, 'M','IFNg','NS')
male_IL10_NS = get_sex_subset(data_df, 'M','IL10','NS')
male_IL12p70_NS = get_sex_subset(data_df, 'M','IL12p70','NS')
male_IL13_NS = get_sex_subset(data_df, 'M','IL13','NS')
male_IL17B_NS = get_sex_subset(data_df, 'M','IL17B','NS')
male_IL17D_NS = get_sex_subset(data_df, 'M','IL17D','NS')
male_IL1b_NS = get_sex_subset(data_df, 'M','IL1b','NS')
male_IL4_NS = get_sex_subset(data_df, 'M','IL4','NS')
male_IL6_NS = get_sex_subset(data_df, 'M','IL6','NS')
male_IL8_NS = get_sex_subset(data_df, 'M','IL8','NS')
male_IP10_NS = get_sex_subset(data_df, 'M','IP10','NS')
male_ITAC_NS = get_sex_subset(data_df, 'M','ITAC','NS')
male_MCP1_NS = get_sex_subset(data_df, 'M','MCP1','NS')
male_MIG_NS = get_sex_subset(data_df, 'M','MIG','NS')
male_MIP1a_NS = get_sex_subset(data_df, 'M','MIP1a','NS')
male_MIP1b_NS = get_sex_subset(data_df, 'M','MIP1b','NS')
male_TARC_NS = get_sex_subset(data_df, 'M','TARC','NS')
male_TNFa_NS = get_sex_subset(data_df, 'M','TNFa','NS')

#female subjects
female_Eotaxin_CS = get_sex_subset(data_df, 'F','Eotaxin','CS')
female_Eotaxin3_CS = get_sex_subset(data_df, 'F','Eotaxin3','CS')
female_Fractalkine_CS = get_sex_subset(data_df, 'F','Fractalkine','CS')
female_I309_CS = get_sex_subset(data_df, 'F','I309','CS')
female_IFNg_CS = get_sex_subset(data_df, 'F','IFNg','CS')
female_IL10_CS = get_sex_subset(data_df, 'F','IL10','CS')
female_IL12p70_CS = get_sex_subset(data_df, 'F','IL12p70','CS')
female_IL13_CS = get_sex_subset(data_df, 'F','IL13','CS')
female_IL17B_CS = get_sex_subset(data_df, 'F','IL17B','CS')
female_IL17D_CS = get_sex_subset(data_df, 'F','IL17D','CS')
female_IL1b_CS = get_sex_subset(data_df, 'F','IL1b','CS')
female_IL4_CS = get_sex_subset(data_df, 'F','IL4','CS')
female_IL6_CS = get_sex_subset(data_df, 'F','IL6','CS')
female_IL8_CS = get_sex_subset(data_df, 'F','IL8','CS')
female_IP10_CS = get_sex_subset(data_df, 'F','IP10','CS')
female_ITAC_CS = get_sex_subset(data_df, 'F','ITAC','CS')
female_MCP1_CS = get_sex_subset(data_df, 'F','MCP1','CS')
female_MIG_CS = get_sex_subset(data_df, 'F','MIG','CS')
female_MIP1a_CS = get_sex_subset(data_df, 'F','MIP1a','CS')
female_MIP1b_CS = get_sex_subset(data_df, 'F','MIP1b','CS')
female_TARC_CS = get_sex_subset(data_df, 'F','TARC','CS')
female_TNFa_CS = get_sex_subset(data_df, 'F','TNFa','CS')
female_Eotaxin_Ecig = get_sex_subset(data_df, 'F','Eotaxin','Ecig')
female_Eotaxin3_Ecig = get_sex_subset(data_df, 'F','Eotaxin3','Ecig')
female_Fractalkine_Ecig = get_sex_subset(data_df, 'F','Fractalkine','Ecig')
female_I309_Ecig = get_sex_subset(data_df, 'F','I309','Ecig')
female_IFNg_Ecig = get_sex_subset(data_df, 'F','IFNg','Ecig')
female_IL10_Ecig = get_sex_subset(data_df, 'F','IL10','Ecig')
female_IL12p70_Ecig = get_sex_subset(data_df, 'F','IL12p70','Ecig')
female_IL13_Ecig = get_sex_subset(data_df, 'F','IL13','Ecig')
female_IL17B_Ecig = get_sex_subset(data_df, 'F','IL17B','Ecig')
female_IL17D_Ecig = get_sex_subset(data_df, 'F','IL17D','Ecig')
female_IL1b_Ecig = get_sex_subset(data_df, 'F','IL1b','Ecig')
female_IL4_Ecig = get_sex_subset(data_df, 'F','IL4','Ecig')
female_IL6_Ecig = get_sex_subset(data_df, 'F','IL6','Ecig')
female_IL8_Ecig = get_sex_subset(data_df, 'F','IL8','Ecig')
female_IP10_Ecig = get_sex_subset(data_df, 'F','IP10','Ecig')
female_ITAC_Ecig = get_sex_subset(data_df, 'F','ITAC','Ecig')
female_MCP1_Ecig = get_sex_subset(data_df, 'F','MCP1','Ecig')
female_MIG_Ecig = get_sex_subset(data_df, 'F','MIG','Ecig')
female_MIP1a_Ecig = get_sex_subset(data_df, 'F','MIP1a','Ecig')
female_MIP1b_Ecig = get_sex_subset(data_df, 'F','MIP1b','Ecig')
female_TARC_Ecig = get_sex_subset(data_df, 'F','TARC','Ecig')
female_TNFa_Ecig = get_sex_subset(data_df, 'F','TNFa','Ecig')
female_Eotaxin_NS = get_sex_subset(data_df, 'F','Eotaxin','NS')
female_Eotaxin3_NS = get_sex_subset(data_df, 'F','Eotaxin3','NS')
female_Fractalkine_NS = get_sex_subset(data_df, 'F','Fractalkine','NS')
female_I309_NS = get_sex_subset(data_df, 'F','I309','NS')
female_IFNg_NS = get_sex_subset(data_df, 'F','IFNg','NS')
female_IL10_NS = get_sex_subset(data_df, 'F','IL10','NS')
female_IL12p70_NS = get_sex_subset(data_df, 'F','IL12p70','NS')
female_IL13_NS = get_sex_subset(data_df, 'F','IL13','NS')
female_IL17B_NS = get_sex_subset(data_df, 'F','IL17B','NS')
female_IL17D_NS = get_sex_subset(data_df, 'F','IL17D','NS')
female_IL1b_NS = get_sex_subset(data_df, 'F','IL1b','NS')
female_IL4_NS = get_sex_subset(data_df, 'F','IL4','NS')
female_IL6_NS = get_sex_subset(data_df, 'F','IL6','NS')
female_IL8_NS = get_sex_subset(data_df, 'F','IL8','NS')
female_IP10_NS = get_sex_subset(data_df, 'F','IP10','NS')
female_ITAC_NS = get_sex_subset(data_df, 'F','ITAC','NS')
female_MCP1_NS = get_sex_subset(data_df, 'F','MCP1','NS')
female_MIG_NS = get_sex_subset(data_df, 'F','MIG','NS')
female_MIP1a_NS = get_sex_subset(data_df, 'F','MIP1a','NS')
female_MIP1b_NS = get_sex_subset(data_df, 'F','MIP1b','NS')
female_TARC_NS = get_sex_subset(data_df, 'F','TARC','NS')
female_TNFa_NS = get_sex_subset(data_df, 'F','TNFa','NS')

# %%
#male CS vs. NS
Eotaxin_male_CS = wilcox.test(male_Eotaxin_CS$Conc_pslog2, male_Eotaxin_NS$Conc_pslog2)
Eotaxin3_male_CS = wilcox.test(male_Eotaxin3_CS$Conc_pslog2, male_Eotaxin3_NS$Conc_pslog2)
Fractalkine_male_CS = wilcox.test(male_Fractalkine_CS$Conc_pslog2, male_Fractalkine_NS$Conc_pslog2)
I309_male_CS = wilcox.test(male_I309_CS$Conc_pslog2, male_I309_NS$Conc_pslog2)
IFNg_male_CS = wilcox.test(male_IFNg_CS$Conc_pslog2, male_IFNg_NS$Conc_pslog2)
IL10_male_CS = wilcox.test(male_IL10_CS$Conc_pslog2, male_IL10_NS$Conc_pslog2)
IL12p70_male_CS = wilcox.test(male_IL12p70_CS$Conc_pslog2, male_IL12p70_NS$Conc_pslog2)
IL13_male_CS = wilcox.test(male_IL13_CS$Conc_pslog2, male_IL13_NS$Conc_pslog2)
IL17B_male_CS = wilcox.test(male_IL17B_CS$Conc_pslog2, male_IL17B_NS$Conc_pslog2)
IL17D_male_CS = wilcox.test(male_IL17D_CS$Conc_pslog2, male_IL17D_NS$Conc_pslog2)
IL1b_male_CS = wilcox.test(male_IL1b_CS$Conc_pslog2, male_IL1b_NS$Conc_pslog2)
IL4_male_CS = wilcox.test(male_IL4_CS$Conc_pslog2, male_IL4_NS$Conc_pslog2)
IL6_male_CS = wilcox.test(male_IL6_CS$Conc_pslog2, male_IL6_NS$Conc_pslog2)
IL8_male_CS = wilcox.test(male_IL8_CS$Conc_pslog2, male_IL8_NS$Conc_pslog2)
IP10_male_CS = wilcox.test(male_IP10_CS$Conc_pslog2, male_IP10_NS$Conc_pslog2)
ITAC_male_CS = wilcox.test(male_ITAC_CS$Conc_pslog2, male_ITAC_NS$Conc_pslog2)
MCP1_male_CS = wilcox.test(male_MCP1_CS$Conc_pslog2, male_MCP1_NS$Conc_pslog2)
MIG_male_CS = wilcox.test(male_MIG_CS$Conc_pslog2, male_MIG_NS$Conc_pslog2)
MIP1a_male_CS = wilcox.test(male_MIP1a_CS$Conc_pslog2, male_MIP1a_NS$Conc_pslog2)
MIP1b_male_CS = wilcox.test(male_MIP1b_CS$Conc_pslog2, male_MIP1b_NS$Conc_pslog2)
TARC_male_CS = wilcox.test(male_TARC_CS$Conc_pslog2, male_TARC_NS$Conc_pslog2)
TNFa_male_CS = wilcox.test(male_TNFa_CS$Conc_pslog2, male_TNFa_NS$Conc_pslog2)

#male Ecig vs. NS
Eotaxin_male_Ecig = wilcox.test(male_Eotaxin_Ecig$Conc_pslog2, male_Eotaxin_NS$Conc_pslog2)
Eotaxin3_male_Ecig = wilcox.test(male_Eotaxin3_Ecig$Conc_pslog2, male_Eotaxin3_NS$Conc_pslog2)
Fractalkine_male_Ecig = wilcox.test(male_Fractalkine_Ecig$Conc_pslog2, male_Fractalkine_NS$Conc_pslog2)
I309_male_Ecig = wilcox.test(male_I309_Ecig$Conc_pslog2, male_I309_NS$Conc_pslog2)
IFNg_male_Ecig = wilcox.test(male_IFNg_Ecig$Conc_pslog2, male_IFNg_NS$Conc_pslog2)
IL10_male_Ecig = wilcox.test(male_IL10_Ecig$Conc_pslog2, male_IL10_NS$Conc_pslog2)
IL12p70_male_Ecig = wilcox.test(male_IL12p70_Ecig$Conc_pslog2, male_IL12p70_NS$Conc_pslog2)
IL13_male_Ecig = wilcox.test(male_IL13_Ecig$Conc_pslog2, male_IL13_NS$Conc_pslog2)
IL17B_male_Ecig = wilcox.test(male_IL17B_Ecig$Conc_pslog2, male_IL17B_NS$Conc_pslog2)
IL17D_male_Ecig = wilcox.test(male_IL17D_Ecig$Conc_pslog2, male_IL17D_NS$Conc_pslog2)
IL1b_male_Ecig = wilcox.test(male_IL1b_Ecig$Conc_pslog2, male_IL1b_NS$Conc_pslog2)
IL4_male_Ecig = wilcox.test(male_IL4_Ecig$Conc_pslog2, male_IL4_NS$Conc_pslog2)
IL6_male_Ecig = wilcox.test(male_IL6_Ecig$Conc_pslog2, male_IL6_NS$Conc_pslog2)
IL8_male_Ecig = wilcox.test(male_IL8_Ecig$Conc_pslog2, male_IL8_NS$Conc_pslog2)
IP10_male_Ecig = wilcox.test(male_IP10_Ecig$Conc_pslog2, male_IP10_NS$Conc_pslog2)
ITAC_male_Ecig = wilcox.test(male_ITAC_Ecig$Conc_pslog2, male_ITAC_NS$Conc_pslog2)
MCP1_male_Ecig = wilcox.test(male_MCP1_Ecig$Conc_pslog2, male_MCP1_NS$Conc_pslog2)
MIG_male_Ecig = wilcox.test(male_MIG_Ecig$Conc_pslog2, male_MIG_NS$Conc_pslog2)
MIP1a_male_Ecig = wilcox.test(male_MIP1a_Ecig$Conc_pslog2, male_MIP1a_NS$Conc_pslog2)
MIP1b_male_Ecig = wilcox.test(male_MIP1b_Ecig$Conc_pslog2, male_MIP1b_NS$Conc_pslog2)
TARC_male_Ecig = wilcox.test(male_TARC_Ecig$Conc_pslog2, male_TARC_NS$Conc_pslog2)
TNFa_male_Ecig = wilcox.test(male_TNFa_Ecig$Conc_pslog2, male_TNFa_NS$Conc_pslog2)

#female CS vs. NS
Eotaxin_female_CS = wilcox.test(female_Eotaxin_CS$Conc_pslog2, female_Eotaxin_NS$Conc_pslog2)
Eotaxin3_female_CS = wilcox.test(female_Eotaxin3_CS$Conc_pslog2, female_Eotaxin3_NS$Conc_pslog2)
Fractalkine_female_CS = wilcox.test(female_Fractalkine_CS$Conc_pslog2, female_Fractalkine_NS$Conc_pslog2)
I309_female_CS = wilcox.test(female_I309_CS$Conc_pslog2, female_I309_NS$Conc_pslog2)
IFNg_female_CS = wilcox.test(female_IFNg_CS$Conc_pslog2, female_IFNg_NS$Conc_pslog2)
IL10_female_CS = wilcox.test(female_IL10_CS$Conc_pslog2, female_IL10_NS$Conc_pslog2)
IL12p70_female_CS = wilcox.test(female_IL12p70_CS$Conc_pslog2, female_IL12p70_NS$Conc_pslog2)
IL13_female_CS = wilcox.test(female_IL13_CS$Conc_pslog2, female_IL13_NS$Conc_pslog2)
IL17B_female_CS = wilcox.test(female_IL17B_CS$Conc_pslog2, female_IL17B_NS$Conc_pslog2)
IL17D_female_CS = wilcox.test(female_IL17D_CS$Conc_pslog2, female_IL17D_NS$Conc_pslog2)
IL1b_female_CS = wilcox.test(female_IL1b_CS$Conc_pslog2, female_IL1b_NS$Conc_pslog2)
IL4_female_CS = wilcox.test(female_IL4_CS$Conc_pslog2, female_IL4_NS$Conc_pslog2)
IL6_female_CS = wilcox.test(female_IL6_CS$Conc_pslog2, female_IL6_NS$Conc_pslog2)
IL8_female_CS = wilcox.test(female_IL8_CS$Conc_pslog2, female_IL8_NS$Conc_pslog2)
IP10_female_CS = wilcox.test(female_IP10_CS$Conc_pslog2, female_IP10_NS$Conc_pslog2)
ITAC_female_CS = wilcox.test(female_ITAC_CS$Conc_pslog2, female_ITAC_NS$Conc_pslog2)
MCP1_female_CS = wilcox.test(female_MCP1_CS$Conc_pslog2, female_MCP1_NS$Conc_pslog2)
MIG_female_CS = wilcox.test(female_MIG_CS$Conc_pslog2, female_MIG_NS$Conc_pslog2)
MIP1a_female_CS = wilcox.test(female_MIP1a_CS$Conc_pslog2, female_MIP1a_NS$Conc_pslog2)
MIP1b_female_CS = wilcox.test(female_MIP1b_CS$Conc_pslog2, female_MIP1b_NS$Conc_pslog2)
TARC_female_CS = wilcox.test(female_TARC_CS$Conc_pslog2, female_TARC_NS$Conc_pslog2)
TNFa_female_CS = wilcox.test(female_TNFa_CS$Conc_pslog2, female_TNFa_NS$Conc_pslog2)

#female Ecig vs. NS
Eotaxin_female_Ecig = wilcox.test(female_Eotaxin_Ecig$Conc_pslog2, female_Eotaxin_NS$Conc_pslog2)
Eotaxin3_female_Ecig = wilcox.test(female_Eotaxin3_Ecig$Conc_pslog2, female_Eotaxin3_NS$Conc_pslog2)
Fractalkine_female_Ecig = wilcox.test(female_Fractalkine_Ecig$Conc_pslog2, female_Fractalkine_NS$Conc_pslog2)
I309_female_Ecig = wilcox.test(female_I309_Ecig$Conc_pslog2, female_I309_NS$Conc_pslog2)
IFNg_female_Ecig = wilcox.test(female_IFNg_Ecig$Conc_pslog2, female_IFNg_NS$Conc_pslog2)
IL10_female_Ecig = wilcox.test(female_IL10_Ecig$Conc_pslog2, female_IL10_NS$Conc_pslog2)
IL12p70_female_Ecig = wilcox.test(female_IL12p70_Ecig$Conc_pslog2, female_IL12p70_NS$Conc_pslog2)
IL13_female_Ecig = wilcox.test(female_IL13_Ecig$Conc_pslog2, female_IL13_NS$Conc_pslog2)
IL17B_female_Ecig = wilcox.test(female_IL17B_Ecig$Conc_pslog2, female_IL17B_NS$Conc_pslog2)
IL17D_female_Ecig = wilcox.test(female_IL17D_Ecig$Conc_pslog2, female_IL17D_NS$Conc_pslog2)
IL1b_female_Ecig = wilcox.test(female_IL1b_Ecig$Conc_pslog2, female_IL1b_NS$Conc_pslog2)
IL4_female_Ecig = wilcox.test(female_IL4_Ecig$Conc_pslog2, female_IL4_NS$Conc_pslog2)
IL6_female_Ecig = wilcox.test(female_IL6_Ecig$Conc_pslog2, female_IL6_NS$Conc_pslog2)
IL8_female_Ecig = wilcox.test(female_IL8_Ecig$Conc_pslog2, female_IL8_NS$Conc_pslog2)
IP10_female_Ecig = wilcox.test(female_IP10_Ecig$Conc_pslog2, female_IP10_NS$Conc_pslog2)
ITAC_female_Ecig = wilcox.test(female_ITAC_Ecig$Conc_pslog2, female_ITAC_NS$Conc_pslog2)
MCP1_female_Ecig = wilcox.test(female_MCP1_Ecig$Conc_pslog2, female_MCP1_NS$Conc_pslog2)
MIG_female_Ecig = wilcox.test(female_MIG_Ecig$Conc_pslog2, female_MIG_NS$Conc_pslog2)
MIP1a_female_Ecig = wilcox.test(female_MIP1a_Ecig$Conc_pslog2, female_MIP1a_NS$Conc_pslog2)
MIP1b_female_Ecig = wilcox.test(female_MIP1b_Ecig$Conc_pslog2, female_MIP1b_NS$Conc_pslog2)
TARC_female_Ecig = wilcox.test(female_TARC_Ecig$Conc_pslog2, female_TARC_NS$Conc_pslog2)
TNFa_female_Ecig = wilcox.test(female_TNFa_Ecig$Conc_pslog2, female_TNFa_NS$Conc_pslog2)
# Out:
# Warning message in wilcox.test.default(male_Eotaxin_CS$Conc_pslog2, male_Eotaxin_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(male_Eotaxin3_CS$Conc_pslog2, male_Eotaxin3_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(male_I309_CS$Conc_pslog2, male_I309_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(male_IFNg_CS$Conc_pslog2, male_IFNg_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(male_IL10_CS$Conc_pslog2, male_IL10_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(male_IL12p70_CS$Conc_pslog2, male_IL12p70_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(male_IL13_CS$Conc_pslog2, male_IL13_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# ...

# %%
#male CS vs. NS
Eotaxin_male_CS_tuple = get_stat_pvalue_tuple(Eotaxin_male_CS)
Eotaxin3_male_CS_tuple = get_stat_pvalue_tuple(Eotaxin3_male_CS)
Fractalkine_male_CS_tuple = get_stat_pvalue_tuple(Fractalkine_male_CS)
I309_male_CS_tuple = get_stat_pvalue_tuple(I309_male_CS)
IFNg_male_CS_tuple = get_stat_pvalue_tuple(IFNg_male_CS)
IL10_male_CS_tuple = get_stat_pvalue_tuple(IL10_male_CS)
IL12p70_male_CS_tuple = get_stat_pvalue_tuple(IL12p70_male_CS)
IL13_male_CS_tuple = get_stat_pvalue_tuple(IL13_male_CS)
IL17B_male_CS_tuple = get_stat_pvalue_tuple(IL17B_male_CS)
IL17D_male_CS_tuple = get_stat_pvalue_tuple(IL17D_male_CS)
IL1b_male_CS_tuple = get_stat_pvalue_tuple(IL1b_male_CS)
IL4_male_CS_tuple = get_stat_pvalue_tuple(IL4_male_CS)
IL6_male_CS_tuple = get_stat_pvalue_tuple(IL6_male_CS)
IL8_male_CS_tuple = get_stat_pvalue_tuple(IL8_male_CS)
IP10_male_CS_tuple = get_stat_pvalue_tuple(IP10_male_CS)
ITAC_male_CS_tuple = get_stat_pvalue_tuple(ITAC_male_CS)
MCP1_male_CS_tuple = get_stat_pvalue_tuple(MCP1_male_CS)
MIG_male_CS_tuple = get_stat_pvalue_tuple(MIG_male_CS)
MIP1a_male_CS_tuple = get_stat_pvalue_tuple(MIP1a_male_CS)
MIP1b_male_CS_tuple = get_stat_pvalue_tuple(MIP1b_male_CS)
TARC_male_CS_tuple = get_stat_pvalue_tuple(TARC_male_CS)
TNFa_male_CS_tuple = get_stat_pvalue_tuple(TNFa_male_CS)

#male Ecig vs. NS
Eotaxin_male_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin_male_Ecig)
Eotaxin3_male_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin3_male_Ecig)
Fractalkine_male_Ecig_tuple = get_stat_pvalue_tuple(Fractalkine_male_Ecig)
I309_male_Ecig_tuple = get_stat_pvalue_tuple(I309_male_Ecig)
IFNg_male_Ecig_tuple = get_stat_pvalue_tuple(IFNg_male_Ecig)
IL10_male_Ecig_tuple = get_stat_pvalue_tuple(IL10_male_Ecig)
IL12p70_male_Ecig_tuple = get_stat_pvalue_tuple(IL12p70_male_Ecig)
IL13_male_Ecig_tuple = get_stat_pvalue_tuple(IL13_male_Ecig)
IL17B_male_Ecig_tuple = get_stat_pvalue_tuple(IL17B_male_Ecig)
IL17D_male_Ecig_tuple = get_stat_pvalue_tuple(IL17D_male_Ecig)
IL1b_male_Ecig_tuple = get_stat_pvalue_tuple(IL1b_male_Ecig)
IL4_male_Ecig_tuple = get_stat_pvalue_tuple(IL4_male_Ecig)
IL6_male_Ecig_tuple = get_stat_pvalue_tuple(IL6_male_Ecig)
IL8_male_Ecig_tuple = get_stat_pvalue_tuple(IL8_male_Ecig)
IP10_male_Ecig_tuple = get_stat_pvalue_tuple(IP10_male_Ecig)
ITAC_male_Ecig_tuple = get_stat_pvalue_tuple(ITAC_male_Ecig)
MCP1_male_Ecig_tuple = get_stat_pvalue_tuple(MCP1_male_Ecig)
MIG_male_Ecig_tuple = get_stat_pvalue_tuple(MIG_male_Ecig)
MIP1a_male_Ecig_tuple = get_stat_pvalue_tuple(MIP1a_male_Ecig)
MIP1b_male_Ecig_tuple = get_stat_pvalue_tuple(MIP1b_male_Ecig)
TARC_male_Ecig_tuple = get_stat_pvalue_tuple(TARC_male_Ecig)
TNFa_male_Ecig_tuple = get_stat_pvalue_tuple(TNFa_male_Ecig)

#female CS vs. NS
Eotaxin_female_CS_tuple = get_stat_pvalue_tuple(Eotaxin_female_CS)
Eotaxin3_female_CS_tuple = get_stat_pvalue_tuple(Eotaxin3_female_CS)
Fractalkine_female_CS_tuple = get_stat_pvalue_tuple(Fractalkine_female_CS)
I309_female_CS_tuple = get_stat_pvalue_tuple(I309_female_CS)
IFNg_female_CS_tuple = get_stat_pvalue_tuple(IFNg_female_CS)
IL10_female_CS_tuple = get_stat_pvalue_tuple(IL10_female_CS)
IL12p70_female_CS_tuple = get_stat_pvalue_tuple(IL12p70_female_CS)
IL13_female_CS_tuple = get_stat_pvalue_tuple(IL13_female_CS)
IL17B_female_CS_tuple = get_stat_pvalue_tuple(IL17B_female_CS)
IL17D_female_CS_tuple = get_stat_pvalue_tuple(IL17D_female_CS)
IL1b_female_CS_tuple = get_stat_pvalue_tuple(IL1b_female_CS)
IL4_female_CS_tuple = get_stat_pvalue_tuple(IL4_female_CS)
IL6_female_CS_tuple = get_stat_pvalue_tuple(IL6_female_CS)
IL8_female_CS_tuple = get_stat_pvalue_tuple(IL8_female_CS)
IP10_female_CS_tuple = get_stat_pvalue_tuple(IP10_female_CS)
ITAC_female_CS_tuple = get_stat_pvalue_tuple(ITAC_female_CS)
MCP1_female_CS_tuple = get_stat_pvalue_tuple(MCP1_female_CS)
MIG_female_CS_tuple = get_stat_pvalue_tuple(MIG_female_CS)
MIP1a_female_CS_tuple = get_stat_pvalue_tuple(MIP1a_female_CS)
MIP1b_female_CS_tuple = get_stat_pvalue_tuple(MIP1b_female_CS)
TARC_female_CS_tuple = get_stat_pvalue_tuple(TARC_female_CS)
TNFa_female_CS_tuple = get_stat_pvalue_tuple(TNFa_female_CS)

#female Ecig vs. NS
Eotaxin_female_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin_female_Ecig)
Eotaxin3_female_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin3_female_Ecig)
Fractalkine_female_Ecig_tuple = get_stat_pvalue_tuple(Fractalkine_female_Ecig)
I309_female_Ecig_tuple = get_stat_pvalue_tuple(I309_female_Ecig)
IFNg_female_Ecig_tuple = get_stat_pvalue_tuple(IFNg_female_Ecig)
IL10_female_Ecig_tuple = get_stat_pvalue_tuple(IL10_female_Ecig)
IL12p70_female_Ecig_tuple = get_stat_pvalue_tuple(IL12p70_female_Ecig)
IL13_female_Ecig_tuple = get_stat_pvalue_tuple(IL13_female_Ecig)
IL17B_female_Ecig_tuple = get_stat_pvalue_tuple(IL17B_female_Ecig)
IL17D_female_Ecig_tuple = get_stat_pvalue_tuple(IL17D_female_Ecig)
IL1b_female_Ecig_tuple = get_stat_pvalue_tuple(IL1b_female_Ecig)
IL4_female_Ecig_tuple = get_stat_pvalue_tuple(IL4_female_Ecig)
IL6_female_Ecig_tuple = get_stat_pvalue_tuple(IL6_female_Ecig)
IL8_female_Ecig_tuple = get_stat_pvalue_tuple(IL8_female_Ecig)
IP10_female_Ecig_tuple = get_stat_pvalue_tuple(IP10_female_Ecig)
ITAC_female_Ecig_tuple = get_stat_pvalue_tuple(ITAC_female_Ecig)
MCP1_female_Ecig_tuple = get_stat_pvalue_tuple(MCP1_female_Ecig)
MIG_female_Ecig_tuple = get_stat_pvalue_tuple(MIG_female_Ecig)
MIP1a_female_Ecig_tuple = get_stat_pvalue_tuple(MIP1a_female_Ecig)
MIP1b_female_Ecig_tuple = get_stat_pvalue_tuple(MIP1b_female_Ecig)
TARC_female_Ecig_tuple = get_stat_pvalue_tuple(TARC_female_Ecig)
TNFa_female_Ecig_tuple = get_stat_pvalue_tuple(TNFa_female_Ecig)

# %% [markdown]
# # Age

# %%
get_age_subset = function(dataframe, age, protein, smoking_status){
    #"""
    # Getting concentrations for subjects based on age for each cytokine based on smoking status (ciagratte or 
    # e-cig user).
    
    #:param: subsetted data frame, age specification, cytokine, smoking status 
    #:output: a 24x13 matrix containing concentrations for each cytokine

    #"""
    subsetted_df = subset(dataframe, dataframe$Age == age & dataframe$Protein == protein & dataframe$Group == smoking_status)
}

#under30 subjects
under30_Eotaxin_CS = get_age_subset(data_df, 'U','Eotaxin','CS')
under30_Eotaxin3_CS = get_age_subset(data_df, 'U','Eotaxin3','CS')
under30_Fractalkine_CS = get_age_subset(data_df, 'U','Fractalkine','CS')
under30_I309_CS = get_age_subset(data_df, 'U','I309','CS')
under30_IFNg_CS = get_age_subset(data_df, 'U','IFNg','CS')
under30_IL10_CS = get_age_subset(data_df, 'U','IL10','CS')
under30_IL12p70_CS = get_age_subset(data_df, 'U','IL12p70','CS')
under30_IL13_CS = get_age_subset(data_df, 'U','IL13','CS')
under30_IL17B_CS = get_age_subset(data_df, 'U','IL17B','CS')
under30_IL17D_CS = get_age_subset(data_df, 'U','IL17D','CS')
under30_IL1b_CS = get_age_subset(data_df, 'U','IL1b','CS')
under30_IL4_CS = get_age_subset(data_df, 'U','IL4','CS')
under30_IL6_CS = get_age_subset(data_df, 'U','IL6','CS')
under30_IL8_CS = get_age_subset(data_df, 'U','IL8','CS')
under30_IP10_CS = get_age_subset(data_df, 'U','IP10','CS')
under30_ITAC_CS = get_age_subset(data_df, 'U','ITAC','CS')
under30_MCP1_CS = get_age_subset(data_df, 'U','MCP1','CS')
under30_MIG_CS = get_age_subset(data_df, 'U','MIG','CS')
under30_MIP1a_CS = get_age_subset(data_df, 'U','MIP1a','CS')
under30_MIP1b_CS = get_age_subset(data_df, 'U','MIP1b','CS')
under30_TARC_CS = get_age_subset(data_df, 'U','TARC','CS')
under30_TNFa_CS = get_age_subset(data_df, 'U','TNFa','CS')
under30_Eotaxin_Ecig = get_age_subset(data_df, 'U','Eotaxin','Ecig')
under30_Eotaxin3_Ecig = get_age_subset(data_df, 'U','Eotaxin3','Ecig')
under30_Fractalkine_Ecig = get_age_subset(data_df, 'U','Fractalkine','Ecig')
under30_I309_Ecig = get_age_subset(data_df, 'U','I309','Ecig')
under30_IFNg_Ecig = get_age_subset(data_df, 'U','IFNg','Ecig')
under30_IL10_Ecig = get_age_subset(data_df, 'U','IL10','Ecig')
under30_IL12p70_Ecig = get_age_subset(data_df, 'U','IL12p70','Ecig')
under30_IL13_Ecig = get_age_subset(data_df, 'U','IL13','Ecig')
under30_IL17B_Ecig = get_age_subset(data_df, 'U','IL17B','Ecig')
under30_IL17D_Ecig = get_age_subset(data_df, 'U','IL17D','Ecig')
under30_IL1b_Ecig = get_age_subset(data_df, 'U','IL1b','Ecig')
under30_IL4_Ecig = get_age_subset(data_df, 'U','IL4','Ecig')
under30_IL6_Ecig = get_age_subset(data_df, 'U','IL6','Ecig')
under30_IL8_Ecig = get_age_subset(data_df, 'U','IL8','Ecig')
under30_IP10_Ecig = get_age_subset(data_df, 'U','IP10','Ecig')
under30_ITAC_Ecig = get_age_subset(data_df, 'U','ITAC','Ecig')
under30_MCP1_Ecig = get_age_subset(data_df, 'U','MCP1','Ecig')
under30_MIG_Ecig = get_age_subset(data_df, 'U','MIG','Ecig')
under30_MIP1a_Ecig = get_age_subset(data_df, 'U','MIP1a','Ecig')
under30_MIP1b_Ecig = get_age_subset(data_df, 'U','MIP1b','Ecig')
under30_TARC_Ecig = get_age_subset(data_df, 'U','TARC','Ecig')
under30_TNFa_Ecig = get_age_subset(data_df, 'U','TNFa','Ecig')
under30_Eotaxin_NS = get_age_subset(data_df, 'U','Eotaxin','NS')
under30_Eotaxin3_NS = get_age_subset(data_df, 'U','Eotaxin3','NS')
under30_Fractalkine_NS = get_age_subset(data_df, 'U','Fractalkine','NS')
under30_I309_NS = get_age_subset(data_df, 'U','I309','NS')
under30_IFNg_NS = get_age_subset(data_df, 'U','IFNg','NS')
under30_IL10_NS = get_age_subset(data_df, 'U','IL10','NS')
under30_IL12p70_NS = get_age_subset(data_df, 'U','IL12p70','NS')
under30_IL13_NS = get_age_subset(data_df, 'U','IL13','NS')
under30_IL17B_NS = get_age_subset(data_df, 'U','IL17B','NS')
under30_IL17D_NS = get_age_subset(data_df, 'U','IL17D','NS')
under30_IL1b_NS = get_age_subset(data_df, 'U','IL1b','NS')
under30_IL4_NS = get_age_subset(data_df, 'U','IL4','NS')
under30_IL6_NS = get_age_subset(data_df, 'U','IL6','NS')
under30_IL8_NS = get_age_subset(data_df, 'U','IL8','NS')
under30_IP10_NS = get_age_subset(data_df, 'U','IP10','NS')
under30_ITAC_NS = get_age_subset(data_df, 'U','ITAC','NS')
under30_MCP1_NS = get_age_subset(data_df, 'U','MCP1','NS')
under30_MIG_NS = get_age_subset(data_df, 'U','MIG','NS')
under30_MIP1a_NS = get_age_subset(data_df, 'U','MIP1a','NS')
under30_MIP1b_NS = get_age_subset(data_df, 'U','MIP1b','NS')
under30_TARC_NS = get_age_subset(data_df, 'U','TARC','NS')
under30_TNFa_NS = get_age_subset(data_df, 'U','TNFa','NS')

#over30 subjects
over30_Eotaxin_CS = get_age_subset(data_df, 'O','Eotaxin','CS')
over30_Eotaxin3_CS = get_age_subset(data_df, 'O','Eotaxin3','CS')
over30_Fractalkine_CS = get_age_subset(data_df, 'O','Fractalkine','CS')
over30_I309_CS = get_age_subset(data_df, 'O','I309','CS')
over30_IFNg_CS = get_age_subset(data_df, 'O','IFNg','CS')
over30_IL10_CS = get_age_subset(data_df, 'O','IL10','CS')
over30_IL12p70_CS = get_age_subset(data_df, 'O','IL12p70','CS')
over30_IL13_CS = get_age_subset(data_df, 'O','IL13','CS')
over30_IL17B_CS = get_age_subset(data_df, 'O','IL17B','CS')
over30_IL17D_CS = get_age_subset(data_df, 'O','IL17D','CS')
over30_IL1b_CS = get_age_subset(data_df, 'O','IL1b','CS')
over30_IL4_CS = get_age_subset(data_df, 'O','IL4','CS')
over30_IL6_CS = get_age_subset(data_df, 'O','IL6','CS')
over30_IL8_CS = get_age_subset(data_df, 'O','IL8','CS')
over30_IP10_CS = get_age_subset(data_df, 'O','IP10','CS')
over30_ITAC_CS = get_age_subset(data_df, 'O','ITAC','CS')
over30_MCP1_CS = get_age_subset(data_df, 'O','MCP1','CS')
over30_MIG_CS = get_age_subset(data_df, 'O','MIG','CS')
over30_MIP1a_CS = get_age_subset(data_df, 'O','MIP1a','CS')
over30_MIP1b_CS = get_age_subset(data_df, 'O','MIP1b','CS')
over30_TARC_CS = get_age_subset(data_df, 'O','TARC','CS')
over30_TNFa_CS = get_age_subset(data_df, 'O','TNFa','CS')
over30_Eotaxin_Ecig = get_age_subset(data_df, 'O','Eotaxin','Ecig')
over30_Eotaxin3_Ecig = get_age_subset(data_df, 'O','Eotaxin3','Ecig')
over30_Fractalkine_Ecig = get_age_subset(data_df, 'O','Fractalkine','Ecig')
over30_I309_Ecig = get_age_subset(data_df, 'O','I309','Ecig')
over30_IFNg_Ecig = get_age_subset(data_df, 'O','IFNg','Ecig')
over30_IL10_Ecig = get_age_subset(data_df, 'O','IL10','Ecig')
over30_IL12p70_Ecig = get_age_subset(data_df, 'O','IL12p70','Ecig')
over30_IL13_Ecig = get_age_subset(data_df, 'O','IL13','Ecig')
over30_IL17B_Ecig = get_age_subset(data_df, 'O','IL17B','Ecig')
over30_IL17D_Ecig = get_age_subset(data_df, 'O','IL17D','Ecig')
over30_IL1b_Ecig = get_age_subset(data_df, 'O','IL1b','Ecig')
over30_IL4_Ecig = get_age_subset(data_df, 'O','IL4','Ecig')
over30_IL6_Ecig = get_age_subset(data_df, 'O','IL6','Ecig')
over30_IL8_Ecig = get_age_subset(data_df, 'O','IL8','Ecig')
over30_IP10_Ecig = get_age_subset(data_df, 'O','IP10','Ecig')
over30_ITAC_Ecig = get_age_subset(data_df, 'O','ITAC','Ecig')
over30_MCP1_Ecig = get_age_subset(data_df, 'O','MCP1','Ecig')
over30_MIG_Ecig = get_age_subset(data_df, 'O','MIG','Ecig')
over30_MIP1a_Ecig = get_age_subset(data_df, 'O','MIP1a','Ecig')
over30_MIP1b_Ecig = get_age_subset(data_df, 'O','MIP1b','Ecig')
over30_TARC_Ecig = get_age_subset(data_df, 'O','TARC','Ecig')
over30_TNFa_Ecig = get_age_subset(data_df, 'O','TNFa','Ecig')
over30_Eotaxin_NS = get_age_subset(data_df, 'O','Eotaxin','NS')
over30_Eotaxin3_NS = get_age_subset(data_df, 'O','Eotaxin3','NS')
over30_Fractalkine_NS = get_age_subset(data_df, 'O','Fractalkine','NS')
over30_I309_NS = get_age_subset(data_df, 'O','I309','NS')
over30_IFNg_NS = get_age_subset(data_df, 'O','IFNg','NS')
over30_IL10_NS = get_age_subset(data_df, 'O','IL10','NS')
over30_IL12p70_NS = get_age_subset(data_df, 'O','IL12p70','NS')
over30_IL13_NS = get_age_subset(data_df, 'O','IL13','NS')
over30_IL17B_NS = get_age_subset(data_df, 'O','IL17B','NS')
over30_IL17D_NS = get_age_subset(data_df, 'O','IL17D','NS')
over30_IL1b_NS = get_age_subset(data_df, 'O','IL1b','NS')
over30_IL4_NS = get_age_subset(data_df, 'O','IL4','NS')
over30_IL6_NS = get_age_subset(data_df, 'O','IL6','NS')
over30_IL8_NS = get_age_subset(data_df, 'O','IL8','NS')
over30_IP10_NS = get_age_subset(data_df, 'O','IP10','NS')
over30_ITAC_NS = get_age_subset(data_df, 'O','ITAC','NS')
over30_MCP1_NS = get_age_subset(data_df, 'O','MCP1','NS')
over30_MIG_NS = get_age_subset(data_df, 'O','MIG','NS')
over30_MIP1a_NS = get_age_subset(data_df, 'O','MIP1a','NS')
over30_MIP1b_NS = get_age_subset(data_df, 'O','MIP1b','NS')
over30_TARC_NS = get_age_subset(data_df, 'O','TARC','NS')
over30_TNFa_NS = get_age_subset(data_df, 'O','TNFa','NS')

# %%
#under30 CS vs. NS
Eotaxin_under30_CS = wilcox.test(under30_Eotaxin_CS$Conc_pslog2, under30_Eotaxin_NS$Conc_pslog2)
Eotaxin3_under30_CS = wilcox.test(under30_Eotaxin3_CS$Conc_pslog2, under30_Eotaxin3_NS$Conc_pslog2)
Fractalkine_under30_CS = wilcox.test(under30_Fractalkine_CS$Conc_pslog2, under30_Fractalkine_NS$Conc_pslog2)
I309_under30_CS = wilcox.test(under30_I309_CS$Conc_pslog2, under30_I309_NS$Conc_pslog2)
IFNg_under30_CS = wilcox.test(under30_IFNg_CS$Conc_pslog2, under30_IFNg_NS$Conc_pslog2)
IL10_under30_CS = wilcox.test(under30_IL10_CS$Conc_pslog2, under30_IL10_NS$Conc_pslog2)
IL12p70_under30_CS = wilcox.test(under30_IL12p70_CS$Conc_pslog2, under30_IL12p70_NS$Conc_pslog2)
IL13_under30_CS = wilcox.test(under30_IL13_CS$Conc_pslog2, under30_IL13_NS$Conc_pslog2)
IL17B_under30_CS = wilcox.test(under30_IL17B_CS$Conc_pslog2, under30_IL17B_NS$Conc_pslog2)
IL17D_under30_CS = wilcox.test(under30_IL17D_CS$Conc_pslog2, under30_IL17D_NS$Conc_pslog2)
IL1b_under30_CS = wilcox.test(under30_IL1b_CS$Conc_pslog2, under30_IL1b_NS$Conc_pslog2)
IL4_under30_CS = wilcox.test(under30_IL4_CS$Conc_pslog2, under30_IL4_NS$Conc_pslog2)
IL6_under30_CS = wilcox.test(under30_IL6_CS$Conc_pslog2, under30_IL6_NS$Conc_pslog2)
IL8_under30_CS = wilcox.test(under30_IL8_CS$Conc_pslog2, under30_IL8_NS$Conc_pslog2)
IP10_under30_CS = wilcox.test(under30_IP10_CS$Conc_pslog2, under30_IP10_NS$Conc_pslog2)
ITAC_under30_CS = wilcox.test(under30_ITAC_CS$Conc_pslog2, under30_ITAC_NS$Conc_pslog2)
MCP1_under30_CS = wilcox.test(under30_MCP1_CS$Conc_pslog2, under30_MCP1_NS$Conc_pslog2)
MIG_under30_CS = wilcox.test(under30_MIG_CS$Conc_pslog2, under30_MIG_NS$Conc_pslog2)
MIP1a_under30_CS = wilcox.test(under30_MIP1a_CS$Conc_pslog2, under30_MIP1a_NS$Conc_pslog2)
MIP1b_under30_CS = wilcox.test(under30_MIP1b_CS$Conc_pslog2, under30_MIP1b_NS$Conc_pslog2)
TARC_under30_CS = wilcox.test(under30_TARC_CS$Conc_pslog2, under30_TARC_NS$Conc_pslog2)
TNFa_under30_CS = wilcox.test(under30_TNFa_CS$Conc_pslog2, under30_TNFa_NS$Conc_pslog2)

#under30 Ecig vs. NS
Eotaxin_under30_Ecig = wilcox.test(under30_Eotaxin_Ecig$Conc_pslog2, under30_Eotaxin_NS$Conc_pslog2)
Eotaxin3_under30_Ecig = wilcox.test(under30_Eotaxin3_Ecig$Conc_pslog2, under30_Eotaxin3_NS$Conc_pslog2)
Fractalkine_under30_Ecig = wilcox.test(under30_Fractalkine_Ecig$Conc_pslog2, under30_Fractalkine_NS$Conc_pslog2)
I309_under30_Ecig = wilcox.test(under30_I309_Ecig$Conc_pslog2, under30_I309_NS$Conc_pslog2)
IFNg_under30_Ecig = wilcox.test(under30_IFNg_Ecig$Conc_pslog2, under30_IFNg_NS$Conc_pslog2)
IL10_under30_Ecig = wilcox.test(under30_IL10_Ecig$Conc_pslog2, under30_IL10_NS$Conc_pslog2)
IL12p70_under30_Ecig = wilcox.test(under30_IL12p70_Ecig$Conc_pslog2, under30_IL12p70_NS$Conc_pslog2)
IL13_under30_Ecig = wilcox.test(under30_IL13_Ecig$Conc_pslog2, under30_IL13_NS$Conc_pslog2)
IL17B_under30_Ecig = wilcox.test(under30_IL17B_Ecig$Conc_pslog2, under30_IL17B_NS$Conc_pslog2)
IL17D_under30_Ecig = wilcox.test(under30_IL17D_Ecig$Conc_pslog2, under30_IL17D_NS$Conc_pslog2)
IL1b_under30_Ecig = wilcox.test(under30_IL1b_Ecig$Conc_pslog2, under30_IL1b_NS$Conc_pslog2)
IL4_under30_Ecig = wilcox.test(under30_IL4_Ecig$Conc_pslog2, under30_IL4_NS$Conc_pslog2)
IL6_under30_Ecig = wilcox.test(under30_IL6_Ecig$Conc_pslog2, under30_IL6_NS$Conc_pslog2)
IL8_under30_Ecig = wilcox.test(under30_IL8_Ecig$Conc_pslog2, under30_IL8_NS$Conc_pslog2)
IP10_under30_Ecig = wilcox.test(under30_IP10_Ecig$Conc_pslog2, under30_IP10_NS$Conc_pslog2)
ITAC_under30_Ecig = wilcox.test(under30_ITAC_Ecig$Conc_pslog2, under30_ITAC_NS$Conc_pslog2)
MCP1_under30_Ecig = wilcox.test(under30_MCP1_Ecig$Conc_pslog2, under30_MCP1_NS$Conc_pslog2)
MIG_under30_Ecig = wilcox.test(under30_MIG_Ecig$Conc_pslog2, under30_MIG_NS$Conc_pslog2)
MIP1a_under30_Ecig = wilcox.test(under30_MIP1a_Ecig$Conc_pslog2, under30_MIP1a_NS$Conc_pslog2)
MIP1b_under30_Ecig = wilcox.test(under30_MIP1b_Ecig$Conc_pslog2, under30_MIP1b_NS$Conc_pslog2)
TARC_under30_Ecig = wilcox.test(under30_TARC_Ecig$Conc_pslog2, under30_TARC_NS$Conc_pslog2)
TNFa_under30_Ecig = wilcox.test(under30_TNFa_Ecig$Conc_pslog2, under30_TNFa_NS$Conc_pslog2)

#over30 CS vs. NS
Eotaxin_over30_CS = wilcox.test(over30_Eotaxin_CS$Conc_pslog2, over30_Eotaxin_NS$Conc_pslog2)
Eotaxin3_over30_CS = wilcox.test(over30_Eotaxin3_CS$Conc_pslog2, over30_Eotaxin3_NS$Conc_pslog2)
Fractalkine_over30_CS = wilcox.test(over30_Fractalkine_CS$Conc_pslog2, over30_Fractalkine_NS$Conc_pslog2)
I309_over30_CS = wilcox.test(over30_I309_CS$Conc_pslog2, over30_I309_NS$Conc_pslog2)
IFNg_over30_CS = wilcox.test(over30_IFNg_CS$Conc_pslog2, over30_IFNg_NS$Conc_pslog2)
IL10_over30_CS = wilcox.test(over30_IL10_CS$Conc_pslog2, over30_IL10_NS$Conc_pslog2)
IL12p70_over30_CS = wilcox.test(over30_IL12p70_CS$Conc_pslog2, over30_IL12p70_NS$Conc_pslog2)
IL13_over30_CS = wilcox.test(over30_IL13_CS$Conc_pslog2, over30_IL13_NS$Conc_pslog2)
IL17B_over30_CS = wilcox.test(over30_IL17B_CS$Conc_pslog2, over30_IL17B_NS$Conc_pslog2)
IL17D_over30_CS = wilcox.test(over30_IL17D_CS$Conc_pslog2, over30_IL17D_NS$Conc_pslog2)
IL1b_over30_CS = wilcox.test(over30_IL1b_CS$Conc_pslog2, over30_IL1b_NS$Conc_pslog2)
IL4_over30_CS = wilcox.test(over30_IL4_CS$Conc_pslog2, over30_IL4_NS$Conc_pslog2)
IL6_over30_CS = wilcox.test(over30_IL6_CS$Conc_pslog2, over30_IL6_NS$Conc_pslog2)
IL8_over30_CS = wilcox.test(over30_IL8_CS$Conc_pslog2, over30_IL8_NS$Conc_pslog2)
IP10_over30_CS = wilcox.test(over30_IP10_CS$Conc_pslog2, over30_IP10_NS$Conc_pslog2)
ITAC_over30_CS = wilcox.test(over30_ITAC_CS$Conc_pslog2, over30_ITAC_NS$Conc_pslog2)
MCP1_over30_CS = wilcox.test(over30_MCP1_CS$Conc_pslog2, over30_MCP1_NS$Conc_pslog2)
MIG_over30_CS = wilcox.test(over30_MIG_CS$Conc_pslog2, over30_MIG_NS$Conc_pslog2)
MIP1a_over30_CS = wilcox.test(over30_MIP1a_CS$Conc_pslog2, over30_MIP1a_NS$Conc_pslog2)
MIP1b_over30_CS = wilcox.test(over30_MIP1b_CS$Conc_pslog2, over30_MIP1b_NS$Conc_pslog2)
TARC_over30_CS = wilcox.test(over30_TARC_CS$Conc_pslog2, over30_TARC_NS$Conc_pslog2)
TNFa_over30_CS = wilcox.test(over30_TNFa_CS$Conc_pslog2, over30_TNFa_NS$Conc_pslog2)

#over30 Ecig vs. NS
Eotaxin_over30_Ecig = wilcox.test(over30_Eotaxin_Ecig$Conc_pslog2, over30_Eotaxin_NS$Conc_pslog2)
Eotaxin3_over30_Ecig = wilcox.test(over30_Eotaxin3_Ecig$Conc_pslog2, over30_Eotaxin3_NS$Conc_pslog2)
Fractalkine_over30_Ecig = wilcox.test(over30_Fractalkine_Ecig$Conc_pslog2, over30_Fractalkine_NS$Conc_pslog2)
I309_over30_Ecig = wilcox.test(over30_I309_Ecig$Conc_pslog2, over30_I309_NS$Conc_pslog2)
IFNg_over30_Ecig = wilcox.test(over30_IFNg_Ecig$Conc_pslog2, over30_IFNg_NS$Conc_pslog2)
IL10_over30_Ecig = wilcox.test(over30_IL10_Ecig$Conc_pslog2, over30_IL10_NS$Conc_pslog2)
IL12p70_over30_Ecig = wilcox.test(over30_IL12p70_Ecig$Conc_pslog2, over30_IL12p70_NS$Conc_pslog2)
IL13_over30_Ecig = wilcox.test(over30_IL13_Ecig$Conc_pslog2, over30_IL13_NS$Conc_pslog2)
IL17B_over30_Ecig = wilcox.test(over30_IL17B_Ecig$Conc_pslog2, over30_IL17B_NS$Conc_pslog2)
IL17D_over30_Ecig = wilcox.test(over30_IL17D_Ecig$Conc_pslog2, over30_IL17D_NS$Conc_pslog2)
IL1b_over30_Ecig = wilcox.test(over30_IL1b_Ecig$Conc_pslog2, over30_IL1b_NS$Conc_pslog2)
IL4_over30_Ecig = wilcox.test(over30_IL4_Ecig$Conc_pslog2, over30_IL4_NS$Conc_pslog2)
IL6_over30_Ecig = wilcox.test(over30_IL6_Ecig$Conc_pslog2, over30_IL6_NS$Conc_pslog2)
IL8_over30_Ecig = wilcox.test(over30_IL8_Ecig$Conc_pslog2, over30_IL8_NS$Conc_pslog2)
IP10_over30_Ecig = wilcox.test(over30_IP10_Ecig$Conc_pslog2, over30_IP10_NS$Conc_pslog2)
ITAC_over30_Ecig = wilcox.test(over30_ITAC_Ecig$Conc_pslog2, over30_ITAC_NS$Conc_pslog2)
MCP1_over30_Ecig = wilcox.test(over30_MCP1_Ecig$Conc_pslog2, over30_MCP1_NS$Conc_pslog2)
MIG_over30_Ecig = wilcox.test(over30_MIG_Ecig$Conc_pslog2, over30_MIG_NS$Conc_pslog2)
MIP1a_over30_Ecig = wilcox.test(over30_MIP1a_Ecig$Conc_pslog2, over30_MIP1a_NS$Conc_pslog2)
MIP1b_over30_Ecig = wilcox.test(over30_MIP1b_Ecig$Conc_pslog2, over30_MIP1b_NS$Conc_pslog2)
TARC_over30_Ecig = wilcox.test(over30_TARC_Ecig$Conc_pslog2, over30_TARC_NS$Conc_pslog2)
TNFa_over30_Ecig = wilcox.test(over30_TNFa_Ecig$Conc_pslog2, over30_TNFa_NS$Conc_pslog2)
# Out:
# Warning message in wilcox.test.default(under30_Eotaxin_CS$Conc_pslog2, under30_Eotaxin_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(under30_Eotaxin3_CS$Conc_pslog2, under30_Eotaxin3_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(under30_I309_CS$Conc_pslog2, under30_I309_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(under30_IFNg_CS$Conc_pslog2, under30_IFNg_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(under30_IL10_CS$Conc_pslog2, under30_IL10_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(under30_IL12p70_CS$Conc_pslog2, under30_IL12p70_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(under30_IL13_CS$Conc_pslog2, under30_IL13_NS$Conc_pslog2):
# ...

# %%
#under30 CS vs. NS
Eotaxin_under30_CS_tuple = get_stat_pvalue_tuple(Eotaxin_under30_CS)
Eotaxin3_under30_CS_tuple = get_stat_pvalue_tuple(Eotaxin3_under30_CS)
Fractalkine_under30_CS_tuple = get_stat_pvalue_tuple(Fractalkine_under30_CS)
I309_under30_CS_tuple = get_stat_pvalue_tuple(I309_under30_CS)
IFNg_under30_CS_tuple = get_stat_pvalue_tuple(IFNg_under30_CS)
IL10_under30_CS_tuple = get_stat_pvalue_tuple(IL10_under30_CS)
IL12p70_under30_CS_tuple = get_stat_pvalue_tuple(IL12p70_under30_CS)
IL13_under30_CS_tuple = get_stat_pvalue_tuple(IL13_under30_CS)
IL17B_under30_CS_tuple = get_stat_pvalue_tuple(IL17B_under30_CS)
IL17D_under30_CS_tuple = get_stat_pvalue_tuple(IL17D_under30_CS)
IL1b_under30_CS_tuple = get_stat_pvalue_tuple(IL1b_under30_CS)
IL4_under30_CS_tuple = get_stat_pvalue_tuple(IL4_under30_CS)
IL6_under30_CS_tuple = get_stat_pvalue_tuple(IL6_under30_CS)
IL8_under30_CS_tuple = get_stat_pvalue_tuple(IL8_under30_CS)
IP10_under30_CS_tuple = get_stat_pvalue_tuple(IP10_under30_CS)
ITAC_under30_CS_tuple = get_stat_pvalue_tuple(ITAC_under30_CS)
MCP1_under30_CS_tuple = get_stat_pvalue_tuple(MCP1_under30_CS)
MIG_under30_CS_tuple = get_stat_pvalue_tuple(MIG_under30_CS)
MIP1a_under30_CS_tuple = get_stat_pvalue_tuple(MIP1a_under30_CS)
MIP1b_under30_CS_tuple = get_stat_pvalue_tuple(MIP1b_under30_CS)
TARC_under30_CS_tuple = get_stat_pvalue_tuple(TARC_under30_CS)
TNFa_under30_CS_tuple = get_stat_pvalue_tuple(TNFa_under30_CS)

#under30 Ecig vs. NS
Eotaxin_under30_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin_under30_Ecig)
Eotaxin3_under30_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin3_under30_Ecig)
Fractalkine_under30_Ecig_tuple = get_stat_pvalue_tuple(Fractalkine_under30_Ecig)
I309_under30_Ecig_tuple = get_stat_pvalue_tuple(I309_under30_Ecig)
IFNg_under30_Ecig_tuple = get_stat_pvalue_tuple(IFNg_under30_Ecig)
IL10_under30_Ecig_tuple = get_stat_pvalue_tuple(IL10_under30_Ecig)
IL12p70_under30_Ecig_tuple = get_stat_pvalue_tuple(IL12p70_under30_Ecig)
IL13_under30_Ecig_tuple = get_stat_pvalue_tuple(IL13_under30_Ecig)
IL17B_under30_Ecig_tuple = get_stat_pvalue_tuple(IL17B_under30_Ecig)
IL17D_under30_Ecig_tuple = get_stat_pvalue_tuple(IL17D_under30_Ecig)
IL1b_under30_Ecig_tuple = get_stat_pvalue_tuple(IL1b_under30_Ecig)
IL4_under30_Ecig_tuple = get_stat_pvalue_tuple(IL4_under30_Ecig)
IL6_under30_Ecig_tuple = get_stat_pvalue_tuple(IL6_under30_Ecig)
IL8_under30_Ecig_tuple = get_stat_pvalue_tuple(IL8_under30_Ecig)
IP10_under30_Ecig_tuple = get_stat_pvalue_tuple(IP10_under30_Ecig)
ITAC_under30_Ecig_tuple = get_stat_pvalue_tuple(ITAC_under30_Ecig)
MCP1_under30_Ecig_tuple = get_stat_pvalue_tuple(MCP1_under30_Ecig)
MIG_under30_Ecig_tuple = get_stat_pvalue_tuple(MIG_under30_Ecig)
MIP1a_under30_Ecig_tuple = get_stat_pvalue_tuple(MIP1a_under30_Ecig)
MIP1b_under30_Ecig_tuple = get_stat_pvalue_tuple(MIP1b_under30_Ecig)
TARC_under30_Ecig_tuple = get_stat_pvalue_tuple(TARC_under30_Ecig)
TNFa_under30_Ecig_tuple = get_stat_pvalue_tuple(TNFa_under30_Ecig)

#over30 CS vs. NS
Eotaxin_over30_CS_tuple = get_stat_pvalue_tuple(Eotaxin_over30_CS)
Eotaxin3_over30_CS_tuple = get_stat_pvalue_tuple(Eotaxin3_over30_CS)
Fractalkine_over30_CS_tuple = get_stat_pvalue_tuple(Fractalkine_over30_CS)
I309_over30_CS_tuple = get_stat_pvalue_tuple(I309_over30_CS)
IFNg_over30_CS_tuple = get_stat_pvalue_tuple(IFNg_over30_CS)
IL10_over30_CS_tuple = get_stat_pvalue_tuple(IL10_over30_CS)
IL12p70_over30_CS_tuple = get_stat_pvalue_tuple(IL12p70_over30_CS)
IL13_over30_CS_tuple = get_stat_pvalue_tuple(IL13_over30_CS)
IL17B_over30_CS_tuple = get_stat_pvalue_tuple(IL17B_over30_CS)
IL17D_over30_CS_tuple = get_stat_pvalue_tuple(IL17D_over30_CS)
IL1b_over30_CS_tuple = get_stat_pvalue_tuple(IL1b_over30_CS)
IL4_over30_CS_tuple = get_stat_pvalue_tuple(IL4_over30_CS)
IL6_over30_CS_tuple = get_stat_pvalue_tuple(IL6_over30_CS)
IL8_over30_CS_tuple = get_stat_pvalue_tuple(IL8_over30_CS)
IP10_over30_CS_tuple = get_stat_pvalue_tuple(IP10_over30_CS)
ITAC_over30_CS_tuple = get_stat_pvalue_tuple(ITAC_over30_CS)
MCP1_over30_CS_tuple = get_stat_pvalue_tuple(MCP1_over30_CS)
MIG_over30_CS_tuple = get_stat_pvalue_tuple(MIG_over30_CS)
MIP1a_over30_CS_tuple = get_stat_pvalue_tuple(MIP1a_over30_CS)
MIP1b_over30_CS_tuple = get_stat_pvalue_tuple(MIP1b_over30_CS)
TARC_over30_CS_tuple = get_stat_pvalue_tuple(TARC_over30_CS)
TNFa_over30_CS_tuple = get_stat_pvalue_tuple(TNFa_over30_CS)

#over30 Ecig vs. NS
Eotaxin_over30_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin_over30_Ecig)
Eotaxin3_over30_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin3_over30_Ecig)
Fractalkine_over30_Ecig_tuple = get_stat_pvalue_tuple(Fractalkine_over30_Ecig)
I309_over30_Ecig_tuple = get_stat_pvalue_tuple(I309_over30_Ecig)
IFNg_over30_Ecig_tuple = get_stat_pvalue_tuple(IFNg_over30_Ecig)
IL10_over30_Ecig_tuple = get_stat_pvalue_tuple(IL10_over30_Ecig)
IL12p70_over30_Ecig_tuple = get_stat_pvalue_tuple(IL12p70_over30_Ecig)
IL13_over30_Ecig_tuple = get_stat_pvalue_tuple(IL13_over30_Ecig)
IL17B_over30_Ecig_tuple = get_stat_pvalue_tuple(IL17B_over30_Ecig)
IL17D_over30_Ecig_tuple = get_stat_pvalue_tuple(IL17D_over30_Ecig)
IL1b_over30_Ecig_tuple = get_stat_pvalue_tuple(IL1b_over30_Ecig)
IL4_over30_Ecig_tuple = get_stat_pvalue_tuple(IL4_over30_Ecig)
IL6_over30_Ecig_tuple = get_stat_pvalue_tuple(IL6_over30_Ecig)
IL8_over30_Ecig_tuple = get_stat_pvalue_tuple(IL8_over30_Ecig)
IP10_over30_Ecig_tuple = get_stat_pvalue_tuple(IP10_over30_Ecig)
ITAC_over30_Ecig_tuple = get_stat_pvalue_tuple(ITAC_over30_Ecig)
MCP1_over30_Ecig_tuple = get_stat_pvalue_tuple(MCP1_over30_Ecig)
MIG_over30_Ecig_tuple = get_stat_pvalue_tuple(MIG_over30_Ecig)
MIP1a_over30_Ecig_tuple = get_stat_pvalue_tuple(MIP1a_over30_Ecig)
MIP1b_over30_Ecig_tuple = get_stat_pvalue_tuple(MIP1b_over30_Ecig)
TARC_over30_Ecig_tuple = get_stat_pvalue_tuple(TARC_over30_Ecig)
TNFa_over30_Ecig_tuple = get_stat_pvalue_tuple(TNFa_over30_Ecig)

# %% [markdown]
# # BMI

# %%
get_bmi_subset = function(dataframe, bmi, protein, smoking_status){
    #"""
    # Getting concentrations for subjects based on bmi for each cytokine based on smoking status (ciagratte or 
    # e-cig user).
    
    #:param: subsetted data frame, bmi specification, cytokine, smoking status 
    #:output: a 24x13 matrix containing concentrations for each cytokine

    #"""
    subsetted_df = subset(dataframe, dataframe$BMI == bmi & dataframe$Protein == protein & dataframe$Group == smoking_status)
}

#normalbmi subjects
normalbmi_Eotaxin_CS = get_bmi_subset(data_df, 'N','Eotaxin','CS')
normalbmi_Eotaxin3_CS = get_bmi_subset(data_df, 'N','Eotaxin3','CS')
normalbmi_Fractalkine_CS = get_bmi_subset(data_df, 'N','Fractalkine','CS')
normalbmi_I309_CS = get_bmi_subset(data_df, 'N','I309','CS')
normalbmi_IFNg_CS = get_bmi_subset(data_df, 'N','IFNg','CS')
normalbmi_IL10_CS = get_bmi_subset(data_df, 'N','IL10','CS')
normalbmi_IL12p70_CS = get_bmi_subset(data_df, 'N','IL12p70','CS')
normalbmi_IL13_CS = get_bmi_subset(data_df, 'N','IL13','CS')
normalbmi_IL17B_CS = get_bmi_subset(data_df, 'N','IL17B','CS')
normalbmi_IL17D_CS = get_bmi_subset(data_df, 'N','IL17D','CS')
normalbmi_IL1b_CS = get_bmi_subset(data_df, 'N','IL1b','CS')
normalbmi_IL4_CS = get_bmi_subset(data_df, 'N','IL4','CS')
normalbmi_IL6_CS = get_bmi_subset(data_df, 'N','IL6','CS')
normalbmi_IL8_CS = get_bmi_subset(data_df, 'N','IL8','CS')
normalbmi_IP10_CS = get_bmi_subset(data_df, 'N','IP10','CS')
normalbmi_ITAC_CS = get_bmi_subset(data_df, 'N','ITAC','CS')
normalbmi_MCP1_CS = get_bmi_subset(data_df, 'N','MCP1','CS')
normalbmi_MIG_CS = get_bmi_subset(data_df, 'N','MIG','CS')
normalbmi_MIP1a_CS = get_bmi_subset(data_df, 'N','MIP1a','CS')
normalbmi_MIP1b_CS = get_bmi_subset(data_df, 'N','MIP1b','CS')
normalbmi_TARC_CS = get_bmi_subset(data_df, 'N','TARC','CS')
normalbmi_TNFa_CS = get_bmi_subset(data_df, 'N','TNFa','CS')
normalbmi_Eotaxin_Ecig = get_bmi_subset(data_df, 'N','Eotaxin','Ecig')
normalbmi_Eotaxin3_Ecig = get_bmi_subset(data_df, 'N','Eotaxin3','Ecig')
normalbmi_Fractalkine_Ecig = get_bmi_subset(data_df, 'N','Fractalkine','Ecig')
normalbmi_I309_Ecig = get_bmi_subset(data_df, 'N','I309','Ecig')
normalbmi_IFNg_Ecig = get_bmi_subset(data_df, 'N','IFNg','Ecig')
normalbmi_IL10_Ecig = get_bmi_subset(data_df, 'N','IL10','Ecig')
normalbmi_IL12p70_Ecig = get_bmi_subset(data_df, 'N','IL12p70','Ecig')
normalbmi_IL13_Ecig = get_bmi_subset(data_df, 'N','IL13','Ecig')
normalbmi_IL17B_Ecig = get_bmi_subset(data_df, 'N','IL17B','Ecig')
normalbmi_IL17D_Ecig = get_bmi_subset(data_df, 'N','IL17D','Ecig')
normalbmi_IL1b_Ecig = get_bmi_subset(data_df, 'N','IL1b','Ecig')
normalbmi_IL4_Ecig = get_bmi_subset(data_df, 'N','IL4','Ecig')
normalbmi_IL6_Ecig = get_bmi_subset(data_df, 'N','IL6','Ecig')
normalbmi_IL8_Ecig = get_bmi_subset(data_df, 'N','IL8','Ecig')
normalbmi_IP10_Ecig = get_bmi_subset(data_df, 'N','IP10','Ecig')
normalbmi_ITAC_Ecig = get_bmi_subset(data_df, 'N','ITAC','Ecig')
normalbmi_MCP1_Ecig = get_bmi_subset(data_df, 'N','MCP1','Ecig')
normalbmi_MIG_Ecig = get_bmi_subset(data_df, 'N','MIG','Ecig')
normalbmi_MIP1a_Ecig = get_bmi_subset(data_df, 'N','MIP1a','Ecig')
normalbmi_MIP1b_Ecig = get_bmi_subset(data_df, 'N','MIP1b','Ecig')
normalbmi_TARC_Ecig = get_bmi_subset(data_df, 'N','TARC','Ecig')
normalbmi_TNFa_Ecig = get_bmi_subset(data_df, 'N','TNFa','Ecig')
normalbmi_Eotaxin_NS = get_bmi_subset(data_df, 'N','Eotaxin','NS')
normalbmi_Eotaxin3_NS = get_bmi_subset(data_df, 'N','Eotaxin3','NS')
normalbmi_Fractalkine_NS = get_bmi_subset(data_df, 'N','Fractalkine','NS')
normalbmi_I309_NS = get_bmi_subset(data_df, 'N','I309','NS')
normalbmi_IFNg_NS = get_bmi_subset(data_df, 'N','IFNg','NS')
normalbmi_IL10_NS = get_bmi_subset(data_df, 'N','IL10','NS')
normalbmi_IL12p70_NS = get_bmi_subset(data_df, 'N','IL12p70','NS')
normalbmi_IL13_NS = get_bmi_subset(data_df, 'N','IL13','NS')
normalbmi_IL17B_NS = get_bmi_subset(data_df, 'N','IL17B','NS')
normalbmi_IL17D_NS = get_bmi_subset(data_df, 'N','IL17D','NS')
normalbmi_IL1b_NS = get_bmi_subset(data_df, 'N','IL1b','NS')
normalbmi_IL4_NS = get_bmi_subset(data_df, 'N','IL4','NS')
normalbmi_IL6_NS = get_bmi_subset(data_df, 'N','IL6','NS')
normalbmi_IL8_NS = get_bmi_subset(data_df, 'N','IL8','NS')
normalbmi_IP10_NS = get_bmi_subset(data_df, 'N','IP10','NS')
normalbmi_ITAC_NS = get_bmi_subset(data_df, 'N','ITAC','NS')
normalbmi_MCP1_NS = get_bmi_subset(data_df, 'N','MCP1','NS')
normalbmi_MIG_NS = get_bmi_subset(data_df, 'N','MIG','NS')
normalbmi_MIP1a_NS = get_bmi_subset(data_df, 'N','MIP1a','NS')
normalbmi_MIP1b_NS = get_bmi_subset(data_df, 'N','MIP1b','NS')
normalbmi_TARC_NS = get_bmi_subset(data_df, 'N','TARC','NS')
normalbmi_TNFa_NS = get_bmi_subset(data_df, 'N','TNFa','NS')

#overweight subjects
overweight_Eotaxin_CS = get_bmi_subset(data_df, 'O','Eotaxin','CS')
overweight_Eotaxin3_CS = get_bmi_subset(data_df, 'O','Eotaxin3','CS')
overweight_Fractalkine_CS = get_bmi_subset(data_df, 'O','Fractalkine','CS')
overweight_I309_CS = get_bmi_subset(data_df, 'O','I309','CS')
overweight_IFNg_CS = get_bmi_subset(data_df, 'O','IFNg','CS')
overweight_IL10_CS = get_bmi_subset(data_df, 'O','IL10','CS')
overweight_IL12p70_CS = get_bmi_subset(data_df, 'O','IL12p70','CS')
overweight_IL13_CS = get_bmi_subset(data_df, 'O','IL13','CS')
overweight_IL17B_CS = get_bmi_subset(data_df, 'O','IL17B','CS')
overweight_IL17D_CS = get_bmi_subset(data_df, 'O','IL17D','CS')
overweight_IL1b_CS = get_bmi_subset(data_df, 'O','IL1b','CS')
overweight_IL4_CS = get_bmi_subset(data_df, 'O','IL4','CS')
overweight_IL6_CS = get_bmi_subset(data_df, 'O','IL6','CS')
overweight_IL8_CS = get_bmi_subset(data_df, 'O','IL8','CS')
overweight_IP10_CS = get_bmi_subset(data_df, 'O','IP10','CS')
overweight_ITAC_CS = get_bmi_subset(data_df, 'O','ITAC','CS')
overweight_MCP1_CS = get_bmi_subset(data_df, 'O','MCP1','CS')
overweight_MIG_CS = get_bmi_subset(data_df, 'O','MIG','CS')
overweight_MIP1a_CS = get_bmi_subset(data_df, 'O','MIP1a','CS')
overweight_MIP1b_CS = get_bmi_subset(data_df, 'O','MIP1b','CS')
overweight_TARC_CS = get_bmi_subset(data_df, 'O','TARC','CS')
overweight_TNFa_CS = get_bmi_subset(data_df, 'O','TNFa','CS')
overweight_Eotaxin_Ecig = get_bmi_subset(data_df, 'O','Eotaxin','Ecig')
overweight_Eotaxin3_Ecig = get_bmi_subset(data_df, 'O','Eotaxin3','Ecig')
overweight_Fractalkine_Ecig = get_bmi_subset(data_df, 'O','Fractalkine','Ecig')
overweight_I309_Ecig = get_bmi_subset(data_df, 'O','I309','Ecig')
overweight_IFNg_Ecig = get_bmi_subset(data_df, 'O','IFNg','Ecig')
overweight_IL10_Ecig = get_bmi_subset(data_df, 'O','IL10','Ecig')
overweight_IL12p70_Ecig = get_bmi_subset(data_df, 'O','IL12p70','Ecig')
overweight_IL13_Ecig = get_bmi_subset(data_df, 'O','IL13','Ecig')
overweight_IL17B_Ecig = get_bmi_subset(data_df, 'O','IL17B','Ecig')
overweight_IL17D_Ecig = get_bmi_subset(data_df, 'O','IL17D','Ecig')
overweight_IL1b_Ecig = get_bmi_subset(data_df, 'O','IL1b','Ecig')
overweight_IL4_Ecig = get_bmi_subset(data_df, 'O','IL4','Ecig')
overweight_IL6_Ecig = get_bmi_subset(data_df, 'O','IL6','Ecig')
overweight_IL8_Ecig = get_bmi_subset(data_df, 'O','IL8','Ecig')
overweight_IP10_Ecig = get_bmi_subset(data_df, 'O','IP10','Ecig')
overweight_ITAC_Ecig = get_bmi_subset(data_df, 'O','ITAC','Ecig')
overweight_MCP1_Ecig = get_bmi_subset(data_df, 'O','MCP1','Ecig')
overweight_MIG_Ecig = get_bmi_subset(data_df, 'O','MIG','Ecig')
overweight_MIP1a_Ecig = get_bmi_subset(data_df, 'O','MIP1a','Ecig')
overweight_MIP1b_Ecig = get_bmi_subset(data_df, 'O','MIP1b','Ecig')
overweight_TARC_Ecig = get_bmi_subset(data_df, 'O','TARC','Ecig')
overweight_TNFa_Ecig = get_bmi_subset(data_df, 'O','TNFa','Ecig')
overweight_Eotaxin_NS = get_bmi_subset(data_df, 'O','Eotaxin','NS')
overweight_Eotaxin3_NS = get_bmi_subset(data_df, 'O','Eotaxin3','NS')
overweight_Fractalkine_NS = get_bmi_subset(data_df, 'O','Fractalkine','NS')
overweight_I309_NS = get_bmi_subset(data_df, 'O','I309','NS')
overweight_IFNg_NS = get_bmi_subset(data_df, 'O','IFNg','NS')
overweight_IL10_NS = get_bmi_subset(data_df, 'O','IL10','NS')
overweight_IL12p70_NS = get_bmi_subset(data_df, 'O','IL12p70','NS')
overweight_IL13_NS = get_bmi_subset(data_df, 'O','IL13','NS')
overweight_IL17B_NS = get_bmi_subset(data_df, 'O','IL17B','NS')
overweight_IL17D_NS = get_bmi_subset(data_df, 'O','IL17D','NS')
overweight_IL1b_NS = get_bmi_subset(data_df, 'O','IL1b','NS')
overweight_IL4_NS = get_bmi_subset(data_df, 'O','IL4','NS')
overweight_IL6_NS = get_bmi_subset(data_df, 'O','IL6','NS')
overweight_IL8_NS = get_bmi_subset(data_df, 'O','IL8','NS')
overweight_IP10_NS = get_bmi_subset(data_df, 'O','IP10','NS')
overweight_ITAC_NS = get_bmi_subset(data_df, 'O','ITAC','NS')
overweight_MCP1_NS = get_bmi_subset(data_df, 'O','MCP1','NS')
overweight_MIG_NS = get_bmi_subset(data_df, 'O','MIG','NS')
overweight_MIP1a_NS = get_bmi_subset(data_df, 'O','MIP1a','NS')
overweight_MIP1b_NS = get_bmi_subset(data_df, 'O','MIP1b','NS')
overweight_TARC_NS = get_bmi_subset(data_df, 'O','TARC','NS')
overweight_TNFa_NS = get_bmi_subset(data_df, 'O','TNFa','NS')

# %%
#normalbmi CS vs. NS
Eotaxin_normalbmi_CS = wilcox.test(normalbmi_Eotaxin_CS$Conc_pslog2, normalbmi_Eotaxin_NS$Conc_pslog2)
Eotaxin3_normalbmi_CS = wilcox.test(normalbmi_Eotaxin3_CS$Conc_pslog2, normalbmi_Eotaxin3_NS$Conc_pslog2)
Fractalkine_normalbmi_CS = wilcox.test(normalbmi_Fractalkine_CS$Conc_pslog2, normalbmi_Fractalkine_NS$Conc_pslog2)
I309_normalbmi_CS = wilcox.test(normalbmi_I309_CS$Conc_pslog2, normalbmi_I309_NS$Conc_pslog2)
IFNg_normalbmi_CS = wilcox.test(normalbmi_IFNg_CS$Conc_pslog2, normalbmi_IFNg_NS$Conc_pslog2)
IL10_normalbmi_CS = wilcox.test(normalbmi_IL10_CS$Conc_pslog2, normalbmi_IL10_NS$Conc_pslog2)
IL12p70_normalbmi_CS = wilcox.test(normalbmi_IL12p70_CS$Conc_pslog2, normalbmi_IL12p70_NS$Conc_pslog2)
IL13_normalbmi_CS = wilcox.test(normalbmi_IL13_CS$Conc_pslog2, normalbmi_IL13_NS$Conc_pslog2)
IL17B_normalbmi_CS = wilcox.test(normalbmi_IL17B_CS$Conc_pslog2, normalbmi_IL17B_NS$Conc_pslog2)
IL17D_normalbmi_CS = wilcox.test(normalbmi_IL17D_CS$Conc_pslog2, normalbmi_IL17D_NS$Conc_pslog2)
IL1b_normalbmi_CS = wilcox.test(normalbmi_IL1b_CS$Conc_pslog2, normalbmi_IL1b_NS$Conc_pslog2)
IL4_normalbmi_CS = wilcox.test(normalbmi_IL4_CS$Conc_pslog2, normalbmi_IL4_NS$Conc_pslog2)
IL6_normalbmi_CS = wilcox.test(normalbmi_IL6_CS$Conc_pslog2, normalbmi_IL6_NS$Conc_pslog2)
IL8_normalbmi_CS = wilcox.test(normalbmi_IL8_CS$Conc_pslog2, normalbmi_IL8_NS$Conc_pslog2)
IP10_normalbmi_CS = wilcox.test(normalbmi_IP10_CS$Conc_pslog2, normalbmi_IP10_NS$Conc_pslog2)
ITAC_normalbmi_CS = wilcox.test(normalbmi_ITAC_CS$Conc_pslog2, normalbmi_ITAC_NS$Conc_pslog2)
MCP1_normalbmi_CS = wilcox.test(normalbmi_MCP1_CS$Conc_pslog2, normalbmi_MCP1_NS$Conc_pslog2)
MIG_normalbmi_CS = wilcox.test(normalbmi_MIG_CS$Conc_pslog2, normalbmi_MIG_NS$Conc_pslog2)
MIP1a_normalbmi_CS = wilcox.test(normalbmi_MIP1a_CS$Conc_pslog2, normalbmi_MIP1a_NS$Conc_pslog2)
MIP1b_normalbmi_CS = wilcox.test(normalbmi_MIP1b_CS$Conc_pslog2, normalbmi_MIP1b_NS$Conc_pslog2)
TARC_normalbmi_CS = wilcox.test(normalbmi_TARC_CS$Conc_pslog2, normalbmi_TARC_NS$Conc_pslog2)
TNFa_normalbmi_CS = wilcox.test(normalbmi_TNFa_CS$Conc_pslog2, normalbmi_TNFa_NS$Conc_pslog2)

#normalbmi Ecig vs. NS
Eotaxin_normalbmi_Ecig = wilcox.test(normalbmi_Eotaxin_Ecig$Conc_pslog2, normalbmi_Eotaxin_NS$Conc_pslog2)
Eotaxin3_normalbmi_Ecig = wilcox.test(normalbmi_Eotaxin3_Ecig$Conc_pslog2, normalbmi_Eotaxin3_NS$Conc_pslog2)
Fractalkine_normalbmi_Ecig = wilcox.test(normalbmi_Fractalkine_Ecig$Conc_pslog2, normalbmi_Fractalkine_NS$Conc_pslog2)
I309_normalbmi_Ecig = wilcox.test(normalbmi_I309_Ecig$Conc_pslog2, normalbmi_I309_NS$Conc_pslog2)
IFNg_normalbmi_Ecig = wilcox.test(normalbmi_IFNg_Ecig$Conc_pslog2, normalbmi_IFNg_NS$Conc_pslog2)
IL10_normalbmi_Ecig = wilcox.test(normalbmi_IL10_Ecig$Conc_pslog2, normalbmi_IL10_NS$Conc_pslog2)
IL12p70_normalbmi_Ecig = wilcox.test(normalbmi_IL12p70_Ecig$Conc_pslog2, normalbmi_IL12p70_NS$Conc_pslog2)
IL13_normalbmi_Ecig = wilcox.test(normalbmi_IL13_Ecig$Conc_pslog2, normalbmi_IL13_NS$Conc_pslog2)
IL17B_normalbmi_Ecig = wilcox.test(normalbmi_IL17B_Ecig$Conc_pslog2, normalbmi_IL17B_NS$Conc_pslog2)
IL17D_normalbmi_Ecig = wilcox.test(normalbmi_IL17D_Ecig$Conc_pslog2, normalbmi_IL17D_NS$Conc_pslog2)
IL1b_normalbmi_Ecig = wilcox.test(normalbmi_IL1b_Ecig$Conc_pslog2, normalbmi_IL1b_NS$Conc_pslog2)
IL4_normalbmi_Ecig = wilcox.test(normalbmi_IL4_Ecig$Conc_pslog2, normalbmi_IL4_NS$Conc_pslog2)
IL6_normalbmi_Ecig = wilcox.test(normalbmi_IL6_Ecig$Conc_pslog2, normalbmi_IL6_NS$Conc_pslog2)
IL8_normalbmi_Ecig = wilcox.test(normalbmi_IL8_Ecig$Conc_pslog2, normalbmi_IL8_NS$Conc_pslog2)
IP10_normalbmi_Ecig = wilcox.test(normalbmi_IP10_Ecig$Conc_pslog2, normalbmi_IP10_NS$Conc_pslog2)
ITAC_normalbmi_Ecig = wilcox.test(normalbmi_ITAC_Ecig$Conc_pslog2, normalbmi_ITAC_NS$Conc_pslog2)
MCP1_normalbmi_Ecig = wilcox.test(normalbmi_MCP1_Ecig$Conc_pslog2, normalbmi_MCP1_NS$Conc_pslog2)
MIG_normalbmi_Ecig = wilcox.test(normalbmi_MIG_Ecig$Conc_pslog2, normalbmi_MIG_NS$Conc_pslog2)
MIP1a_normalbmi_Ecig = wilcox.test(normalbmi_MIP1a_Ecig$Conc_pslog2, normalbmi_MIP1a_NS$Conc_pslog2)
MIP1b_normalbmi_Ecig = wilcox.test(normalbmi_MIP1b_Ecig$Conc_pslog2, normalbmi_MIP1b_NS$Conc_pslog2)
TARC_normalbmi_Ecig = wilcox.test(normalbmi_TARC_Ecig$Conc_pslog2, normalbmi_TARC_NS$Conc_pslog2)
TNFa_normalbmi_Ecig = wilcox.test(normalbmi_TNFa_Ecig$Conc_pslog2, normalbmi_TNFa_NS$Conc_pslog2)

#overweight CS vs. NS
Eotaxin_overweight_CS = wilcox.test(overweight_Eotaxin_CS$Conc_pslog2, overweight_Eotaxin_NS$Conc_pslog2)
Eotaxin3_overweight_CS = wilcox.test(overweight_Eotaxin3_CS$Conc_pslog2, overweight_Eotaxin3_NS$Conc_pslog2)
Fractalkine_overweight_CS = wilcox.test(overweight_Fractalkine_CS$Conc_pslog2, overweight_Fractalkine_NS$Conc_pslog2)
I309_overweight_CS = wilcox.test(overweight_I309_CS$Conc_pslog2, overweight_I309_NS$Conc_pslog2)
IFNg_overweight_CS = wilcox.test(overweight_IFNg_CS$Conc_pslog2, overweight_IFNg_NS$Conc_pslog2)
IL10_overweight_CS = wilcox.test(overweight_IL10_CS$Conc_pslog2, overweight_IL10_NS$Conc_pslog2)
IL12p70_overweight_CS = wilcox.test(overweight_IL12p70_CS$Conc_pslog2, overweight_IL12p70_NS$Conc_pslog2)
IL13_overweight_CS = wilcox.test(overweight_IL13_CS$Conc_pslog2, overweight_IL13_NS$Conc_pslog2)
IL17B_overweight_CS = wilcox.test(overweight_IL17B_CS$Conc_pslog2, overweight_IL17B_NS$Conc_pslog2)
IL17D_overweight_CS = wilcox.test(overweight_IL17D_CS$Conc_pslog2, overweight_IL17D_NS$Conc_pslog2)
IL1b_overweight_CS = wilcox.test(overweight_IL1b_CS$Conc_pslog2, overweight_IL1b_NS$Conc_pslog2)
IL4_overweight_CS = wilcox.test(overweight_IL4_CS$Conc_pslog2, overweight_IL4_NS$Conc_pslog2)
IL6_overweight_CS = wilcox.test(overweight_IL6_CS$Conc_pslog2, overweight_IL6_NS$Conc_pslog2)
IL8_overweight_CS = wilcox.test(overweight_IL8_CS$Conc_pslog2, overweight_IL8_NS$Conc_pslog2)
IP10_overweight_CS = wilcox.test(overweight_IP10_CS$Conc_pslog2, overweight_IP10_NS$Conc_pslog2)
ITAC_overweight_CS = wilcox.test(overweight_ITAC_CS$Conc_pslog2, overweight_ITAC_NS$Conc_pslog2)
MCP1_overweight_CS = wilcox.test(overweight_MCP1_CS$Conc_pslog2, overweight_MCP1_NS$Conc_pslog2)
MIG_overweight_CS = wilcox.test(overweight_MIG_CS$Conc_pslog2, overweight_MIG_NS$Conc_pslog2)
MIP1a_overweight_CS = wilcox.test(overweight_MIP1a_CS$Conc_pslog2, overweight_MIP1a_NS$Conc_pslog2)
MIP1b_overweight_CS = wilcox.test(overweight_MIP1b_CS$Conc_pslog2, overweight_MIP1b_NS$Conc_pslog2)
TARC_overweight_CS = wilcox.test(overweight_TARC_CS$Conc_pslog2, overweight_TARC_NS$Conc_pslog2)
TNFa_overweight_CS = wilcox.test(overweight_TNFa_CS$Conc_pslog2, overweight_TNFa_NS$Conc_pslog2)

#overweight Ecig vs. NS
Eotaxin_overweight_Ecig = wilcox.test(overweight_Eotaxin_Ecig$Conc_pslog2, overweight_Eotaxin_NS$Conc_pslog2)
Eotaxin3_overweight_Ecig = wilcox.test(overweight_Eotaxin3_Ecig$Conc_pslog2, overweight_Eotaxin3_NS$Conc_pslog2)
Fractalkine_overweight_Ecig = wilcox.test(overweight_Fractalkine_Ecig$Conc_pslog2, overweight_Fractalkine_NS$Conc_pslog2)
I309_overweight_Ecig = wilcox.test(overweight_I309_Ecig$Conc_pslog2, overweight_I309_NS$Conc_pslog2)
IFNg_overweight_Ecig = wilcox.test(overweight_IFNg_Ecig$Conc_pslog2, overweight_IFNg_NS$Conc_pslog2)
IL10_overweight_Ecig = wilcox.test(overweight_IL10_Ecig$Conc_pslog2, overweight_IL10_NS$Conc_pslog2)
IL12p70_overweight_Ecig = wilcox.test(overweight_IL12p70_Ecig$Conc_pslog2, overweight_IL12p70_NS$Conc_pslog2)
IL13_overweight_Ecig = wilcox.test(overweight_IL13_Ecig$Conc_pslog2, overweight_IL13_NS$Conc_pslog2)
IL17B_overweight_Ecig = wilcox.test(overweight_IL17B_Ecig$Conc_pslog2, overweight_IL17B_NS$Conc_pslog2)
IL17D_overweight_Ecig = wilcox.test(overweight_IL17D_Ecig$Conc_pslog2, overweight_IL17D_NS$Conc_pslog2)
IL1b_overweight_Ecig = wilcox.test(overweight_IL1b_Ecig$Conc_pslog2, overweight_IL1b_NS$Conc_pslog2)
IL4_overweight_Ecig = wilcox.test(overweight_IL4_Ecig$Conc_pslog2, overweight_IL4_NS$Conc_pslog2)
IL6_overweight_Ecig = wilcox.test(overweight_IL6_Ecig$Conc_pslog2, overweight_IL6_NS$Conc_pslog2)
IL8_overweight_Ecig = wilcox.test(overweight_IL8_Ecig$Conc_pslog2, overweight_IL8_NS$Conc_pslog2)
IP10_overweight_Ecig = wilcox.test(overweight_IP10_Ecig$Conc_pslog2, overweight_IP10_NS$Conc_pslog2)
ITAC_overweight_Ecig = wilcox.test(overweight_ITAC_Ecig$Conc_pslog2, overweight_ITAC_NS$Conc_pslog2)
MCP1_overweight_Ecig = wilcox.test(overweight_MCP1_Ecig$Conc_pslog2, overweight_MCP1_NS$Conc_pslog2)
MIG_overweight_Ecig = wilcox.test(overweight_MIG_Ecig$Conc_pslog2, overweight_MIG_NS$Conc_pslog2)
MIP1a_overweight_Ecig = wilcox.test(overweight_MIP1a_Ecig$Conc_pslog2, overweight_MIP1a_NS$Conc_pslog2)
MIP1b_overweight_Ecig = wilcox.test(overweight_MIP1b_Ecig$Conc_pslog2, overweight_MIP1b_NS$Conc_pslog2)
TARC_overweight_Ecig = wilcox.test(overweight_TARC_Ecig$Conc_pslog2, overweight_TARC_NS$Conc_pslog2)
TNFa_overweight_Ecig = wilcox.test(overweight_TNFa_Ecig$Conc_pslog2, overweight_TNFa_NS$Conc_pslog2)
# Out:
# Warning message in wilcox.test.default(normalbmi_Eotaxin_CS$Conc_pslog2, normalbmi_Eotaxin_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(normalbmi_Eotaxin3_CS$Conc_pslog2, normalbmi_Eotaxin3_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(normalbmi_I309_CS$Conc_pslog2, normalbmi_I309_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(normalbmi_IFNg_CS$Conc_pslog2, normalbmi_IFNg_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(normalbmi_IL10_CS$Conc_pslog2, normalbmi_IL10_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(normalbmi_IL12p70_CS$Conc_pslog2, normalbmi_IL12p70_NS$Conc_pslog2):
# “cannot compute exact p-value with ties”
# ...

# %%
#normalbmi CS vs. NS
Eotaxin_normalbmi_CS_tuple = get_stat_pvalue_tuple(Eotaxin_normalbmi_CS)
Eotaxin3_normalbmi_CS_tuple = get_stat_pvalue_tuple(Eotaxin3_normalbmi_CS)
Fractalkine_normalbmi_CS_tuple = get_stat_pvalue_tuple(Fractalkine_normalbmi_CS)
I309_normalbmi_CS_tuple = get_stat_pvalue_tuple(I309_normalbmi_CS)
IFNg_normalbmi_CS_tuple = get_stat_pvalue_tuple(IFNg_normalbmi_CS)
IL10_normalbmi_CS_tuple = get_stat_pvalue_tuple(IL10_normalbmi_CS)
IL12p70_normalbmi_CS_tuple = get_stat_pvalue_tuple(IL12p70_normalbmi_CS)
IL13_normalbmi_CS_tuple = get_stat_pvalue_tuple(IL13_normalbmi_CS)
IL17B_normalbmi_CS_tuple = get_stat_pvalue_tuple(IL17B_normalbmi_CS)
IL17D_normalbmi_CS_tuple = get_stat_pvalue_tuple(IL17D_normalbmi_CS)
IL1b_normalbmi_CS_tuple = get_stat_pvalue_tuple(IL1b_normalbmi_CS)
IL4_normalbmi_CS_tuple = get_stat_pvalue_tuple(IL4_normalbmi_CS)
IL6_normalbmi_CS_tuple = get_stat_pvalue_tuple(IL6_normalbmi_CS)
IL8_normalbmi_CS_tuple = get_stat_pvalue_tuple(IL8_normalbmi_CS)
IP10_normalbmi_CS_tuple = get_stat_pvalue_tuple(IP10_normalbmi_CS)
ITAC_normalbmi_CS_tuple = get_stat_pvalue_tuple(ITAC_normalbmi_CS)
MCP1_normalbmi_CS_tuple = get_stat_pvalue_tuple(MCP1_normalbmi_CS)
MIG_normalbmi_CS_tuple = get_stat_pvalue_tuple(MIG_normalbmi_CS)
MIP1a_normalbmi_CS_tuple = get_stat_pvalue_tuple(MIP1a_normalbmi_CS)
MIP1b_normalbmi_CS_tuple = get_stat_pvalue_tuple(MIP1b_normalbmi_CS)
TARC_normalbmi_CS_tuple = get_stat_pvalue_tuple(TARC_normalbmi_CS)
TNFa_normalbmi_CS_tuple = get_stat_pvalue_tuple(TNFa_normalbmi_CS)

#normalbmi Ecig vs. NS
Eotaxin_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin_normalbmi_Ecig)
Eotaxin3_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin3_normalbmi_Ecig)
Fractalkine_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(Fractalkine_normalbmi_Ecig)
I309_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(I309_normalbmi_Ecig)
IFNg_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(IFNg_normalbmi_Ecig)
IL10_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(IL10_normalbmi_Ecig)
IL12p70_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(IL12p70_normalbmi_Ecig)
IL13_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(IL13_normalbmi_Ecig)
IL17B_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(IL17B_normalbmi_Ecig)
IL17D_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(IL17D_normalbmi_Ecig)
IL1b_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(IL1b_normalbmi_Ecig)
IL4_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(IL4_normalbmi_Ecig)
IL6_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(IL6_normalbmi_Ecig)
IL8_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(IL8_normalbmi_Ecig)
IP10_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(IP10_normalbmi_Ecig)
ITAC_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(ITAC_normalbmi_Ecig)
MCP1_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(MCP1_normalbmi_Ecig)
MIG_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(MIG_normalbmi_Ecig)
MIP1a_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(MIP1a_normalbmi_Ecig)
MIP1b_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(MIP1b_normalbmi_Ecig)
TARC_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(TARC_normalbmi_Ecig)
TNFa_normalbmi_Ecig_tuple = get_stat_pvalue_tuple(TNFa_normalbmi_Ecig)

#overweight CS vs. NS
Eotaxin_overweight_CS_tuple = get_stat_pvalue_tuple(Eotaxin_overweight_CS)
Eotaxin3_overweight_CS_tuple = get_stat_pvalue_tuple(Eotaxin3_overweight_CS)
Fractalkine_overweight_CS_tuple = get_stat_pvalue_tuple(Fractalkine_overweight_CS)
I309_overweight_CS_tuple = get_stat_pvalue_tuple(I309_overweight_CS)
IFNg_overweight_CS_tuple = get_stat_pvalue_tuple(IFNg_overweight_CS)
IL10_overweight_CS_tuple = get_stat_pvalue_tuple(IL10_overweight_CS)
IL12p70_overweight_CS_tuple = get_stat_pvalue_tuple(IL12p70_overweight_CS)
IL13_overweight_CS_tuple = get_stat_pvalue_tuple(IL13_overweight_CS)
IL17B_overweight_CS_tuple = get_stat_pvalue_tuple(IL17B_overweight_CS)
IL17D_overweight_CS_tuple = get_stat_pvalue_tuple(IL17D_overweight_CS)
IL1b_overweight_CS_tuple = get_stat_pvalue_tuple(IL1b_overweight_CS)
IL4_overweight_CS_tuple = get_stat_pvalue_tuple(IL4_overweight_CS)
IL6_overweight_CS_tuple = get_stat_pvalue_tuple(IL6_overweight_CS)
IL8_overweight_CS_tuple = get_stat_pvalue_tuple(IL8_overweight_CS)
IP10_overweight_CS_tuple = get_stat_pvalue_tuple(IP10_overweight_CS)
ITAC_overweight_CS_tuple = get_stat_pvalue_tuple(ITAC_overweight_CS)
MCP1_overweight_CS_tuple = get_stat_pvalue_tuple(MCP1_overweight_CS)
MIG_overweight_CS_tuple = get_stat_pvalue_tuple(MIG_overweight_CS)
MIP1a_overweight_CS_tuple = get_stat_pvalue_tuple(MIP1a_overweight_CS)
MIP1b_overweight_CS_tuple = get_stat_pvalue_tuple(MIP1b_overweight_CS)
TARC_overweight_CS_tuple = get_stat_pvalue_tuple(TARC_overweight_CS)
TNFa_overweight_CS_tuple = get_stat_pvalue_tuple(TNFa_overweight_CS)

#overweight Ecig vs. NS
Eotaxin_overweight_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin_overweight_Ecig)
Eotaxin3_overweight_Ecig_tuple = get_stat_pvalue_tuple(Eotaxin3_overweight_Ecig)
Fractalkine_overweight_Ecig_tuple = get_stat_pvalue_tuple(Fractalkine_overweight_Ecig)
I309_overweight_Ecig_tuple = get_stat_pvalue_tuple(I309_overweight_Ecig)
IFNg_overweight_Ecig_tuple = get_stat_pvalue_tuple(IFNg_overweight_Ecig)
IL10_overweight_Ecig_tuple = get_stat_pvalue_tuple(IL10_overweight_Ecig)
IL12p70_overweight_Ecig_tuple = get_stat_pvalue_tuple(IL12p70_overweight_Ecig)
IL13_overweight_Ecig_tuple = get_stat_pvalue_tuple(IL13_overweight_Ecig)
IL17B_overweight_Ecig_tuple = get_stat_pvalue_tuple(IL17B_overweight_Ecig)
IL17D_overweight_Ecig_tuple = get_stat_pvalue_tuple(IL17D_overweight_Ecig)
IL1b_overweight_Ecig_tuple = get_stat_pvalue_tuple(IL1b_overweight_Ecig)
IL4_overweight_Ecig_tuple = get_stat_pvalue_tuple(IL4_overweight_Ecig)
IL6_overweight_Ecig_tuple = get_stat_pvalue_tuple(IL6_overweight_Ecig)
IL8_overweight_Ecig_tuple = get_stat_pvalue_tuple(IL8_overweight_Ecig)
IP10_overweight_Ecig_tuple = get_stat_pvalue_tuple(IP10_overweight_Ecig)
ITAC_overweight_Ecig_tuple = get_stat_pvalue_tuple(ITAC_overweight_Ecig)
MCP1_overweight_Ecig_tuple = get_stat_pvalue_tuple(MCP1_overweight_Ecig)
MIG_overweight_Ecig_tuple = get_stat_pvalue_tuple(MIG_overweight_Ecig)
MIP1a_overweight_Ecig_tuple = get_stat_pvalue_tuple(MIP1a_overweight_Ecig)
MIP1b_overweight_Ecig_tuple = get_stat_pvalue_tuple(MIP1b_overweight_Ecig)
TARC_overweight_Ecig_tuple = get_stat_pvalue_tuple(TARC_overweight_Ecig)
TNFa_overweight_Ecig_tuple = get_stat_pvalue_tuple(TNFa_overweight_Ecig)

# %%
table_summary = function(Eotaxin, Eotaxin3, Fractalkine, I309,
                                           IFNg, IL10, IL12p70, IL13,
                                           IL17B, IL17D, IL1b, IL4, IL6,
                                           IL8, IP10, ITAC, MCP1, MIG,
                                           MIP1a, MIP1b, TARC, TNFa, comparison_name){
    #"""
    #Putting stats into a table(matrix) to make transfer to excel easier.

    #:param: none
    #:output: a 22x2 matrix containing statistic and p value. 
    #"""
    compartment_stats_table = rbind(Eotaxin, Eotaxin3, Fractalkine, I309,
                                           IFNg, IL10, IL12p70, IL13,
                                           IL17B, IL17D, IL1b, IL4, IL6,
                                           IL8, IP10, ITAC, MCP1, MIG,
                                           MIP1a, MIP1b, TARC, TNFa)
    comparison = rep(comparison_name, times = length(compartment_stats_table[,1])) #adding a col for the comparison 
    padj =  p.adjust(compartment_stats_table[,2], method = "fdr")  #going back to calculate padj values
    final_table = cbind(comparison, compartment_stats_table, padj) #creating one matrix
    colnames(final_table) = c('Comparison','Statistic','P Value', 'P Adj') #adding col names
    return(final_table)
}

# %%
#calling fns
white_CS_table = table_summary(Eotaxin_white_CS_tuple, Eotaxin3_white_CS_tuple, Fractalkine_white_CS_tuple,I309_white_CS_tuple,
                            IFNg_white_CS_tuple, IL10_white_CS_tuple, IL12p70_white_CS_tuple, IL13_white_CS_tuple, 
                            IL17B_white_CS_tuple, IL17D_white_CS_tuple, IL1b_white_CS_tuple, IL4_white_CS_tuple, IL6_white_CS_tuple,
                            IL8_white_CS_tuple, IP10_white_CS_tuple, ITAC_white_CS_tuple, MCP1_white_CS_tuple, MIG_white_CS_tuple,
                            MIP1a_white_CS_tuple, MIP1b_white_CS_tuple, TARC_white_CS_tuple, TNFa_white_CS_tuple, 'white_CS')
white_Ecig_table = table_summary(Eotaxin_white_Ecig_tuple, Eotaxin3_white_Ecig_tuple, Fractalkine_white_Ecig_tuple,I309_white_Ecig_tuple,
                            IFNg_white_Ecig_tuple, IL10_white_Ecig_tuple, IL12p70_white_Ecig_tuple, IL13_white_Ecig_tuple, 
                            IL17B_white_Ecig_tuple, IL17D_white_Ecig_tuple, IL1b_white_Ecig_tuple, IL4_white_Ecig_tuple, IL6_white_Ecig_tuple,
                            IL8_white_Ecig_tuple, IP10_white_Ecig_tuple, ITAC_white_Ecig_tuple, MCP1_white_Ecig_tuple, MIG_white_Ecig_tuple,
                            MIP1a_white_Ecig_tuple, MIP1b_white_Ecig_tuple, TARC_white_Ecig_tuple, TNFa_white_Ecig_tuple, 'white_Ecig') 
nonwhite_CS_table = table_summary(Eotaxin_nonwhite_CS_tuple, Eotaxin3_nonwhite_CS_tuple, Fractalkine_nonwhite_CS_tuple,I309_nonwhite_CS_tuple,
                            IFNg_nonwhite_CS_tuple, IL10_nonwhite_CS_tuple, IL12p70_nonwhite_CS_tuple, IL13_nonwhite_CS_tuple, 
                            IL17B_nonwhite_CS_tuple, IL17D_nonwhite_CS_tuple, IL1b_nonwhite_CS_tuple, IL4_nonwhite_CS_tuple, IL6_nonwhite_CS_tuple,
                            IL8_nonwhite_CS_tuple, IP10_nonwhite_CS_tuple, ITAC_nonwhite_CS_tuple, MCP1_nonwhite_CS_tuple, MIG_nonwhite_CS_tuple,
                            MIP1a_nonwhite_CS_tuple, MIP1b_nonwhite_CS_tuple, TARC_nonwhite_CS_tuple, TNFa_nonwhite_CS_tuple, 'nonwhite_CS')
nonwhite_Ecig_table = table_summary(Eotaxin_nonwhite_Ecig_tuple, Eotaxin3_nonwhite_Ecig_tuple, Fractalkine_nonwhite_Ecig_tuple,I309_nonwhite_Ecig_tuple,
                            IFNg_nonwhite_Ecig_tuple, IL10_nonwhite_Ecig_tuple, IL12p70_nonwhite_Ecig_tuple, IL13_nonwhite_Ecig_tuple, 
                            IL17B_nonwhite_Ecig_tuple, IL17D_nonwhite_Ecig_tuple, IL1b_nonwhite_Ecig_tuple, IL4_nonwhite_Ecig_tuple, IL6_nonwhite_Ecig_tuple,
                            IL8_nonwhite_Ecig_tuple, IP10_nonwhite_Ecig_tuple, ITAC_nonwhite_Ecig_tuple, MCP1_nonwhite_Ecig_tuple, MIG_nonwhite_Ecig_tuple,
                            MIP1a_nonwhite_Ecig_tuple, MIP1b_nonwhite_Ecig_tuple, TARC_nonwhite_Ecig_tuple, TNFa_nonwhite_Ecig_tuple, 'nonwhite_Ecig')
male_CS_table = table_summary(Eotaxin_male_CS_tuple, Eotaxin3_male_CS_tuple, Fractalkine_male_CS_tuple,I309_male_CS_tuple,
                            IFNg_male_CS_tuple, IL10_male_CS_tuple, IL12p70_male_CS_tuple, IL13_male_CS_tuple, 
                            IL17B_male_CS_tuple, IL17D_male_CS_tuple, IL1b_male_CS_tuple, IL4_male_CS_tuple, IL6_male_CS_tuple,
                            IL8_male_CS_tuple, IP10_male_CS_tuple, ITAC_male_CS_tuple, MCP1_male_CS_tuple, MIG_male_CS_tuple,
                            MIP1a_male_CS_tuple, MIP1b_male_CS_tuple, TARC_male_CS_tuple, TNFa_male_CS_tuple, 'male_CS')
male_Ecig_table = table_summary(Eotaxin_male_Ecig_tuple, Eotaxin3_male_Ecig_tuple, Fractalkine_male_Ecig_tuple,I309_male_Ecig_tuple,
                            IFNg_male_Ecig_tuple, IL10_male_Ecig_tuple, IL12p70_male_Ecig_tuple, IL13_male_Ecig_tuple, 
                            IL17B_male_Ecig_tuple, IL17D_male_Ecig_tuple, IL1b_male_Ecig_tuple, IL4_male_Ecig_tuple, IL6_male_Ecig_tuple,
                            IL8_male_Ecig_tuple, IP10_male_Ecig_tuple, ITAC_male_Ecig_tuple, MCP1_male_Ecig_tuple, MIG_male_Ecig_tuple,
                            MIP1a_male_Ecig_tuple, MIP1b_male_Ecig_tuple, TARC_male_Ecig_tuple, TNFa_male_Ecig_tuple, 'male_Ecig') 
female_CS_table = table_summary(Eotaxin_female_CS_tuple, Eotaxin3_female_CS_tuple, Fractalkine_female_CS_tuple,I309_female_CS_tuple,
                            IFNg_female_CS_tuple, IL10_female_CS_tuple, IL12p70_female_CS_tuple, IL13_female_CS_tuple, 
                            IL17B_female_CS_tuple, IL17D_female_CS_tuple, IL1b_female_CS_tuple, IL4_female_CS_tuple, IL6_female_CS_tuple,
                            IL8_female_CS_tuple, IP10_female_CS_tuple, ITAC_female_CS_tuple, MCP1_female_CS_tuple, MIG_female_CS_tuple,
                            MIP1a_female_CS_tuple, MIP1b_female_CS_tuple, TARC_female_CS_tuple, TNFa_female_CS_tuple, 'female_CS')
female_Ecig_table = table_summary(Eotaxin_female_Ecig_tuple, Eotaxin3_female_Ecig_tuple, Fractalkine_female_Ecig_tuple,I309_female_Ecig_tuple,
                            IFNg_female_Ecig_tuple, IL10_female_Ecig_tuple, IL12p70_female_Ecig_tuple, IL13_female_Ecig_tuple, 
                            IL17B_female_Ecig_tuple, IL17D_female_Ecig_tuple, IL1b_female_Ecig_tuple, IL4_female_Ecig_tuple, IL6_female_Ecig_tuple,
                            IL8_female_Ecig_tuple, IP10_female_Ecig_tuple, ITAC_female_Ecig_tuple, MCP1_female_Ecig_tuple, MIG_female_Ecig_tuple,
                            MIP1a_female_Ecig_tuple, MIP1b_female_Ecig_tuple, TARC_female_Ecig_tuple, TNFa_female_Ecig_tuple, 'female_Ecig')
under30_CS_table = table_summary(Eotaxin_under30_CS_tuple, Eotaxin3_under30_CS_tuple, Fractalkine_under30_CS_tuple,I309_under30_CS_tuple,
                            IFNg_under30_CS_tuple, IL10_under30_CS_tuple, IL12p70_under30_CS_tuple, IL13_under30_CS_tuple, 
                            IL17B_under30_CS_tuple, IL17D_under30_CS_tuple, IL1b_under30_CS_tuple, IL4_under30_CS_tuple, IL6_under30_CS_tuple,
                            IL8_under30_CS_tuple, IP10_under30_CS_tuple, ITAC_under30_CS_tuple, MCP1_under30_CS_tuple, MIG_under30_CS_tuple,
                            MIP1a_under30_CS_tuple, MIP1b_under30_CS_tuple, TARC_under30_CS_tuple, TNFa_under30_CS_tuple, 'under30_CS')
under30_Ecig_table = table_summary(Eotaxin_under30_Ecig_tuple, Eotaxin3_under30_Ecig_tuple, Fractalkine_under30_Ecig_tuple,I309_under30_Ecig_tuple,
                            IFNg_under30_Ecig_tuple, IL10_under30_Ecig_tuple, IL12p70_under30_Ecig_tuple, IL13_under30_Ecig_tuple, 
                            IL17B_under30_Ecig_tuple, IL17D_under30_Ecig_tuple, IL1b_under30_Ecig_tuple, IL4_under30_Ecig_tuple, IL6_under30_Ecig_tuple,
                            IL8_under30_Ecig_tuple, IP10_under30_Ecig_tuple, ITAC_under30_Ecig_tuple, MCP1_under30_Ecig_tuple, MIG_under30_Ecig_tuple,
                            MIP1a_under30_Ecig_tuple, MIP1b_under30_Ecig_tuple, TARC_under30_Ecig_tuple, TNFa_under30_Ecig_tuple, 'under30_Ecig') 
over30_CS_table = table_summary(Eotaxin_over30_CS_tuple, Eotaxin3_over30_CS_tuple, Fractalkine_over30_CS_tuple,I309_over30_CS_tuple,
                            IFNg_over30_CS_tuple, IL10_over30_CS_tuple, IL12p70_over30_CS_tuple, IL13_over30_CS_tuple, 
                            IL17B_over30_CS_tuple, IL17D_over30_CS_tuple, IL1b_over30_CS_tuple, IL4_over30_CS_tuple, IL6_over30_CS_tuple,
                            IL8_over30_CS_tuple, IP10_over30_CS_tuple, ITAC_over30_CS_tuple, MCP1_over30_CS_tuple, MIG_over30_CS_tuple,
                            MIP1a_over30_CS_tuple, MIP1b_over30_CS_tuple, TARC_over30_CS_tuple, TNFa_over30_CS_tuple, 'over30_CS')
over30_Ecig_table = table_summary(Eotaxin_over30_Ecig_tuple, Eotaxin3_over30_Ecig_tuple, Fractalkine_over30_Ecig_tuple,I309_over30_Ecig_tuple,
                            IFNg_over30_Ecig_tuple, IL10_over30_Ecig_tuple, IL12p70_over30_Ecig_tuple, IL13_over30_Ecig_tuple, 
                            IL17B_over30_Ecig_tuple, IL17D_over30_Ecig_tuple, IL1b_over30_Ecig_tuple, IL4_over30_Ecig_tuple, IL6_over30_Ecig_tuple,
                            IL8_over30_Ecig_tuple, IP10_over30_Ecig_tuple, ITAC_over30_Ecig_tuple, MCP1_over30_Ecig_tuple, MIG_over30_Ecig_tuple,
                            MIP1a_over30_Ecig_tuple, MIP1b_over30_Ecig_tuple, TARC_over30_Ecig_tuple, TNFa_over30_Ecig_tuple, 'over30_Ecig')
normalbmi_CS_table = table_summary(Eotaxin_normalbmi_CS_tuple, Eotaxin3_normalbmi_CS_tuple, Fractalkine_normalbmi_CS_tuple,I309_normalbmi_CS_tuple,
                            IFNg_normalbmi_CS_tuple, IL10_normalbmi_CS_tuple, IL12p70_normalbmi_CS_tuple, IL13_normalbmi_CS_tuple, 
                            IL17B_normalbmi_CS_tuple, IL17D_normalbmi_CS_tuple, IL1b_normalbmi_CS_tuple, IL4_normalbmi_CS_tuple, IL6_normalbmi_CS_tuple,
                            IL8_normalbmi_CS_tuple, IP10_normalbmi_CS_tuple, ITAC_normalbmi_CS_tuple, MCP1_normalbmi_CS_tuple, MIG_normalbmi_CS_tuple,
                            MIP1a_normalbmi_CS_tuple, MIP1b_normalbmi_CS_tuple, TARC_normalbmi_CS_tuple, TNFa_normalbmi_CS_tuple, 'normalbmi_CS')
normalbmi_Ecig_table = table_summary(Eotaxin_normalbmi_Ecig_tuple, Eotaxin3_normalbmi_Ecig_tuple, Fractalkine_normalbmi_Ecig_tuple,I309_normalbmi_Ecig_tuple,
                            IFNg_normalbmi_Ecig_tuple, IL10_normalbmi_Ecig_tuple, IL12p70_normalbmi_Ecig_tuple, IL13_normalbmi_Ecig_tuple, 
                            IL17B_normalbmi_Ecig_tuple, IL17D_normalbmi_Ecig_tuple, IL1b_normalbmi_Ecig_tuple, IL4_normalbmi_Ecig_tuple, IL6_normalbmi_Ecig_tuple,
                            IL8_normalbmi_Ecig_tuple, IP10_normalbmi_Ecig_tuple, ITAC_normalbmi_Ecig_tuple, MCP1_normalbmi_Ecig_tuple, MIG_normalbmi_Ecig_tuple,
                            MIP1a_normalbmi_Ecig_tuple, MIP1b_normalbmi_Ecig_tuple, TARC_normalbmi_Ecig_tuple, TNFa_normalbmi_Ecig_tuple, 'normalbmi_Ecig') 
overweight_CS_table = table_summary(Eotaxin_overweight_CS_tuple, Eotaxin3_overweight_CS_tuple, Fractalkine_overweight_CS_tuple,I309_overweight_CS_tuple,
                            IFNg_overweight_CS_tuple, IL10_overweight_CS_tuple, IL12p70_overweight_CS_tuple, IL13_overweight_CS_tuple, 
                            IL17B_overweight_CS_tuple, IL17D_overweight_CS_tuple, IL1b_overweight_CS_tuple, IL4_overweight_CS_tuple, IL6_overweight_CS_tuple,
                            IL8_overweight_CS_tuple, IP10_overweight_CS_tuple, ITAC_overweight_CS_tuple, MCP1_overweight_CS_tuple, MIG_overweight_CS_tuple,
                            MIP1a_overweight_CS_tuple, MIP1b_overweight_CS_tuple, TARC_overweight_CS_tuple, TNFa_overweight_CS_tuple, 'overweight_CS')
overweight_Ecig_table = table_summary(Eotaxin_overweight_Ecig_tuple, Eotaxin3_overweight_Ecig_tuple, Fractalkine_overweight_Ecig_tuple,I309_overweight_Ecig_tuple,
                            IFNg_overweight_Ecig_tuple, IL10_overweight_Ecig_tuple, IL12p70_overweight_Ecig_tuple, IL13_overweight_Ecig_tuple, 
                            IL17B_overweight_Ecig_tuple, IL17D_overweight_Ecig_tuple, IL1b_overweight_Ecig_tuple, IL4_overweight_Ecig_tuple, IL6_overweight_Ecig_tuple,
                            IL8_overweight_Ecig_tuple, IP10_overweight_Ecig_tuple, ITAC_overweight_Ecig_tuple, MCP1_overweight_Ecig_tuple, MIG_overweight_Ecig_tuple,
                            MIP1a_overweight_Ecig_tuple, MIP1b_overweight_Ecig_tuple, TARC_overweight_Ecig_tuple, TNFa_overweight_Ecig_tuple, 'overweight_Ecig')

# %%
#combining table for each demographics variable
race_table = rbind(white_CS_table, white_Ecig_table, nonwhite_CS_table, nonwhite_Ecig_table)
sex_table = rbind(male_CS_table, male_Ecig_table, female_CS_table, female_Ecig_table)
age_table = rbind(under30_CS_table, under30_Ecig_table, over30_CS_table, over30_Ecig_table)
bmi_table = rbind(normalbmi_CS_table, normalbmi_Ecig_table, overweight_CS_table, overweight_Ecig_table)

# %%
#exporting data
write.csv(race_table, paste0(Output,"/", cur_date, "_Race_Cytokine_Distribution.csv"), row.names= TRUE)
write.csv(sex_table, paste0(Output,"/", cur_date, "_Sex_Cytokine_Distribution.csv"), row.names= TRUE)
write.csv(age_table, paste0(Output,"/", cur_date, "_Age_Cytokine_Distribution.csv"), row.names= TRUE)
write.csv(bmi_table, paste0(Output,"/", cur_date, "_BMI_Cytokine_Distribution.csv"), row.names= TRUE)
