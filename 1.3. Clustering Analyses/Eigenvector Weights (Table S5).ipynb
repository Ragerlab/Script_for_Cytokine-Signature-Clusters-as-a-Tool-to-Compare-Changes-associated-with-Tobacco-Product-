# %%
setwd('/Users/alexis/IEHS Dropbox/Rager Lab/Alexis_Payton/4_Compartment_Analysis_2021/Expt1.3_Eigenvector Weights/Input')
Output = ('/Users/alexis/IEHS Dropbox/Rager Lab/Alexis_Payton/4_Compartment_Analysis_2021/Expt1.3_Eigenvector Weights/Output')
cur_date = "042121"

library(readxl)
library(data.table)
library(factoextra)
library(dplyr)
library(tidyverse)
library(gridExtra)
library(cluster)
library(vegan)
library(fpc)
library(ggdendro)
library(NbClust)
library(ggrepel)


#reading in file
cytokines <- data.frame(read_excel("CytokineData_032521.xlsx", sheet = 2))
# Out:
# Loading required package: ggplot2
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.0.6     ✔ purrr   0.3.4
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::between()   masks data.table::between()
# ✖ dplyr::filter()    masks stats::filter()
# ✖ dplyr::first()     masks data.table::first()
# ✖ dplyr::lag()       masks stats::lag()
# ✖ dplyr::last()      masks data.table::last()
# ✖ purrr::transpose() masks data.table::transpose()
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# Loading required package: permute
#
# Loading required package: lattice
#
# This is vegan 2.5-7

# %% [markdown]
# Code to obtain weights to figure out the degree to which each cytokine contributed to each eigenvector.
#
# # Validation Dataset Weights

# %%
new_dataset_only_cytokines = c("GMCSF", "IL12p40", "IL15", "IL16", "IL17","IL1a", "IL2", "IL5", "IL7", "MCP4", "MDC","TNFb", "VEGF")
`%notin%` <- Negate(`%in%`)
#changing format of df
cytokines = cytokines %>% 
    #only want non-smokers for baseline analysis & cytokines that were in the previous dataset
    filter(Group == 'NS', Protein %notin% new_dataset_only_cytokines)
cytokines = reshape2::dcast(cytokines, SubjectID ~ Protein, value.var = "Conc_pslog2") %>% 
    column_to_rownames("SubjectID")
#transposed to reduce dimensionality or variation of subjects into principal components
#allows us to determine what cytokines are driving clusters
tcytokines = data.frame(t(cytokines))
head(tcytokines)
# Out:
#          NS_1      NS_10    NS_11    NS_12    NS_13    NS_14    NS_15
# Eotaxin  6.7747713 7.961318 5.798693 5.606658 6.852042 9.230327 5.6911455
# Eotaxin3 7.3359976 3.561784 4.237103 3.133612 5.164080 7.794502 2.0189791
# IFNg     2.7048125 1.501174 4.414765 2.708182 3.038039 3.233542 1.8037654
# IL10     0.8786819 2.521602 3.887937 3.129121 3.572621 3.817435 1.9282279
# IL12p70  0.0000000 1.432708 4.383899 2.299339 1.830181 2.661157 0.6751787
# IL13     4.7858055 5.829412 7.105202 6.466481 6.184908 6.419010 4.4392043
#          NS_16    NS_17    NS_18    NS_19     NS_2      NS_20    NS_3
# Eotaxin  7.950870 7.570201 5.349512 5.8250758 7.1852235 8.714178  8.840770
# Eotaxin3 6.692010 5.525843 1.151684 5.2783081 4.0559827 6.266462 11.511480
# IFNg     3.695319 3.510235 1.645145 1.3414476 6.1204987 3.396166  5.172665
# IL10     3.902469 3.075462 1.025655 2.2546730 2.5890769 3.871091  6.251246
# IL12p70  3.400877 1.431968 1.213433 0.4728952 0.9169927 2.473645  4.267356
# IL13     7.017208 7.044898 4.762298 5.5844884 5.0105656 6.476432  6.860143
#          NS_4     NS_5     NS_6     NS_7     NS_8     NS_9
# Eotaxin  7.412499 7.258541 6.756939 7.605079 7.523347 6.0217081
# Eotaxin3 7.519546 2.954984 3.981245 6.156015 4.261894 3.3244167
# IFNg     3.824419 2.577966 2.973109 1.790451 3.597735 0.0000000
# IL10     4.898731 2.924778 3.748700 2.062107 3.695351 2.1734049
# IL12p70  3.706824 3.174891 2.489741 1.497252 2.911923 0.8209459
# IL13     6.608278 5.209837 6.016760 6.044381 5.992372 5.3379432

# %%
#obtaining clusters from kmeans to get cluster assignments
#previously decided on 3 clusters
k3_tcytokines = kmeans(tcytokines, centers = 3, nstart = 25)
clusters_tcytokines = data.frame(k3_tcytokines$cluster) %>%
    rename("Cluster" = "k3_tcytokines.cluster") 
head(clusters_tcytokines)
# Out:
#          Cluster
# Eotaxin  1
# Eotaxin3 1
# IFNg     2
# IL10     2
# IL12p70  2
# IL13     1

# %%
#now combining into 1 df
full_cytokine_df = data.frame(tcytokines, clusters_tcytokines) %>%
    #doing this so these row names are preserved when splitting df
    rownames_to_column(var = "Protein") %>%
    group_by(Cluster) %>%
    group_split

#obtaining each df after splitting
get_clustered_df = function(input_df, cluster_number){
    output_df = input_df[[cluster_number]] %>%
        column_to_rownames(var = "Protein") %>%
        select(-Cluster)
    return(output_df)
}

Cluster1_df = get_clustered_df(full_cytokine_df, 1)
Cluster2_df = get_clustered_df(full_cytokine_df, 2)
Cluster3_df = get_clustered_df(full_cytokine_df, 3)
head(Cluster3_df)
# Out:
#      NS_1     NS_10    NS_11    NS_12    NS_13    NS_14    NS_15     NS_16
# IL8  12.14873 13.22637 15.86950 14.80805 14.95516 15.43080 13.100360 17.56576
# IP10 12.63683 11.95278 12.13311 10.22781 10.30369 13.31953  8.237185 10.70468
#      NS_17    NS_18    NS_19     NS_2    NS_20    NS_3     NS_4     NS_5
# IL8  14.83894 13.25296 13.756103 12.3272 15.43934 18.34240 15.70105 14.025757
# IP10  0.00000 10.61925  8.918945  0.0000  0.00000 13.32016 11.95839  8.740187
#      NS_6     NS_7     NS_8     NS_9
# IL8  15.23992 13.02190 15.16104 12.87533
# IP10 10.22487  7.92967 15.58333 13.64136

# %%
#now we can run PCA on each
get_eigenvector_weights = function(df, cluster_name){
    pca = prcomp(df, scale = TRUE, center = TRUE)
    #x = values of each sample in terms of the principal components (ie. each cytokine's contribution to PC)
    #rotation = The relationship (correlation or anticorrelation, etc) between the initial variables and PCs
    pca_weights = data.frame(pca$x) %>% 
        #only returning first PC
        select(PC1) %>%
        plyr::rename(replace = c("PC1" = cluster_name)) %>%
        #this will make them easier to combine
        rownames_to_column(var = "Protein") %>%
        reshape2::melt(variable.name = "Cluster", value.name = "Weight")
        
            
    return(pca_weights)
}

#these correspond to previously established clusters
weights1_df = get_eigenvector_weights(Cluster1_df, "Cluster C") 
weights2_df = get_eigenvector_weights(Cluster2_df, "Cluster A")
weights3_df = get_eigenvector_weights(Cluster3_df, "Cluster B")
weights_df = rbind(weights1_df, weights2_df, weights3_df)
#adding compartment col
weights_df$Compartment = rep("NELF", times = length(weights_df$Protein))
#adding a column to specify that this is from the validation dataset
weights_df$Dataset = rep("Validation", times = length(weights_df$Protein))
head(weights_df)
# Out:
# Using Protein as id variables
#
# Using Protein as id variables
#
# Using Protein as id variables
#   Protein  Cluster   Weight     Compartment Dataset
# 1 Eotaxin  Cluster C -2.8002327 NELF        Validation
# 2 Eotaxin3 Cluster C  3.8300461 NELF        Validation
# 3 IL13     Cluster C  0.5233879 NELF        Validation
# 4 IL1b     Cluster C  1.4680325 NELF        Validation
# 5 MCP1     Cluster C -6.5713992 NELF        Validation
# 6 MIP1a    Cluster C  1.4779436 NELF        Validation

# %% [markdown]
# # Original Dataset Weights

# %%
#reading in file 
cytokines <- data.frame(read_excel("CytokineData_102920.xlsx", sheet = 2))

#transposing df first
cytokines = cytokines %>% 
    #only want non-smokers for baseline analysis
    filter(Group == 'NS') %>%
    group_by(Compartment) %>%
    group_split

reshape_cytokines = function(df, number){
    new_df = reshape2::dcast(df[[number]], SubjectID ~ Protein, value.var = "Conc_pslog2") %>% 
    column_to_rownames("SubjectID")
    new_df = data.frame(t(new_df))
    return(new_df)
}

#calling fn
tNLF = reshape_cytokines(cytokines, 2)
tNELF = reshape_cytokines(cytokines, 1)
tSputum = reshape_cytokines(cytokines, 4)
tSerum = reshape_cytokines(cytokines, 3)

#removing cytokines that are nondetect
temp_NLF = data.frame(t(tNLF))
temp_NLF$I309 = NULL
tNLF = data.frame(t(temp_NLF))
temp_Sputum = data.frame(t(tSputum))
temp_Sputum$I309 = NULL
tSputum = data.frame(t(temp_Sputum))
head(tNLF)
# Out:
#             NS_1       NS_10      NS_11      NS_12      NS_13      NS_14
# Eotaxin      3.6280396  6.8187682 3.33682808  5.0333418  6.1047951  5.7762171
# Eotaxin3     3.1961268  7.1675129 3.95125524  2.1919254  6.2414741  3.7784170
# Fractalkine 11.5876883 11.8757287 9.22145132 11.5378449 11.5230939 11.2549039
# IFNg         0.2638601  0.4323116 0.24860903  1.8025665  1.7756286  1.5545991
# IL10         0.1734701  0.1682226 0.08642643  0.3754869  0.3477679  0.5740857
# IL12p70      0.0000000  0.2376845 0.00000000  0.0000000  0.4038254  0.5678858
#             NS_2       NS_3       NS_4       NS_5       NS_6       NS_7
# Eotaxin     0.00000000  4.2097320  4.9384614  4.5968318  3.0585166  5.6634779
# Eotaxin3    3.20964831  5.0682269  3.5987808  2.6011813  1.3244504  5.0072047
# Fractalkine 7.81170469 10.0374539 10.6850491 11.0118375 10.7846908 11.4959189
# IFNg        0.00000000  0.1494616  0.8951656  5.8186862  0.3636737  0.8036332
# IL10        0.24341949  0.1561912  0.1550925  0.3022863  0.1194807  0.1833912
# IL12p70     0.08310156  0.0000000  0.5869011  1.0878560  0.0000000  0.6653735
#             NS_8       NS_9
# Eotaxin      6.6094316  4.90597963
# Eotaxin3     9.4070022  2.62280152
# Fractalkine 11.5096358 11.37872980
# IFNg         1.4807508  0.01754746
# IL10         1.1451618  0.06902558
# IL12p70      0.5077944  0.00000000

# %%
#obtaining clusters from kmeans to get cluster assignments
#previously decided on 3 clusters
get_clusters = function(df){
    k3_tcytokines = kmeans(df, centers = 3, nstart = 25)
    clusters_tcytokines = data.frame(k3_tcytokines$cluster) %>%
        rename("Cluster" = "k3_tcytokines.cluster") 
    return(clusters_tcytokines)
}
clusters_tNLF = get_clusters(tNLF)
clusters_tNELF = get_clusters(tNELF)
clusters_tSputum = get_clusters(tSputum)
clusters_tSerum = get_clusters(tSerum)
head(clusters_tNLF)
# Out:
#             Cluster
# Eotaxin     1
# Eotaxin3    1
# Fractalkine 3
# IFNg        2
# IL10        2
# IL12p70     2

# %%
get_clustered_df = function(tcytokines_df, tclusters_df, cluster_number){
    #now combining into 1 df
    full_cytokine_df = data.frame(tcytokines_df, tclusters_df) %>%
        #doing this so these row names are preserved when splitting df
        rownames_to_column(var = "Protein") %>%
        group_by(Cluster) %>%
        group_split
    
    #obtaining each df after splitting
    output_df = full_cytokine_df[[cluster_number]] %>%
        column_to_rownames(var = "Protein") %>%
        select(-Cluster)
    return(output_df)
}

#NLF
NLF_Cluster1_df = get_clustered_df(tNLF, clusters_tNLF, 1)
NLF_Cluster2_df = get_clustered_df(tNLF, clusters_tNLF, 2)
NLF_Cluster3_df = get_clustered_df(tNLF, clusters_tNLF, 3)
head(NLF_Cluster3_df)

#NELF
NELF_Cluster1_df = get_clustered_df(tNELF, clusters_tNELF, 1)
NELF_Cluster2_df = get_clustered_df(tNELF, clusters_tNELF, 2)
NELF_Cluster3_df = get_clustered_df(tNELF, clusters_tNELF, 3)

#Sputum
Sputum_Cluster1_df = get_clustered_df(tSputum, clusters_tSputum, 1)
Sputum_Cluster2_df = get_clustered_df(tSputum, clusters_tSputum, 2)
Sputum_Cluster3_df = get_clustered_df(tSputum, clusters_tSputum, 3)

#Serum
Serum_Cluster1_df = get_clustered_df(tSerum, clusters_tSerum, 1)
Serum_Cluster2_df = get_clustered_df(tSerum, clusters_tSerum, 2)
Serum_Cluster3_df = get_clustered_df(tSerum, clusters_tSerum, 3)
# Out:
#             NS_1      NS_10     NS_11    NS_12     NS_13     NS_14    NS_2
# Fractalkine 11.587688 11.875729 9.221451 11.537845 11.523094 11.25490 7.811705
# IL8         10.212021 11.078729 9.685325 11.023798  9.530267 10.38829 8.060430
# IP10         8.062337 10.757725 8.926272 12.215292 11.066588 12.50019 4.855869
# MIG         11.683005  8.336243 6.510956  7.143335 12.035249 13.84042 9.365894
#             NS_3      NS_4      NS_5      NS_6      NS_7      NS_8
# Fractalkine 10.037454 10.685049 11.011838 10.784691 11.495919 11.509636
# IL8          9.618243  9.667124 10.993323  7.769040  9.970973 12.153517
# IP10         8.265443  0.000000  0.000000  5.862039 16.373484 12.324919
# MIG          6.005208 11.016590  9.904974  4.977772  7.124912  8.980772
#             NS_9
# Fractalkine 11.378730
# IL8          8.987441
# IP10        10.053841
# MIG          7.113998

# %%
#running pca on each using function above to get weights
#these correspond to previously established clusters
#NLF
NLF_weights1_df = get_eigenvector_weights(NLF_Cluster1_df, "Cluster A") 
NLF_weights2_df = get_eigenvector_weights(NLF_Cluster2_df, "Cluster B")
NLF_weights3_df = get_eigenvector_weights(NLF_Cluster3_df, "Cluster C")

#NELF
NELF_weights1_df = get_eigenvector_weights(NELF_Cluster1_df, "Cluster C") 
NELF_weights2_df = get_eigenvector_weights(NELF_Cluster2_df, "Cluster A")
NELF_weights3_df = get_eigenvector_weights(NELF_Cluster3_df, "Cluster B")

#Sputum
Sputum_weights1_df = get_eigenvector_weights(Sputum_Cluster1_df, "Cluster B") 
Sputum_weights2_df = get_eigenvector_weights(Sputum_Cluster2_df, "Cluster A")
Sputum_weights3_df = get_eigenvector_weights(Sputum_Cluster3_df, "Cluster C")

#Serum
Serum_weights1_df = get_eigenvector_weights(Serum_Cluster1_df, "Cluster C") 
Serum_weights2_df = get_eigenvector_weights(Serum_Cluster2_df, "Cluster A")
Serum_weights3_df = get_eigenvector_weights(Serum_Cluster3_df, "Cluster B")
# Out:
# Using Protein as id variables
#
# Using Protein as id variables
#
# Using Protein as id variables
#
# Using Protein as id variables
#
# Using Protein as id variables
#
# Using Protein as id variables
#
# Using Protein as id variables
#
# Using Protein as id variables
#
# Using Protein as id variables
#
# Using Protein as id variables
#
# Using Protein as id variables
#
# Using Protein as id variables

# %%
get_final_df = function(weights1, weights2, weights3, compartment_name){
    weights_df = rbind(weights1, weights2, weights3)
    #adding compartment col
    weights_df$Compartment = rep(compartment_name, times = length(weights_df$Protein))
    #adding a column to specify that this is from the validation dataset
    weights_df$Dataset = rep("Original", times = length(weights_df$Protein))
    return(weights_df)
}

#calling fn
NLF_weights = get_final_df(NLF_weights1_df, NLF_weights2_df, NLF_weights3_df, "NLF")
NELF_weights = get_final_df(NELF_weights1_df, NELF_weights2_df, NELF_weights3_df, "NELF")
Sputum_weights = get_final_df(Sputum_weights1_df, Sputum_weights2_df, Sputum_weights3_df, "Sputum")
Serum_weights = get_final_df(Serum_weights1_df, Serum_weights2_df, Serum_weights3_df, "Serum")

#combining all weights into one final df
final_weights_df = rbind(weights_df, NLF_weights, NELF_weights, Sputum_weights, Serum_weights)

# %%
#exporting
write.csv(final_weights_df, paste0(Output,"/", cur_date, "_eigenvector_weights.csv"), row.names = FALSE)
