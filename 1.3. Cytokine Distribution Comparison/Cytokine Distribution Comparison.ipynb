# %%
setwd('/Users/alexis/IEHS Dropbox/Rager Lab/Alexis_Payton/1_Compartment_Analysis/Expt1.1_DescriptiveStats/Input')
Output = ('/Users/alexis/IEHS Dropbox/Rager Lab/Alexis_Payton/1_Compartment_Analysis/Expt1.2_Cytokine Distribution Analyses/Output')
cur_date = '120520'

library("readxl")
library(tidyverse)
library(reshape2)

#reading in file
data <- read_excel("CytokineData_102920.xlsx", sheet = 2)
data_df = data.frame(data)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths

# %%
head(data_df)
# Out:
#   Original_Identifier Protein Conc       Conc_pslog2 Compartment SubjectNo
# 1 E_C_F_002           IFNg     17.642316 4.220509    ELF         1
# 2 E_C_F_002           IL10      2.873724 1.953721    ELF         1
# 3 E_C_F_002           IL12p70   1.625272 1.392467    ELF         1
# 4 E_C_F_002           IL13     36.117692 5.214035    ELF         1
# 5 E_C_F_002           IL1b    104.409217 6.719857    ELF         1
# 6 E_C_F_002           IL6      21.159536 4.469856    ELF         1
#   Group SubjectID
# 1 NS    NS_1
# 2 NS    NS_1
# 3 NS    NS_1
# 4 NS    NS_1
# 5 NS    NS_1
# 6 NS    NS_1

# %% [markdown]
# ## How do baseline cytokine profiles differ across compartments, especially in comparison to NLF (gold standard of source of cytokine samples)?

# %% [markdown]
# Previous Wilcoxon rank sum test results comparing cytokine concentrations across compartments revealed each had different distributions (p < 0.05) with the exception of ELF and Serum. Running individual wilcox tests to see if this trend persists with individual cytokines.

# %%
get_Eotaxin_list = function(filename,compartment_type){
    Eotaxin_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'Eotaxin'){
                Eotaxin_concentration_list = c(Eotaxin_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(Eotaxin_concentration_list)
}
get_Eotaxin3_list = function(filename,compartment_type){
    Eotaxin3_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'Eotaxin3'){
                Eotaxin3_concentration_list = c(Eotaxin3_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(Eotaxin3_concentration_list)
}
get_Fractalkine_list = function(filename,compartment_type){
    Fractalkine_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'Fractalkine'){
                Fractalkine_concentration_list = c(Fractalkine_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(Fractalkine_concentration_list)
}
get_I309_list = function(filename,compartment_type){
    I309_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'I309'){
                I309_concentration_list = c(I309_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(I309_concentration_list)
}
get_IFNg_list = function(filename,compartment_type){
    IFNg_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'IFNg'){
                IFNg_concentration_list = c(IFNg_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(IFNg_concentration_list)
}
get_IL10_list = function(filename,compartment_type){
    IL10_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'IL10'){
                IL10_concentration_list = c(IL10_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(IL10_concentration_list)
}
get_IL12p70_list = function(filename,compartment_type){
    IL12p70_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'IL12p70'){
                IL12p70_concentration_list = c(IL12p70_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(IL12p70_concentration_list)
}
get_IL13_list = function(filename,compartment_type){
    IL13_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'IL13'){
                IL13_concentration_list = c(IL13_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(IL13_concentration_list)
}
get_IL17B_list = function(filename,compartment_type){
    IL17B_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'IL17B'){
                IL17B_concentration_list = c(IL17B_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(IL17B_concentration_list)
}
get_IL17D_list = function(filename,compartment_type){
    IL17D_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'IL17D'){
                IL17D_concentration_list = c(IL17D_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(IL17D_concentration_list)
}
get_IL1b_list = function(filename,compartment_type){
    IL1b_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'IL1b'){
                IL1b_concentration_list = c(IL1b_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(IL1b_concentration_list)
}
get_IL4_list = function(filename,compartment_type){
    IL4_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'IL4'){
                IL4_concentration_list = c(IL4_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(IL4_concentration_list)
}

get_IL6_list = function(filename,compartment_type){
    IL6_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'IL6'){
                IL6_concentration_list = c(IL6_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(IL6_concentration_list)
}
get_IL8_list = function(filename,compartment_type){
    IL8_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'IL8'){
                IL8_concentration_list = c(IL8_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(IL8_concentration_list)
}
get_IP10_list = function(filename,compartment_type){
    IP10_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'IP10'){
                IP10_concentration_list = c(IP10_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(IP10_concentration_list)
}
get_ITAC_list = function(filename,compartment_type){
    ITAC_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'ITAC'){
                ITAC_concentration_list = c(ITAC_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(ITAC_concentration_list)
}
get_MCP1_list = function(filename,compartment_type){
    MCP1_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'MCP1'){
                MCP1_concentration_list = c(MCP1_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(MCP1_concentration_list)
}
get_MIG_list = function(filename,compartment_type){
    MIG_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'MIG'){
                MIG_concentration_list = c(MIG_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(MIG_concentration_list)
}
get_MIP1a_list = function(filename,compartment_type){
    MIP1a_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'MIP1a'){
                MIP1a_concentration_list = c(MIP1a_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(MIP1a_concentration_list)
}
get_MIP1b_list = function(filename,compartment_type){
    MIP1b_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'MIP1b'){
                MIP1b_concentration_list = c(MIP1b_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(MIP1b_concentration_list)
}
get_TARC_list = function(filename,compartment_type){
    TARC_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'TARC'){
                TARC_concentration_list = c(TARC_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(TARC_concentration_list)
}
get_TNFa_list = function(filename,compartment_type){
    TNFa_concentration_list = c()
    for (i in 1:length(filename$Compartment)){
        if (filename$Compartment[i] == compartment_type & filename$Group[i] == 'NS'){
            if (filename$Protein[i] == 'TNFa'){
                TNFa_concentration_list = c(TNFa_concentration_list, filename$Conc_pslog2[i])
            }
        }
    }
    return(TNFa_concentration_list)
}

# %%
#calling all concentration list functions
Eotaxin_concentration_list_NLF = get_Eotaxin_list(data_df,'NLF')
Eotaxin3_concentration_list_NLF = get_Eotaxin3_list(data_df,'NLF')
Fractalkine_concentration_list_NLF = get_Fractalkine_list(data_df,'NLF')
I309_concentration_list_NLF = get_I309_list(data_df,'NLF')
IFNg_concentration_list_NLF = get_IFNg_list(data_df,'NLF')
IL10_concentration_list_NLF = get_IL10_list(data_df,'NLF')
IL12p70_concentration_list_NLF = get_IL12p70_list(data_df,'NLF')
IL13_concentration_list_NLF = get_IL13_list(data_df,'NLF')
IL17B_concentration_list_NLF = get_IL17B_list(data_df,'NLF')
IL17D_concentration_list_NLF = get_IL17D_list(data_df,'NLF')
IL1b_concentration_list_NLF = get_IL1b_list(data_df,'NLF')
IL4_concentration_list_NLF = get_IL4_list(data_df,'NLF')
IL6_concentration_list_NLF = get_IL6_list(data_df,'NLF')
IL8_concentration_list_NLF = get_IL8_list(data_df,'NLF')
IP10_concentration_list_NLF = get_IP10_list(data_df,'NLF')
ITAC_concentration_list_NLF = get_ITAC_list(data_df,'NLF')
MCP1_concentration_list_NLF = get_MCP1_list(data_df,'NLF')
MIG_concentration_list_NLF = get_MIG_list(data_df,'NLF')
MIP1a_concentration_list_NLF = get_MIP1a_list(data_df,'NLF')
MIP1b_concentration_list_NLF = get_MIP1b_list(data_df,'NLF')
TARC_concentration_list_NLF = get_TARC_list(data_df,'NLF')
TNFa_concentration_list_NLF = get_TNFa_list(data_df,'NLF')  

Eotaxin_concentration_list_ELF = get_Eotaxin_list(data_df,'ELF')
Eotaxin3_concentration_list_ELF = get_Eotaxin3_list(data_df,'ELF')
Fractalkine_concentration_list_ELF = get_Fractalkine_list(data_df,'ELF')
I309_concentration_list_ELF = get_I309_list(data_df,'ELF')
IFNg_concentration_list_ELF = get_IFNg_list(data_df,'ELF')
IL10_concentration_list_ELF = get_IL10_list(data_df,'ELF')
IL12p70_concentration_list_ELF = get_IL12p70_list(data_df,'ELF')
IL13_concentration_list_ELF = get_IL13_list(data_df,'ELF')
IL17B_concentration_list_ELF = get_IL17B_list(data_df,'ELF')
IL17D_concentration_list_ELF = get_IL17D_list(data_df,'ELF')
IL1b_concentration_list_ELF = get_IL1b_list(data_df,'ELF')
IL4_concentration_list_ELF = get_IL4_list(data_df,'ELF')
IL6_concentration_list_ELF = get_IL6_list(data_df,'ELF')
IL8_concentration_list_ELF = get_IL8_list(data_df,'ELF')
IP10_concentration_list_ELF = get_IP10_list(data_df,'ELF')
ITAC_concentration_list_ELF = get_ITAC_list(data_df,'ELF')
MCP1_concentration_list_ELF = get_MCP1_list(data_df,'ELF')
MIG_concentration_list_ELF = get_MIG_list(data_df,'ELF')
MIP1a_concentration_list_ELF = get_MIP1a_list(data_df,'ELF')
MIP1b_concentration_list_ELF = get_MIP1b_list(data_df,'ELF')
TARC_concentration_list_ELF = get_TARC_list(data_df,'ELF')
TNFa_concentration_list_ELF = get_TNFa_list(data_df,'ELF')  

Eotaxin_concentration_list_Sputum = get_Eotaxin_list(data_df,'Sputum')
Eotaxin3_concentration_list_Sputum = get_Eotaxin3_list(data_df,'Sputum')
Fractalkine_concentration_list_Sputum = get_Fractalkine_list(data_df,'Sputum')
I309_concentration_list_Sputum = get_I309_list(data_df,'Sputum')
IFNg_concentration_list_Sputum = get_IFNg_list(data_df,'Sputum')
IL10_concentration_list_Sputum = get_IL10_list(data_df,'Sputum')
IL12p70_concentration_list_Sputum = get_IL12p70_list(data_df,'Sputum')
IL13_concentration_list_Sputum = get_IL13_list(data_df,'Sputum')
IL17B_concentration_list_Sputum = get_IL17B_list(data_df,'Sputum')
IL17D_concentration_list_Sputum = get_IL17D_list(data_df,'Sputum')
IL1b_concentration_list_Sputum = get_IL1b_list(data_df,'Sputum')
IL4_concentration_list_Sputum = get_IL4_list(data_df,'Sputum')
IL6_concentration_list_Sputum = get_IL6_list(data_df,'Sputum')
IL8_concentration_list_Sputum = get_IL8_list(data_df,'Sputum')
IP10_concentration_list_Sputum = get_IP10_list(data_df,'Sputum')
ITAC_concentration_list_Sputum = get_ITAC_list(data_df,'Sputum')
MCP1_concentration_list_Sputum = get_MCP1_list(data_df,'Sputum')
MIG_concentration_list_Sputum = get_MIG_list(data_df,'Sputum')
MIP1a_concentration_list_Sputum = get_MIP1a_list(data_df,'Sputum')
MIP1b_concentration_list_Sputum = get_MIP1b_list(data_df,'Sputum')
TARC_concentration_list_Sputum = get_TARC_list(data_df,'Sputum')
TNFa_concentration_list_Sputum = get_TNFa_list(data_df,'Sputum')  

Eotaxin_concentration_list_Serum = get_Eotaxin_list(data_df,'Serum')
Eotaxin3_concentration_list_Serum = get_Eotaxin3_list(data_df,'Serum')
Fractalkine_concentration_list_Serum = get_Fractalkine_list(data_df,'Serum')
I309_concentration_list_Serum = get_I309_list(data_df,'Serum')
IFNg_concentration_list_Serum = get_IFNg_list(data_df,'Serum')
IL10_concentration_list_Serum = get_IL10_list(data_df,'Serum')
IL12p70_concentration_list_Serum = get_IL12p70_list(data_df,'Serum')
IL13_concentration_list_Serum = get_IL13_list(data_df,'Serum')
IL17B_concentration_list_Serum = get_IL17B_list(data_df,'Serum')
IL17D_concentration_list_Serum = get_IL17D_list(data_df,'Serum')
IL1b_concentration_list_Serum = get_IL1b_list(data_df,'Serum')
IL4_concentration_list_Serum = get_IL4_list(data_df,'Serum')
IL6_concentration_list_Serum = get_IL6_list(data_df,'Serum')
IL8_concentration_list_Serum = get_IL8_list(data_df,'Serum')
IP10_concentration_list_Serum = get_IP10_list(data_df,'Serum')
ITAC_concentration_list_Serum = get_ITAC_list(data_df,'Serum')
MCP1_concentration_list_Serum = get_MCP1_list(data_df,'Serum')
MIG_concentration_list_Serum = get_MIG_list(data_df,'Serum')
MIP1a_concentration_list_Serum = get_MIP1a_list(data_df,'Serum')
MIP1b_concentration_list_Serum = get_MIP1b_list(data_df,'Serum')
TARC_concentration_list_Serum = get_TARC_list(data_df,'Serum')
TNFa_concentration_list_Serum = get_TNFa_list(data_df,'Serum')

# %%
#running wilcox tests
#NLF vs. ELF
Eotaxin_NLF_ELF = wilcox.test(Eotaxin_concentration_list_NLF, Eotaxin_concentration_list_ELF)
Eotaxin3_NLF_ELF = wilcox.test(Eotaxin3_concentration_list_NLF, Eotaxin3_concentration_list_ELF)
Fractalkine_NLF_ELF = wilcox.test(Fractalkine_concentration_list_NLF, Fractalkine_concentration_list_ELF)
I309_NLF_ELF = wilcox.test(I309_concentration_list_NLF, I309_concentration_list_ELF)
IFNg_NLF_ELF = wilcox.test(IFNg_concentration_list_NLF, IFNg_concentration_list_ELF)
IL10_NLF_ELF = wilcox.test(IL10_concentration_list_NLF, IL10_concentration_list_ELF)
IL12p70_NLF_ELF = wilcox.test(IL12p70_concentration_list_NLF, IL12p70_concentration_list_ELF)
IL13_NLF_ELF = wilcox.test(IL13_concentration_list_NLF, IL13_concentration_list_ELF)
IL17B_NLF_ELF = wilcox.test(IL17B_concentration_list_NLF, IL17B_concentration_list_ELF)
IL17D_NLF_ELF = wilcox.test(IL17D_concentration_list_NLF, IL17D_concentration_list_ELF)
IL1b_NLF_ELF = wilcox.test(IL1b_concentration_list_NLF, IL1b_concentration_list_ELF)
IL4_NLF_ELF = wilcox.test(IL4_concentration_list_NLF, IL4_concentration_list_ELF)
IL6_NLF_ELF = wilcox.test(IL6_concentration_list_NLF, IL6_concentration_list_ELF)
IL8_NLF_ELF = wilcox.test(IL8_concentration_list_NLF, IL8_concentration_list_ELF)
IP10_NLF_ELF = wilcox.test(IP10_concentration_list_NLF, IP10_concentration_list_ELF)
ITAC_NLF_ELF = wilcox.test(ITAC_concentration_list_NLF, ITAC_concentration_list_ELF)
MCP1_NLF_ELF = wilcox.test(MCP1_concentration_list_NLF, MCP1_concentration_list_ELF)
MIG_NLF_ELF = wilcox.test(MIG_concentration_list_NLF, MIG_concentration_list_ELF)
MIP1a_NLF_ELF = wilcox.test(MIP1a_concentration_list_NLF, MIP1a_concentration_list_ELF)
MIP1b_NLF_ELF = wilcox.test(MIP1b_concentration_list_NLF, MIP1b_concentration_list_ELF)
TARC_NLF_ELF = wilcox.test(TARC_concentration_list_NLF, TARC_concentration_list_ELF)
TNFa_NLF_ELF = wilcox.test(TNFa_concentration_list_NLF, TNFa_concentration_list_ELF)

#NLF vs. Sputum
Eotaxin_NLF_Sputum = wilcox.test(Eotaxin_concentration_list_NLF, Eotaxin_concentration_list_Sputum)
Eotaxin3_NLF_Sputum = wilcox.test(Eotaxin3_concentration_list_NLF, Eotaxin3_concentration_list_Sputum)
Fractalkine_NLF_Sputum = wilcox.test(Fractalkine_concentration_list_NLF, Fractalkine_concentration_list_Sputum)
I309_NLF_Sputum = wilcox.test(I309_concentration_list_NLF, I309_concentration_list_Sputum)
IFNg_NLF_Sputum = wilcox.test(IFNg_concentration_list_NLF, IFNg_concentration_list_Sputum)
IL10_NLF_Sputum = wilcox.test(IL10_concentration_list_NLF, IL10_concentration_list_Sputum)
IL12p70_NLF_Sputum = wilcox.test(IL12p70_concentration_list_NLF, IL12p70_concentration_list_Sputum)
IL13_NLF_Sputum = wilcox.test(IL13_concentration_list_NLF, IL13_concentration_list_Sputum)
IL17B_NLF_Sputum = wilcox.test(IL17B_concentration_list_NLF, IL17B_concentration_list_Sputum)
IL17D_NLF_Sputum = wilcox.test(IL17D_concentration_list_NLF, IL17D_concentration_list_Sputum)
IL1b_NLF_Sputum = wilcox.test(IL1b_concentration_list_NLF, IL1b_concentration_list_Sputum)
IL4_NLF_Sputum = wilcox.test(IL4_concentration_list_NLF, IL4_concentration_list_Sputum)
IL6_NLF_Sputum = wilcox.test(IL6_concentration_list_NLF, IL6_concentration_list_Sputum)
IL8_NLF_Sputum = wilcox.test(IL8_concentration_list_NLF, IL8_concentration_list_Sputum)
IP10_NLF_Sputum = wilcox.test(IP10_concentration_list_NLF, IP10_concentration_list_Sputum)
ITAC_NLF_Sputum = wilcox.test(ITAC_concentration_list_NLF, ITAC_concentration_list_Sputum)
MCP1_NLF_Sputum = wilcox.test(MCP1_concentration_list_NLF, MCP1_concentration_list_Sputum)
MIG_NLF_Sputum = wilcox.test(MIG_concentration_list_NLF, MIG_concentration_list_Sputum)
MIP1a_NLF_Sputum = wilcox.test(MIP1a_concentration_list_NLF, MIP1a_concentration_list_Sputum)
MIP1b_NLF_Sputum = wilcox.test(MIP1b_concentration_list_NLF, MIP1b_concentration_list_Sputum)
TARC_NLF_Sputum = wilcox.test(TARC_concentration_list_NLF, TARC_concentration_list_Sputum)
TNFa_NLF_Sputum = wilcox.test(TNFa_concentration_list_NLF, TNFa_concentration_list_Sputum)

#NLF vs. Serum
Eotaxin_NLF_Serum = wilcox.test(Eotaxin_concentration_list_NLF, Eotaxin_concentration_list_Serum)
Eotaxin3_NLF_Serum = wilcox.test(Eotaxin3_concentration_list_NLF, Eotaxin3_concentration_list_Serum)
Fractalkine_NLF_Serum = wilcox.test(Fractalkine_concentration_list_NLF, Fractalkine_concentration_list_Serum)
I309_NLF_Serum = wilcox.test(I309_concentration_list_NLF, I309_concentration_list_Serum)
IFNg_NLF_Serum = wilcox.test(IFNg_concentration_list_NLF, IFNg_concentration_list_Serum)
IL10_NLF_Serum = wilcox.test(IL10_concentration_list_NLF, IL10_concentration_list_Serum)
IL12p70_NLF_Serum = wilcox.test(IL12p70_concentration_list_NLF, IL12p70_concentration_list_Serum)
IL13_NLF_Serum = wilcox.test(IL13_concentration_list_NLF, IL13_concentration_list_Serum)
IL17B_NLF_Serum = wilcox.test(IL17B_concentration_list_NLF, IL17B_concentration_list_Serum)
IL17D_NLF_Serum = wilcox.test(IL17D_concentration_list_NLF, IL17D_concentration_list_Serum)
IL1b_NLF_Serum = wilcox.test(IL1b_concentration_list_NLF, IL1b_concentration_list_Serum)
IL4_NLF_Serum = wilcox.test(IL4_concentration_list_NLF, IL4_concentration_list_Serum)
IL6_NLF_Serum = wilcox.test(IL6_concentration_list_NLF, IL6_concentration_list_Serum)
IL8_NLF_Serum = wilcox.test(IL8_concentration_list_NLF, IL8_concentration_list_Serum)
IP10_NLF_Serum = wilcox.test(IP10_concentration_list_NLF, IP10_concentration_list_Serum)
ITAC_NLF_Serum = wilcox.test(ITAC_concentration_list_NLF, ITAC_concentration_list_Serum)
MCP1_NLF_Serum = wilcox.test(MCP1_concentration_list_NLF, MCP1_concentration_list_Serum)
MIG_NLF_Serum = wilcox.test(MIG_concentration_list_NLF, MIG_concentration_list_Serum)
MIP1a_NLF_Serum = wilcox.test(MIP1a_concentration_list_NLF, MIP1a_concentration_list_Serum)
MIP1b_NLF_Serum = wilcox.test(MIP1b_concentration_list_NLF, MIP1b_concentration_list_Serum)
TARC_NLF_Serum = wilcox.test(TARC_concentration_list_NLF, TARC_concentration_list_Serum)
TNFa_NLF_Serum = wilcox.test(TNFa_concentration_list_NLF, TNFa_concentration_list_Serum)

#ELF vs. Sputum
Eotaxin_ELF_Sputum = wilcox.test(Eotaxin_concentration_list_ELF, Eotaxin_concentration_list_Sputum)
Eotaxin3_ELF_Sputum = wilcox.test(Eotaxin3_concentration_list_ELF, Eotaxin3_concentration_list_Sputum)
Fractalkine_ELF_Sputum = wilcox.test(Fractalkine_concentration_list_ELF, Fractalkine_concentration_list_Sputum)
I309_ELF_Sputum = wilcox.test(I309_concentration_list_ELF, I309_concentration_list_Sputum)
IFNg_ELF_Sputum = wilcox.test(IFNg_concentration_list_ELF, IFNg_concentration_list_Sputum)
IL10_ELF_Sputum = wilcox.test(IL10_concentration_list_ELF, IL10_concentration_list_Sputum)
IL12p70_ELF_Sputum = wilcox.test(IL12p70_concentration_list_ELF, IL12p70_concentration_list_Sputum)
IL13_ELF_Sputum = wilcox.test(IL13_concentration_list_ELF, IL13_concentration_list_Sputum)
IL17B_ELF_Sputum = wilcox.test(IL17B_concentration_list_ELF, IL17B_concentration_list_Sputum)
IL17D_ELF_Sputum = wilcox.test(IL17D_concentration_list_ELF, IL17D_concentration_list_Sputum)
IL1b_ELF_Sputum = wilcox.test(IL1b_concentration_list_ELF, IL1b_concentration_list_Sputum)
IL4_ELF_Sputum = wilcox.test(IL4_concentration_list_ELF, IL4_concentration_list_Sputum)
IL6_ELF_Sputum = wilcox.test(IL6_concentration_list_ELF, IL6_concentration_list_Sputum)
IL8_ELF_Sputum = wilcox.test(IL8_concentration_list_ELF, IL8_concentration_list_Sputum)
IP10_ELF_Sputum = wilcox.test(IP10_concentration_list_ELF, IP10_concentration_list_Sputum)
ITAC_ELF_Sputum = wilcox.test(ITAC_concentration_list_ELF, ITAC_concentration_list_Sputum)
MCP1_ELF_Sputum = wilcox.test(MCP1_concentration_list_ELF, MCP1_concentration_list_Sputum)
MIG_ELF_Sputum = wilcox.test(MIG_concentration_list_ELF, MIG_concentration_list_Sputum)
MIP1a_ELF_Sputum = wilcox.test(MIP1a_concentration_list_ELF, MIP1a_concentration_list_Sputum)
MIP1b_ELF_Sputum = wilcox.test(MIP1b_concentration_list_ELF, MIP1b_concentration_list_Sputum)
TARC_ELF_Sputum = wilcox.test(TARC_concentration_list_ELF, TARC_concentration_list_Sputum)
TNFa_ELF_Sputum = wilcox.test(TNFa_concentration_list_ELF, TNFa_concentration_list_Sputum)

#ELF vs. Serum
Eotaxin_ELF_Serum = wilcox.test(Eotaxin_concentration_list_ELF, Eotaxin_concentration_list_Serum)
Eotaxin3_ELF_Serum = wilcox.test(Eotaxin3_concentration_list_ELF, Eotaxin3_concentration_list_Serum)
Fractalkine_ELF_Serum = wilcox.test(Fractalkine_concentration_list_ELF, Fractalkine_concentration_list_Serum)
I309_ELF_Serum = wilcox.test(I309_concentration_list_ELF, I309_concentration_list_Serum)
IFNg_ELF_Serum = wilcox.test(IFNg_concentration_list_ELF, IFNg_concentration_list_Serum)
IL10_ELF_Serum = wilcox.test(IL10_concentration_list_ELF, IL10_concentration_list_Serum)
IL12p70_ELF_Serum = wilcox.test(IL12p70_concentration_list_ELF, IL12p70_concentration_list_Serum)
IL13_ELF_Serum = wilcox.test(IL13_concentration_list_ELF, IL13_concentration_list_Serum)
IL17B_ELF_Serum = wilcox.test(IL17B_concentration_list_ELF, IL17B_concentration_list_Serum)
IL17D_ELF_Serum = wilcox.test(IL17D_concentration_list_ELF, IL17D_concentration_list_Serum)
IL1b_ELF_Serum = wilcox.test(IL1b_concentration_list_ELF, IL1b_concentration_list_Serum)
IL4_ELF_Serum = wilcox.test(IL4_concentration_list_ELF, IL4_concentration_list_Serum)
IL6_ELF_Serum = wilcox.test(IL6_concentration_list_ELF, IL6_concentration_list_Serum)
IL8_ELF_Serum = wilcox.test(IL8_concentration_list_ELF, IL8_concentration_list_Serum)
IP10_ELF_Serum = wilcox.test(IP10_concentration_list_ELF, IP10_concentration_list_Serum)
ITAC_ELF_Serum = wilcox.test(ITAC_concentration_list_ELF, ITAC_concentration_list_Serum)
MCP1_ELF_Serum = wilcox.test(MCP1_concentration_list_ELF, MCP1_concentration_list_Serum)
MIG_ELF_Serum = wilcox.test(MIG_concentration_list_ELF, MIG_concentration_list_Serum)
MIP1a_ELF_Serum = wilcox.test(MIP1a_concentration_list_ELF, MIP1a_concentration_list_Serum)
MIP1b_ELF_Serum = wilcox.test(MIP1b_concentration_list_ELF, MIP1b_concentration_list_Serum)
TARC_ELF_Serum = wilcox.test(TARC_concentration_list_ELF, TARC_concentration_list_Serum)
TNFa_ELF_Serum = wilcox.test(TNFa_concentration_list_ELF, TNFa_concentration_list_Serum)

#Sputum vs. Serum
Eotaxin_Sputum_Serum = wilcox.test(Eotaxin_concentration_list_Sputum, Eotaxin_concentration_list_Serum)
Eotaxin3_Sputum_Serum = wilcox.test(Eotaxin3_concentration_list_Sputum, Eotaxin3_concentration_list_Serum)
Fractalkine_Sputum_Serum = wilcox.test(Fractalkine_concentration_list_Sputum, Fractalkine_concentration_list_Serum)
I309_Sputum_Serum = wilcox.test(I309_concentration_list_Sputum, I309_concentration_list_Serum)
IFNg_Sputum_Serum = wilcox.test(IFNg_concentration_list_Sputum, IFNg_concentration_list_Serum)
IL10_Sputum_Serum = wilcox.test(IL10_concentration_list_Sputum, IL10_concentration_list_Serum)
IL12p70_Sputum_Serum = wilcox.test(IL12p70_concentration_list_Sputum, IL12p70_concentration_list_Serum)
IL13_Sputum_Serum = wilcox.test(IL13_concentration_list_Sputum, IL13_concentration_list_Serum)
IL17B_Sputum_Serum = wilcox.test(IL17B_concentration_list_Sputum, IL17B_concentration_list_Serum)
IL17D_Sputum_Serum = wilcox.test(IL17D_concentration_list_Sputum, IL17D_concentration_list_Serum)
IL1b_Sputum_Serum = wilcox.test(IL1b_concentration_list_Sputum, IL1b_concentration_list_Serum)
IL4_Sputum_Serum = wilcox.test(IL4_concentration_list_Sputum, IL4_concentration_list_Serum)
IL6_Sputum_Serum = wilcox.test(IL6_concentration_list_Sputum, IL6_concentration_list_Serum)
IL8_Sputum_Serum = wilcox.test(IL8_concentration_list_Sputum, IL8_concentration_list_Serum)
IP10_Sputum_Serum = wilcox.test(IP10_concentration_list_Sputum, IP10_concentration_list_Serum)
ITAC_Sputum_Serum = wilcox.test(ITAC_concentration_list_Sputum, ITAC_concentration_list_Serum)
MCP1_Sputum_Serum = wilcox.test(MCP1_concentration_list_Sputum, MCP1_concentration_list_Serum)
MIG_Sputum_Serum = wilcox.test(MIG_concentration_list_Sputum, MIG_concentration_list_Serum)
MIP1a_Sputum_Serum = wilcox.test(MIP1a_concentration_list_Sputum, MIP1a_concentration_list_Serum)
MIP1b_Sputum_Serum = wilcox.test(MIP1b_concentration_list_Sputum, MIP1b_concentration_list_Serum)
TARC_Sputum_Serum = wilcox.test(TARC_concentration_list_Sputum, TARC_concentration_list_Serum)
TNFa_Sputum_Serum = wilcox.test(TNFa_concentration_list_Sputum, TNFa_concentration_list_Serum)
# Out:
# Warning message in wilcox.test.default(I309_concentration_list_NLF, I309_concentration_list_ELF):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(IFNg_concentration_list_NLF, IFNg_concentration_list_ELF):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(IL10_concentration_list_NLF, IL10_concentration_list_ELF):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(IL12p70_concentration_list_NLF, IL12p70_concentration_list_ELF):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(IL17B_concentration_list_NLF, IL17B_concentration_list_ELF):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(IL17D_concentration_list_NLF, IL17D_concentration_list_ELF):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(IL4_concentration_list_NLF, IL4_concentration_list_ELF):
# ...

# %%
get_stat_pvalue_tuple = function(wilcox_test){
    rank_sum = wilcox_test$statistic
    p_value = wilcox_test$p.value
    tuple = c(rank_sum, p_value)
    return(tuple)
}
#NLF vs. ELF
Eotaxin_NLF_ELF_tuple = get_stat_pvalue_tuple(Eotaxin_NLF_ELF)
Eotaxin3_NLF_ELF_tuple = get_stat_pvalue_tuple(Eotaxin3_NLF_ELF)
Fractalkine_NLF_ELF_tuple = get_stat_pvalue_tuple(Fractalkine_NLF_ELF)
I309_NLF_ELF_tuple = get_stat_pvalue_tuple(I309_NLF_ELF)
IFNg_NLF_ELF_tuple = get_stat_pvalue_tuple(IFNg_NLF_ELF)
IL10_NLF_ELF_tuple = get_stat_pvalue_tuple(IL10_NLF_ELF)
IL12p70_NLF_ELF_tuple = get_stat_pvalue_tuple(IL12p70_NLF_ELF)
IL13_NLF_ELF_tuple = get_stat_pvalue_tuple(IL13_NLF_ELF)
IL17B_NLF_ELF_tuple = get_stat_pvalue_tuple(IL17B_NLF_ELF)
IL17D_NLF_ELF_tuple = get_stat_pvalue_tuple(IL17D_NLF_ELF)
IL1b_NLF_ELF_tuple = get_stat_pvalue_tuple(IL1b_NLF_ELF)
IL4_NLF_ELF_tuple = get_stat_pvalue_tuple(IL4_NLF_ELF)
IL6_NLF_ELF_tuple = get_stat_pvalue_tuple(IL6_NLF_ELF)
IL8_NLF_ELF_tuple = get_stat_pvalue_tuple(IL8_NLF_ELF)
IP10_NLF_ELF_tuple = get_stat_pvalue_tuple(IP10_NLF_ELF)
ITAC_NLF_ELF_tuple = get_stat_pvalue_tuple(ITAC_NLF_ELF)
MCP1_NLF_ELF_tuple = get_stat_pvalue_tuple(MCP1_NLF_ELF)
MIG_NLF_ELF_tuple = get_stat_pvalue_tuple(MIG_NLF_ELF)
MIP1a_NLF_ELF_tuple = get_stat_pvalue_tuple(MIP1a_NLF_ELF)
MIP1b_NLF_ELF_tuple = get_stat_pvalue_tuple(MIP1b_NLF_ELF)
TARC_NLF_ELF_tuple = get_stat_pvalue_tuple(TARC_NLF_ELF)
TNFa_NLF_ELF_tuple = get_stat_pvalue_tuple(TNFa_NLF_ELF)

#NLF vs. Sputum
Eotaxin_NLF_Sputum_tuple = get_stat_pvalue_tuple(Eotaxin_NLF_Sputum)
Eotaxin3_NLF_Sputum_tuple = get_stat_pvalue_tuple(Eotaxin3_NLF_Sputum)
Fractalkine_NLF_Sputum_tuple = get_stat_pvalue_tuple(Fractalkine_NLF_Sputum)
I309_NLF_Sputum_tuple = get_stat_pvalue_tuple(I309_NLF_Sputum)
IFNg_NLF_Sputum_tuple = get_stat_pvalue_tuple(IFNg_NLF_Sputum)
IL10_NLF_Sputum_tuple = get_stat_pvalue_tuple(IL10_NLF_Sputum)
IL12p70_NLF_Sputum_tuple = get_stat_pvalue_tuple(IL12p70_NLF_Sputum)
IL13_NLF_Sputum_tuple = get_stat_pvalue_tuple(IL13_NLF_Sputum)
IL17B_NLF_Sputum_tuple = get_stat_pvalue_tuple(IL17B_NLF_Sputum)
IL17D_NLF_Sputum_tuple = get_stat_pvalue_tuple(IL17D_NLF_Sputum)
IL1b_NLF_Sputum_tuple = get_stat_pvalue_tuple(IL1b_NLF_Sputum)
IL4_NLF_Sputum_tuple = get_stat_pvalue_tuple(IL4_NLF_Sputum)
IL6_NLF_Sputum_tuple = get_stat_pvalue_tuple(IL6_NLF_Sputum)
IL8_NLF_Sputum_tuple = get_stat_pvalue_tuple(IL8_NLF_Sputum)
IP10_NLF_Sputum_tuple = get_stat_pvalue_tuple(IP10_NLF_Sputum)
ITAC_NLF_Sputum_tuple = get_stat_pvalue_tuple(ITAC_NLF_Sputum)
MCP1_NLF_Sputum_tuple = get_stat_pvalue_tuple(MCP1_NLF_Sputum)
MIG_NLF_Sputum_tuple = get_stat_pvalue_tuple(MIG_NLF_Sputum)
MIP1a_NLF_Sputum_tuple = get_stat_pvalue_tuple(MIP1a_NLF_Sputum)
MIP1b_NLF_Sputum_tuple = get_stat_pvalue_tuple(MIP1b_NLF_Sputum)
TARC_NLF_Sputum_tuple = get_stat_pvalue_tuple(TARC_NLF_Sputum)
TNFa_NLF_Sputum_tuple = get_stat_pvalue_tuple(TNFa_NLF_Sputum)

#NLF vs. Serum
Eotaxin_NLF_Serum_tuple = get_stat_pvalue_tuple(Eotaxin_NLF_Serum)
Eotaxin3_NLF_Serum_tuple = get_stat_pvalue_tuple(Eotaxin3_NLF_Serum)
Fractalkine_NLF_Serum_tuple = get_stat_pvalue_tuple(Fractalkine_NLF_Serum)
I309_NLF_Serum_tuple = get_stat_pvalue_tuple(I309_NLF_Serum)
IFNg_NLF_Serum_tuple = get_stat_pvalue_tuple(IFNg_NLF_Serum)
IL10_NLF_Serum_tuple = get_stat_pvalue_tuple(IL10_NLF_Serum)
IL12p70_NLF_Serum_tuple = get_stat_pvalue_tuple(IL12p70_NLF_Serum)
IL13_NLF_Serum_tuple = get_stat_pvalue_tuple(IL13_NLF_Serum)
IL17B_NLF_Serum_tuple = get_stat_pvalue_tuple(IL17B_NLF_Serum)
IL17D_NLF_Serum_tuple = get_stat_pvalue_tuple(IL17D_NLF_Serum)
IL1b_NLF_Serum_tuple = get_stat_pvalue_tuple(IL1b_NLF_Serum)
IL4_NLF_Serum_tuple = get_stat_pvalue_tuple(IL4_NLF_Serum)
IL6_NLF_Serum_tuple = get_stat_pvalue_tuple(IL6_NLF_Serum)
IL8_NLF_Serum_tuple = get_stat_pvalue_tuple(IL8_NLF_Serum)
IP10_NLF_Serum_tuple = get_stat_pvalue_tuple(IP10_NLF_Serum)
ITAC_NLF_Serum_tuple = get_stat_pvalue_tuple(ITAC_NLF_Serum)
MCP1_NLF_Serum_tuple = get_stat_pvalue_tuple(MCP1_NLF_Serum)
MIG_NLF_Serum_tuple = get_stat_pvalue_tuple(MIG_NLF_Serum)
MIP1a_NLF_Serum_tuple = get_stat_pvalue_tuple(MIP1a_NLF_Serum)
MIP1b_NLF_Serum_tuple = get_stat_pvalue_tuple(MIP1b_NLF_Serum)
TARC_NLF_Serum_tuple = get_stat_pvalue_tuple(TARC_NLF_Serum)
TNFa_NLF_Serum_tuple = get_stat_pvalue_tuple(TNFa_NLF_Serum)

#ELF vs. Sputum
Eotaxin_ELF_Sputum_tuple = get_stat_pvalue_tuple(Eotaxin_ELF_Sputum)
Eotaxin3_ELF_Sputum_tuple = get_stat_pvalue_tuple(Eotaxin3_ELF_Sputum)
Fractalkine_ELF_Sputum_tuple = get_stat_pvalue_tuple(Fractalkine_ELF_Sputum)
I309_ELF_Sputum_tuple = get_stat_pvalue_tuple(I309_ELF_Sputum)
IFNg_ELF_Sputum_tuple = get_stat_pvalue_tuple(IFNg_ELF_Sputum)
IL10_ELF_Sputum_tuple = get_stat_pvalue_tuple(IL10_ELF_Sputum)
IL12p70_ELF_Sputum_tuple = get_stat_pvalue_tuple(IL12p70_ELF_Sputum)
IL13_ELF_Sputum_tuple = get_stat_pvalue_tuple(IL13_ELF_Sputum)
IL17B_ELF_Sputum_tuple = get_stat_pvalue_tuple(IL17B_ELF_Sputum)
IL17D_ELF_Sputum_tuple = get_stat_pvalue_tuple(IL17D_ELF_Sputum)
IL1b_ELF_Sputum_tuple = get_stat_pvalue_tuple(IL1b_ELF_Sputum)
IL4_ELF_Sputum_tuple = get_stat_pvalue_tuple(IL4_ELF_Sputum)
IL6_ELF_Sputum_tuple = get_stat_pvalue_tuple(IL6_ELF_Sputum)
IL8_ELF_Sputum_tuple = get_stat_pvalue_tuple(IL8_ELF_Sputum)
IP10_ELF_Sputum_tuple = get_stat_pvalue_tuple(IP10_ELF_Sputum)
ITAC_ELF_Sputum_tuple = get_stat_pvalue_tuple(ITAC_ELF_Sputum)
MCP1_ELF_Sputum_tuple = get_stat_pvalue_tuple(MCP1_ELF_Sputum)
MIG_ELF_Sputum_tuple = get_stat_pvalue_tuple(MIG_ELF_Sputum)
MIP1a_ELF_Sputum_tuple = get_stat_pvalue_tuple(MIP1a_ELF_Sputum)
MIP1b_ELF_Sputum_tuple = get_stat_pvalue_tuple(MIP1b_ELF_Sputum)
TARC_ELF_Sputum_tuple = get_stat_pvalue_tuple(TARC_ELF_Sputum)
TNFa_ELF_Sputum_tuple = get_stat_pvalue_tuple(TNFa_ELF_Sputum)

#ELF vs. Serum
Eotaxin_ELF_Serum_tuple = get_stat_pvalue_tuple(Eotaxin_ELF_Serum)
Eotaxin3_ELF_Serum_tuple = get_stat_pvalue_tuple(Eotaxin3_ELF_Serum)
Fractalkine_ELF_Serum_tuple = get_stat_pvalue_tuple(Fractalkine_ELF_Serum)
I309_ELF_Serum_tuple = get_stat_pvalue_tuple(I309_ELF_Serum)
IFNg_ELF_Serum_tuple = get_stat_pvalue_tuple(IFNg_ELF_Serum)
IL10_ELF_Serum_tuple = get_stat_pvalue_tuple(IL10_ELF_Serum)
IL12p70_ELF_Serum_tuple = get_stat_pvalue_tuple(IL12p70_ELF_Serum)
IL13_ELF_Serum_tuple = get_stat_pvalue_tuple(IL13_ELF_Serum)
IL17B_ELF_Serum_tuple = get_stat_pvalue_tuple(IL17B_ELF_Serum)
IL17D_ELF_Serum_tuple = get_stat_pvalue_tuple(IL17D_ELF_Serum)
IL1b_ELF_Serum_tuple = get_stat_pvalue_tuple(IL1b_ELF_Serum)
IL4_ELF_Serum_tuple = get_stat_pvalue_tuple(IL4_ELF_Serum)
IL6_ELF_Serum_tuple = get_stat_pvalue_tuple(IL6_ELF_Serum)
IL8_ELF_Serum_tuple = get_stat_pvalue_tuple(IL8_ELF_Serum)
IP10_ELF_Serum_tuple = get_stat_pvalue_tuple(IP10_ELF_Serum)
ITAC_ELF_Serum_tuple = get_stat_pvalue_tuple(ITAC_ELF_Serum)
MCP1_ELF_Serum_tuple = get_stat_pvalue_tuple(MCP1_ELF_Serum)
MIG_ELF_Serum_tuple = get_stat_pvalue_tuple(MIG_ELF_Serum)
MIP1a_ELF_Serum_tuple = get_stat_pvalue_tuple(MIP1a_ELF_Serum)
MIP1b_ELF_Serum_tuple = get_stat_pvalue_tuple(MIP1b_ELF_Serum)
TARC_ELF_Serum_tuple = get_stat_pvalue_tuple(TARC_ELF_Serum)
TNFa_ELF_Serum_tuple = get_stat_pvalue_tuple(TNFa_ELF_Serum)

#Sputum vs. Serum
Eotaxin_Sputum_Serum_tuple = get_stat_pvalue_tuple(Eotaxin_Sputum_Serum)
Eotaxin3_Sputum_Serum_tuple = get_stat_pvalue_tuple(Eotaxin3_Sputum_Serum)
Fractalkine_Sputum_Serum_tuple = get_stat_pvalue_tuple(Fractalkine_Sputum_Serum)
I309_Sputum_Serum_tuple = get_stat_pvalue_tuple(I309_Sputum_Serum)
IFNg_Sputum_Serum_tuple = get_stat_pvalue_tuple(IFNg_Sputum_Serum)
IL10_Sputum_Serum_tuple = get_stat_pvalue_tuple(IL10_Sputum_Serum)
IL12p70_Sputum_Serum_tuple = get_stat_pvalue_tuple(IL12p70_Sputum_Serum)
IL13_Sputum_Serum_tuple = get_stat_pvalue_tuple(IL13_Sputum_Serum)
IL17B_Sputum_Serum_tuple = get_stat_pvalue_tuple(IL17B_Sputum_Serum)
IL17D_Sputum_Serum_tuple = get_stat_pvalue_tuple(IL17D_Sputum_Serum)
IL1b_Sputum_Serum_tuple = get_stat_pvalue_tuple(IL1b_Sputum_Serum)
IL4_Sputum_Serum_tuple = get_stat_pvalue_tuple(IL4_Sputum_Serum)
IL6_Sputum_Serum_tuple = get_stat_pvalue_tuple(IL6_Sputum_Serum)
IL8_Sputum_Serum_tuple = get_stat_pvalue_tuple(IL8_Sputum_Serum)
IP10_Sputum_Serum_tuple = get_stat_pvalue_tuple(IP10_Sputum_Serum)
ITAC_Sputum_Serum_tuple = get_stat_pvalue_tuple(ITAC_Sputum_Serum)
MCP1_Sputum_Serum_tuple = get_stat_pvalue_tuple(MCP1_Sputum_Serum)
MIG_Sputum_Serum_tuple = get_stat_pvalue_tuple(MIG_Sputum_Serum)
MIP1a_Sputum_Serum_tuple = get_stat_pvalue_tuple(MIP1a_Sputum_Serum)
MIP1b_Sputum_Serum_tuple = get_stat_pvalue_tuple(MIP1b_Sputum_Serum)
TARC_Sputum_Serum_tuple = get_stat_pvalue_tuple(TARC_Sputum_Serum)
TNFa_Sputum_Serum_tuple = get_stat_pvalue_tuple(TNFa_Sputum_Serum)

# %%
#putting everything into a table
table_summary = function(Eotaxin, Eotaxin3, Fractalkine, I309,
                                           IFNg, IL10, IL12p70, IL13,
                                           IL17B, IL17D, IL1b, IL4, IL6,
                                           IL8, IP10, ITAC, MCP1, MIG,
                                           MIP1a, MIP1b, TARC, TNFa){
    #"""
    #Putting stats into a table(matrix) to make transfer to excel easier.

    #:param: none
    #:output: a 22x2 matrix containing statistic and p value. 
    #"""
    compartment_stats_table = rbind(Eotaxin, Eotaxin3, Fractalkine, I309,
                                           IFNg, IL10, IL12p70, IL13,
                                           IL17B, IL17D, IL1b, IL4, IL6,
                                           IL8, IP10, ITAC, MCP1, MIG,
                                           MIP1a, MIP1b, TARC, TNFa)
    #compartment_stats_table = t(compartment_table_initial)
    
    colnames(compartment_stats_table) = c('Statistic','p value')
    return(compartment_stats_table)
}

# %%
NLF_ELF_table = table_summary(Eotaxin_NLF_ELF_tuple, Eotaxin3_NLF_ELF_tuple, Fractalkine_NLF_ELF_tuple,I309_NLF_ELF_tuple,
                            IFNg_NLF_ELF_tuple, IL10_NLF_ELF_tuple, IL12p70_NLF_ELF_tuple, IL13_NLF_ELF_tuple, 
                            IL17B_NLF_ELF_tuple, IL17D_NLF_ELF_tuple, IL1b_NLF_ELF_tuple, IL4_NLF_ELF_tuple, IL6_NLF_ELF_tuple,
                            IL8_NLF_ELF_tuple, IP10_NLF_ELF_tuple, ITAC_NLF_ELF_tuple, MCP1_NLF_ELF_tuple, MIG_NLF_ELF_tuple,
                            MIP1a_NLF_ELF_tuple, MIP1b_NLF_ELF_tuple, TARC_NLF_ELF_tuple, TNFa_NLF_ELF_tuple)
NLF_Sputum_table = table_summary(Eotaxin_NLF_Sputum_tuple, Eotaxin3_NLF_Sputum_tuple, Fractalkine_NLF_Sputum_tuple,I309_NLF_Sputum_tuple,
                            IFNg_NLF_Sputum_tuple, IL10_NLF_Sputum_tuple, IL12p70_NLF_Sputum_tuple, IL13_NLF_Sputum_tuple, 
                            IL17B_NLF_Sputum_tuple, IL17D_NLF_Sputum_tuple, IL1b_NLF_Sputum_tuple, IL4_NLF_Sputum_tuple, IL6_NLF_Sputum_tuple,
                            IL8_NLF_Sputum_tuple, IP10_NLF_Sputum_tuple, ITAC_NLF_Sputum_tuple, MCP1_NLF_Sputum_tuple, MIG_NLF_Sputum_tuple,
                            MIP1a_NLF_Sputum_tuple, MIP1b_NLF_Sputum_tuple, TARC_NLF_Sputum_tuple, TNFa_NLF_Sputum_tuple)
NLF_Serum_table = table_summary(Eotaxin_NLF_Serum_tuple, Eotaxin3_NLF_Serum_tuple, Fractalkine_NLF_Serum_tuple,I309_NLF_Serum_tuple,
                            IFNg_NLF_Serum_tuple, IL10_NLF_Serum_tuple, IL12p70_NLF_Serum_tuple, IL13_NLF_Serum_tuple, 
                            IL17B_NLF_Serum_tuple, IL17D_NLF_Serum_tuple, IL1b_NLF_Serum_tuple, IL4_NLF_Serum_tuple, IL6_NLF_Serum_tuple,
                            IL8_NLF_Serum_tuple, IP10_NLF_Serum_tuple, ITAC_NLF_Serum_tuple, MCP1_NLF_Serum_tuple, MIG_NLF_Serum_tuple,
                            MIP1a_NLF_Serum_tuple, MIP1b_NLF_Serum_tuple, TARC_NLF_Serum_tuple, TNFa_NLF_Serum_tuple)
ELF_Sputum_table = table_summary(Eotaxin_ELF_Sputum_tuple, Eotaxin3_ELF_Sputum_tuple, Fractalkine_ELF_Sputum_tuple,I309_ELF_Sputum_tuple,
                            IFNg_ELF_Sputum_tuple, IL10_ELF_Sputum_tuple, IL12p70_ELF_Sputum_tuple, IL13_ELF_Sputum_tuple, 
                            IL17B_ELF_Sputum_tuple, IL17D_ELF_Sputum_tuple, IL1b_ELF_Sputum_tuple, IL4_ELF_Sputum_tuple, IL6_ELF_Sputum_tuple,
                            IL8_ELF_Sputum_tuple, IP10_ELF_Sputum_tuple, ITAC_ELF_Sputum_tuple, MCP1_ELF_Sputum_tuple, MIG_ELF_Sputum_tuple,
                            MIP1a_ELF_Sputum_tuple, MIP1b_ELF_Sputum_tuple, TARC_ELF_Sputum_tuple, TNFa_ELF_Sputum_tuple)
ELF_Serum_table = table_summary(Eotaxin_ELF_Serum_tuple, Eotaxin3_ELF_Serum_tuple, Fractalkine_ELF_Serum_tuple,I309_ELF_Serum_tuple,
                            IFNg_ELF_Serum_tuple, IL10_ELF_Serum_tuple, IL12p70_ELF_Serum_tuple, IL13_ELF_Serum_tuple, 
                            IL17B_ELF_Serum_tuple, IL17D_ELF_Serum_tuple, IL1b_ELF_Serum_tuple, IL4_ELF_Serum_tuple, IL6_ELF_Serum_tuple,
                            IL8_ELF_Serum_tuple, IP10_ELF_Serum_tuple, ITAC_ELF_Serum_tuple, MCP1_ELF_Serum_tuple, MIG_ELF_Serum_tuple,
                            MIP1a_ELF_Serum_tuple, MIP1b_ELF_Serum_tuple, TARC_ELF_Serum_tuple, TNFa_ELF_Serum_tuple)
Sputum_Serum_table = table_summary(Eotaxin_Sputum_Serum_tuple, Eotaxin3_Sputum_Serum_tuple, Fractalkine_Sputum_Serum_tuple,I309_Sputum_Serum_tuple,
                            IFNg_Sputum_Serum_tuple, IL10_Sputum_Serum_tuple, IL12p70_Sputum_Serum_tuple, IL13_Sputum_Serum_tuple, 
                            IL17B_Sputum_Serum_tuple, IL17D_Sputum_Serum_tuple, IL1b_Sputum_Serum_tuple, IL4_Sputum_Serum_tuple, IL6_Sputum_Serum_tuple,
                            IL8_Sputum_Serum_tuple, IP10_Sputum_Serum_tuple, ITAC_Sputum_Serum_tuple, MCP1_Sputum_Serum_tuple, MIG_Sputum_Serum_tuple,
                            MIP1a_Sputum_Serum_tuple, MIP1b_Sputum_Serum_tuple, TARC_Sputum_Serum_tuple, TNFa_Sputum_Serum_tuple)
baseline_compartment_table = cbind(NLF_ELF_table, NLF_Sputum_table, NLF_Serum_table, ELF_Sputum_table, ELF_Serum_table, Sputum_Serum_table)

# %%
col_names = c('Stat','p value', 'P Adj', 'Stat','p value', 'P Adj','Stat','p value', 'P Adj','Stat','p value', 
              'P Adj','Stat','p value', 'P Adj', 'Stat','p value', 'P Adj')
final_table_summary = function(table, names_vector){
    #going back to calculate padj values
    padj = apply(cbind(table[,2],table[,4], table[,6], table[,8],table[,10], table[,12]), 2, 
                 p.adjust, method = "fdr") #the 2 applies function down the col
    
    #inserting these back into the OG df to export all values
    final_table = cbind(table[,1:2], padj[,1], table[,3:4],padj[,2], table[,5:6], padj[,3], table[,7:8],padj[,4],
                       table[,9:10], padj[,5], table[,11:12],padj[,6])
    colnames(final_table) = names_vector
    return(final_table)
}
#calling fn
final_baseline_compartment_table = final_table_summary(baseline_compartment_table, col_names)

# %%
write.csv(final_baseline_compartment_table, paste0(Output,"/", cur_date, "_Baseline_Cytokine_Distribution.csv"), row.names= TRUE)
